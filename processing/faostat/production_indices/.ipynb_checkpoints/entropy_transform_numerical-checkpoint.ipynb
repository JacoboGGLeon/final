# %%
library(SpatEntropy)
library(ggplot2)
library(stats)
library(factoextra)
library(clusterCrit)
library(scatterplot3d)
# Out:
# Loading required package: spatstat
# Loading required package: spatstat.data
# Loading required package: nlme
# Loading required package: rpart
#
# spatstat 1.58-2       (nickname: ‘Not Even Wrong’)
# For an introduction to spatstat, type ‘beginner’
#
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %%
file = "../../../../dataframes/faostat/production_indices/production_indices_transform.csv"

# %%
df <- read.csv(file = file)
data <- df
head(data)
# Out:
#   area_code  element_code item_code year      value
# 1 0.06101813 0.25         0.1752673 0.2862622 0.1648842
# 2 0.06101813 0.25         0.1752673 0.4295676 0.1573334
# 3 0.06101813 0.25         0.1752673 0.5721757 0.1740363
# 4 0.06101813 0.25         0.1752673 0.7147838 0.1702903
# 5 0.06101813 0.25         0.1752673 0.8573919 0.1765043
# 6 0.06101813 0.25         0.1752673 1.0000000 0.1699671

# %%
ncol(data)
# Out:
# [1] 5

# %%
data_names <- c()
data_entropy <- c()

for (column in 1:ncol(data)) {
#    print(names(data[column]))
    entropy <- SpatEntropy::shannonX(data = matrix(data[column]))
  
  data_names <- append(x = data_names, values = names(data[column]))
  data_entropy <- append(x = data_entropy, values = entropy$shannon)
}

# %%
df_entropy <- cbind(data.frame(data_names, data_entropy)) 
head(df_entropy)
# Out:
#   data_names   data_entropy
# 1 area_code    5.367854
# 2 element_code 1.386294
# 3 item_code    1.789534
# 4 year         1.945906
# 5 value        8.981984

# %%
order_df_entropy <- df_entropy[order(df_entropy$data_entropy, decreasing = T), ]
head(order_df_entropy)
# Out:
#   data_names   data_entropy
# 5 value        8.981984
# 1 area_code    5.367854
# 4 year         1.945906
# 3 item_code    1.789534
# 2 element_code 1.386294

# %%
ggplot(df_entropy, 
       aes(y=data_names, x=data_entropy)) + geom_point() + theme_light()
# Out:
# plot without title

# %%
ggplot(data = data, 
       aes(y=data$value, 
           x=data$area_code)) + geom_point() + theme_light()
# Out:
# plot without title

# %%
scatterplot3d(y=data$value, 
              x=data$area_code,
              z=data$year, pch = 19, color = "green4", main="3D Scatterplot")
# Out:
# Plot with title “3D Scatterplot”

# %%
file = "../../../../dataframes/faostat/production_indices/production_indices_entropy_transform_numerical.csv"

# %%
write.csv(order_df_entropy, 
          file = file,
          row.names=FALSE)

# %%
data <- as.matrix(data)

# %%
range_k = 2:10
dunn_kmeans <- c()
set.seed(123)

for (k in range_k) {
  set.seed(123)
  
  kmeans <- stats::kmeans(x = data, centers = k, nstart = 25)
    print(is.integer(kmeans$cluster))
  
  index_internal_kmeans <- clusterCrit::intCriteria(traj = data,
                                                    part = kmeans$cluster, 
                                                    #part = as.vector(as.integer(kmeans$cluster)), 
                                                    crit = "dunn")
  dunn_kmeans[k-1] <- index_internal_kmeans$dunn
}
# Out:
# [1] TRUE
# Warning message:
# “Quick-TRANSfer stage steps exceeded maximum (= 1720800)”
# [1] TRUE
# [1] TRUE
# Warning message:
# “Quick-TRANSfer stage steps exceeded maximum (= 1720800)”
# [1] TRUE
# Warning message:
# “Quick-TRANSfer stage steps exceeded maximum (= 1720800)”Warning message:
# “Quick-TRANSfer stage steps exceeded maximum (= 1720800)”Warning message:
# “Quick-TRANSfer stage steps exceeded maximum (= 1720800)”
# [1] TRUE
# Warning message:
# “did not converge in 10 iterations”
# [1] TRUE
# [1] TRUE
# [1] TRUE
# Warning message:
# “Quick-TRANSfer stage steps exceeded maximum (= 1720800)”Warning message:
# “did not converge in 10 iterations”
# [1] TRUE

# %%
dunn_kmeans
# Out:
# [1] 0.003217818 0.003324923 0.003047606 0.003620304 0.003163812 0.003460359
# [7] 0.003595799 0.003782717 0.003688107

# %%
plot_dunn_kmeans <- ggplot2::qplot(x = range_k, 
                                   y = dunn_kmeans, 
                                   geom = 'line', 
                                   main = 'k-means', 
                                   xlab = 'k', 
                                   ylab = 'Distance Ratio')

plot_dunn_kmeans <- plot_dunn_kmeans  + 
  theme_bw() + #ylim(0,0.3) + 
  geom_vline(xintercept = range_k[which.max(dunn_kmeans)],
             linetype = 2, color='red')   
#ggsave(filename = "../../images/enh/dunn_kmeans_2_15.png", dpi = 300)

plot_dunn_kmeans
# Out:
# plot without title

# %%
kmeans <- stats::kmeans(x = data, 
                        centers = range_k[which.max(dunn_kmeans)],  
                        algorithm="MacQueen",
                        nstart = 25)

plot_kmeans <- factoextra::fviz_cluster(object = kmeans,
                                        data = data,
                                        stand = F, 
                                        geom =  'point', 
                                        ellipse.type = 'convex',
                                        ellipse = T,
                                        main = paste('Clustering: k-means k:', range_k[which.max(dunn_kmeans)]),
                                        outlier.color = 'black',
                                        show.clust.cent = T)

plot_kmeans <- plot_kmeans + 
  theme_bw() +
  theme(legend.position = 'bottom')  

plot_kmeans
# Out:
# Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”
# plot without title
