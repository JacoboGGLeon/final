# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file = "../../../../../../dataframes/enh/df_09.csv"

# %%
df = pd.read_csv(file)

# %%
df.shape
# Out:
# (3588, 80)

# %%
df.head()
# Out:
#    CVE_ENT  CVE_MUN  aire_acond  ais_otro  ais_pared  ais_techos  ais_ventan  \
# 0        9        2           2         2          2           2           2
# 1        9        2           2         9          9           9           9
# 2        9        2           2         2          2           2           2
# 3        9        2           2         2          2           2           2
# 4        9        2           2         2          2           2           2
#
#   antiguedad  auto_pick bano_comp  ... tam_loc tanque_gas  tel_fijo  tenencia  \
# 0                     2         1  ...       1          2         1         1
# 1         10          1         2  ...       1          2         1         1
# 2                     2         2  ...       1          2         1         1
# 3         10          1         1  ...       1          1         1         3
# 4                     2         1  ...       1          2         2         1
#
# ...

# %%
df_copy = df.copy()

# %%
df_copy.replace(to_replace=' ', value=np.NaN, inplace=True)

# %%
df_copy.replace(to_replace='&', value=np.NaN, inplace=True)

# %%
df_copy.replace(to_replace=np.NaN, value=-1, inplace=True)

# %%
df_copy = df_copy.astype('int64')

# %%
l = []
bandera = np.NAN
for column in df_copy.columns:
    if df[column].dtype == np.int64:
        bandera = 'entero'
    elif df[column].dtype == np.float64:
        bandera = 'flotante'
    else:
        bandera = 'otro'
        
    print('COLUMNA: ', column)
    print('TIPO: ', bandera)
    print('NUNIQUE: ', df_copy[column].nunique())
    print('UNIQUE: ', df_copy[column].unique())
    print('VALUE COUNTS ', df_copy[column].value_counts())
    print('\n')
# Out:
# COLUMNA:  CVE_ENT
# TIPO:  entero
# NUNIQUE:  1
# UNIQUE:  [9]
# VALUE COUNTS  9    3588
# Name: CVE_ENT, dtype: int64
#
#
# COLUMNA:  CVE_MUN
# TIPO:  entero
# NUNIQUE:  16
# UNIQUE:  [ 2  3  4  5  6  7  8 10 11 12 13 14 15 16 17  9]
# VALUE COUNTS  7     610
# 5     412
# 15    331
# 12    296
# 10    276
# 3     269
# 17    198
# 2     195
# 14    190
# 11    167
# 6     161
# 13    144
# 16    125
# 8      82
# 4      73
# 9      59
# Name: CVE_MUN, dtype: int64
#
#
# COLUMNA:  aire_acond
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    3568
# 1      20
# Name: aire_acond, dtype: int64
#
#
# COLUMNA:  ais_otro
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2 9 1]
# VALUE COUNTS  2    3554
# 9      31
# 1       3
# Name: ais_otro, dtype: int64
#
#
# COLUMNA:  ais_pared
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2 9 1]
# VALUE COUNTS  2    3529
# 9      31
# 1      28
# Name: ais_pared, dtype: int64
#
#
# COLUMNA:  ais_techos
# TIPO:  entero
# NUNIQUE:  3
# ...

# %%
df_copy.replace(to_replace=-1, value=np.NaN, inplace=True)

# %%
df_copy.head()
# Out:
#    CVE_ENT  CVE_MUN  aire_acond  ais_otro  ais_pared  ais_techos  ais_ventan  \
# 0        9        2           2         2          2           2           2
# 1        9        2           2         9          9           9           9
# 2        9        2           2         2          2           2           2
# 3        9        2           2         2          2           2           2
# 4        9        2           2         2          2           2           2
#
#    antiguedad  auto_pick  bano_comp  ...  tam_loc  tanque_gas  tel_fijo  \
# 0         NaN          2        1.0  ...        1           2         1
# 1        10.0          1        2.0  ...        1           2         1
# 2         NaN          2        2.0  ...        1           2         1
# 3        10.0          1        1.0  ...        1           1         1
# 4         NaN          2        1.0  ...        1           2         2
#
# ...

# %%
msno.matrix(df_copy, fontsize=50, sparkline=False, labels=False)
plt.xlabel('Columnas', fontsize=20)
plt.ylabel('Observaciones', fontsize=20)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09.png', dpi=300)
# Out:
# Text(0, 0.5, 'Observaciones')

# %%
msno.bar(df_copy, fontsize=10, labels=False)
plt.xlabel('Columnas', fontsize=20)
plt.ylabel('Observaciones', fontsize=20)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09.png', dpi=300)
# Out:
# Text(0, 0.5, 'Observaciones')

# %%
df_copy.replace(to_replace=np.NaN, value=-1, inplace=True)

# %%
df_copy.columns[df_copy.isna().any()].tolist()
# Out:
# []

# %%
threshold = round(df_copy.shape[0]*.8)
threshold
# Out:
# 2870

# %%
l = []
for column in df_copy.columns:
    na_column =  df_copy[column].value_counts().get(-1)
    if(na_column != None):
        if (df_copy.shape[0] - na_column < threshold):
            print(column, ': ', df_copy.shape[0] - na_column, ' - ', threshold, 'd e l e t e d')
            l.append(column)
# Out:
# antiguedad :  2608  -  2870 d e l e t e d
# condominio :  1113  -  2870 d e l e t e d
# elevador :  1113  -  2870 d e l e t e d
# escrituras :  1871  -  2870 d e l e t e d
# estufa_chi :  5  -  2870 d e l e t e d
# financia_2 :  20  -  2870 d e l e t e d
# financia_3 :  250  -  2870 d e l e t e d
# financia_4 :  161  -  2870 d e l e t e d
# financia_5 :  4  -  2870 d e l e t e d
# financia_6 :  10  -  2870 d e l e t e d
# financia_7 :  145  -  2870 d e l e t e d
# financia_8 :  94  -  2870 d e l e t e d
# hog_dueno1 :  1866  -  2870 d e l e t e d
# hog_dueno2 :  184  -  2870 d e l e t e d
# num_dueno1 :  1866  -  2870 d e l e t e d
# num_dueno2 :  184  -  2870 d e l e t e d
# pago_renta :  803  -  2870 d e l e t e d
# tipo_adqui :  1871  -  2870 d e l e t e d

# %%
l.remove('antiguedad')

# %%
df_copy.drop(labels=l, axis=1, inplace=True)

# %%
df_copy.fillna(value=-1, inplace=True)

# %%
df_copy.replace(to_replace=-1, value=np.NaN, inplace=True)

# %%
msno.bar(df_copy, fontsize=10, labels=False)
plt.xlabel('Columnas', fontsize=20)
plt.ylabel('Observaciones', fontsize=20)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09.png', dpi=300)
# Out:
# Text(0, 0.5, 'Observaciones')

# %%
file = "../../../../../../dataframes/enh/df_09_clean.csv"

# %%
df_copy.to_csv(file,index = False, header = True, sep = ',', encoding = 'utf-8')
