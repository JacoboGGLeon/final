# %%
library(SpatEntropy)
library(ggplot2)
library(stats)
library(factoextra)
library(clusterCrit)
library(scatterplot3d)
# Out:
# Loading required package: spatstat
# Loading required package: spatstat.data
# Loading required package: nlme
# Loading required package: rpart
#
# spatstat 1.58-2       (nickname: ‘Not Even Wrong’)
# For an introduction to spatstat, type ‘beginner’
#
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %%
file = "../../../../../../dataframes/enh/vivienda/df_09_transform.csv"

# %%
df <- read.csv(file = file)
data <- df
head(data)
# Out:
#   aire_acond ais_otro    ais_pared   ais_techos  ais_ventan  antiguedad
# 1 1          0.999163880 0.992196210 0.981884058 0.989966555 0.3535354
# 2 1          0.008639911 0.008639911 0.008361204 0.008639911 0.1010101
# 3 1          0.999163880 0.992196210 0.981884058 0.989966555 0.2424242
# 4 1          0.999163880 0.992196210 0.981884058 0.989966555 0.1010101
# 5 1          0.999163880 0.992196210 0.981884058 0.989966555 0.3838384
# 6 1          0.999163880 0.992196210 0.981884058 0.989966555 0.1515152
#   auto_pick bano_comp bano_excus bano_regad ⋯ sanit_agua tam_loc   tanque_gas
# 1 1.0000000 0.1111111 0.0000000  0          ⋯ 1.0000000  0.9590301 1.0000000
# 2 0.4278149 0.2222222 0.0000000  0          ⋯ 1.0000000  0.9590301 1.0000000
# 3 1.0000000 0.2222222 0.0000000  0          ⋯ 1.0000000  0.9590301 1.0000000
# 4 0.4278149 0.1111111 0.0000000  0          ⋯ 1.0000000  0.9590301 0.3004459
# 5 1.0000000 0.1111111 0.0000000  0          ⋯ 1.0000000  0.9590301 1.0000000
# 6 1.0000000 0.0000000 0.1666667  0          ⋯ 0.1346154  0.9590301 1.0000000
#   tel_fijo  tenencia  tinaco_azo tipo_viv  tot_hog tv_paga   uso_compar
# 1 0.7009476 0.7268673 0.7979376  0.9966555 1       0.6897993 1.0000000
# 2 0.7009476 0.7268673 0.7979376  0.3079710 1       0.6897993 1.0000000
# 3 0.7009476 0.7268673 0.7979376  0.3079710 1       0.6897993 1.0000000
# 4 0.7009476 0.9941472 0.7979376  0.3079710 1       0.6897993 1.0000000
# 5 1.0000000 0.7268673 0.7979376  0.9966555 1       1.0000000 1.0000000
# 6 0.7009476 0.9280936 1.0000000  0.9966555 1       0.6897993 0.0780379

# %%
ncol(data)
# Out:
# [1] 61

# %%
data_names <- c()
data_entropy <- c()

for (column in 1:ncol(data)) {
#    print(names(data[column]))
    entropy <- SpatEntropy::shannonX(data = matrix(data[column]))
  
  data_names <- append(x = data_names, values = names(data[column]))
  data_entropy <- append(x = data_entropy, values = entropy$shannon)
}

# %%
df_entropy <- cbind(data.frame(data_names, data_entropy)) 
head(df_entropy)
# Out:
#   data_names data_entropy
# 1 aire_acond 0.03448621
# 2 ais_otro   0.05640771
# 3 ais_pared  0.09523204
# 4 ais_techos 0.13878714
# 5 ais_ventan 0.10572149
# 6 antiguedad 3.79646658

# %%
order_df_entropy <- df_entropy[order(df_entropy$data_entropy, decreasing = T), ]
head(order_df_entropy)
# Out:
#    data_names data_entropy
# 6  antiguedad 3.796467
# 34 focos_ahor 2.816753
# 43 num_cuarto 1.907477
# 56 tenencia   1.370501
# 26 cuart_dorm 1.294048
# 8  bano_comp  1.074464

# %%
ggplot(df_entropy, 
       aes(y=data_names, x=data_entropy)) + geom_point() + theme_light()
# Out:
# plot without title

# %%
ggplot(data = data, 
       aes(y=data$antiguedad, 
           x=data$focos_ahor)) + geom_point() + theme_light()
# Out:
# plot without title

# %%
scatterplot3d(y=data$antiguedad, 
              x=data$focos_ahor,
              z=data$num_cuarto, pch = 19, color = "green4", main="3D Scatterplot")
# Out:
# Plot with title “3D Scatterplot”

# %%
file = "../../../../../../dataframes/enh/vivienda/df_09_entropy_transform_numerical.csv"

# %%
write.csv(order_df_entropy, 
          file = file,
          row.names=FALSE)
