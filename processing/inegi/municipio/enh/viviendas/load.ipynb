# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Tabla resumen con información a nivel hogar

# %% [markdown]
# `VIVIENDA`

# %%
file = "../../../../../../dataframes/enh/df_09_concat.csv"

# %%
df = pd.read_csv(file)

# %%
df.shape
# Out:
# (3588, 132)

# %%
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#    CVE_ENT  CVE_MUN   ageb  aire_acond  ais_otro  ais_pared  ais_techos  \
# 0        9        2  000-0           2         2          2           2
# 1        9        2  000-0           2         9          9           9
# 2        9        2  000-0           2         2          2           2
# 3        9        2  000-0           2         2          2           2
# 4        9        2  000-0           2         2          2           2
#
#    ais_ventan anio_panel anio_res  ... tipo_viv  tot_hog tot_resid tv_paga  \
# 0           2                 NaN  ...        1        1       4.0       1
# 1           9                 NaN  ...        2        1       3.0       1
# 2           2                 NaN  ...        2        1       3.0       1
# 3           2                 NaN  ...        2        1       4.0       1
# 4           2                 NaN  ...        1        1       1.0       2
#
#   ubica_geo   upm  uso_compar  valor_viv  vend_hered  viv_usada
# 0  90020000  2181           2
# 1  90020000  2181           2
# 2  90020000  2181           2
# 3  90020000  2181           2          6           1          2
# 4  90020000  2181           2
#
# [5 rows x 132 columns]

# %%
#list(df_copy.columns)

# %%
df_09 = df.copy()

# %%
list_identificadores = ['ageb', 'ubica_geo', 'upm', 'factor', 'est_dis', 'folioviv', 'est_dis']

# %%
df_09.drop(labels=list_identificadores, axis=1, inplace=True)

# %%
df_09.fillna(value=-1, inplace=True)

# %%
df_09.replace(to_replace=-1, value=np.NaN, inplace=True)

# %%
msno.matrix(df_09, fontsize=50, sparkline=False, labels=False)
plt.xlabel('Columnas', fontsize=20)
plt.ylabel('Observaciones', fontsize=20)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09.png', dpi=300)
# Out:
# Text(0, 0.5, 'Observaciones')

# %%
msno.bar(df_09, fontsize=10, labels=False)
plt.xlabel('Columnas', fontsize=20)
plt.ylabel('Observaciones', fontsize=20)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09.png', dpi=300)
# Out:
# Text(0, 0.5, 'Observaciones')

# %%
df_09.replace(to_replace=np.NaN, value=-1, inplace=True)

# %%
df_09.columns[df_09.isna().any()].tolist()
# Out:
# []

# %%
threshold = round(df_09.shape[0]*.8)
threshold
# Out:
# 2870

# %%
l = []
for column in df_09.columns:
    na_column =  df_09[column].value_counts().get(-1)
    if(na_column != None):
        if (df_09.shape[0] - na_column < threshold):
            print(column, ': ', df_09.shape[0] - na_column, ' - ', threshold, 'd e l e t e d')
            l.append(column)
# Out:
# anio_panel :  0  -  2870 d e l e t e d
# anio_res :  1776  -  2870 d e l e t e d
# comun1 :  1776  -  2870 d e l e t e d
# comun10 :  1776  -  2870 d e l e t e d
# comun11 :  1776  -  2870 d e l e t e d
# comun12 :  1776  -  2870 d e l e t e d
# comun13 :  1776  -  2870 d e l e t e d
# comun14 :  1776  -  2870 d e l e t e d
# comun15 :  1776  -  2870 d e l e t e d
# comun16 :  1776  -  2870 d e l e t e d
# comun17 :  1776  -  2870 d e l e t e d
# comun2 :  1776  -  2870 d e l e t e d
# comun3 :  1776  -  2870 d e l e t e d
# comun4 :  1776  -  2870 d e l e t e d
# comun5 :  1776  -  2870 d e l e t e d
# comun6 :  1776  -  2870 d e l e t e d
# comun7 :  1776  -  2870 d e l e t e d
# comun8 :  1776  -  2870 d e l e t e d
# comun9 :  1776  -  2870 d e l e t e d
# dispos_ne :  1812  -  2870 d e l e t e d
# dispos_nh1 :  1812  -  2870 d e l e t e d
# dispos_nh2 :  1812  -  2870 d e l e t e d
# dispos_no1 :  1812  -  2870 d e l e t e d
# dispos_no2 :  1812  -  2870 d e l e t e d
# estaciona :  1776  -  2870 d e l e t e d
# facul_ne :  1812  -  2870 d e l e t e d
# facul_nh1 :  1812  -  2870 d e l e t e d
# facul_nh2 :  1812  -  2870 d e l e t e d
# facul_no1 :  1812  -  2870 d e l e t e d
# facul_no2 :  1812  -  2870 d e l e t e d
# familiar :  1776  -  2870 d e l e t e d
# financia_1 :  2500  -  2870 d e l e t e d
# mes_res :  1776  -  2870 d e l e t e d
# panel_ne :  0  -  2870 d e l e t e d
# pot_panel :  0  -  2870 d e l e t e d
# potencia :  0  -  2870 d e l e t e d
# ren_estufa :  1812  -  2870 d e l e t e d
# ren_horno :  1812  -  2870 d e l e t e d
# ren_lavad :  1812  -  2870 d e l e t e d
# ren_planch :  1812  -  2870 d e l e t e d
# ren_refri :  1812  -  2870 d e l e t e d
# ren_tv :  1812  -  2870 d e l e t e d
# tot_resid :  1812  -  2870 d e l e t e d
# valor_viv :  1812  -  2870 d e l e t e d
# vend_hered :  1812  -  2870 d e l e t e d
# viv_usada :  1812  -  2870 d e l e t e d

# %%
df_09.shape
# Out:
# (3588, 126)

# %%
df_09.drop(labels=l, axis=1, inplace=True)

# %%
df_09.fillna(value=-1, inplace=True)

# %%
df_09.replace(to_replace=-1, value=np.NaN, inplace=True)

# %%
msno.matrix(df_09, fontsize=50, sparkline=False, labels=False)
plt.xlabel('Columnas', fontsize=20)
plt.ylabel('Observaciones', fontsize=20)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09.png', dpi=300)
# Out:
# Text(0, 0.5, 'Observaciones')

# %%
msno.bar(df_09, fontsize=10, labels=False)
plt.xlabel('Columnas', fontsize=20)
plt.ylabel('Observaciones', fontsize=20)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09.png', dpi=300)
# Out:
# Text(0, 0.5, 'Observaciones')

# %%
df_09.head()
# Out:
#    CVE_ENT  CVE_MUN  aire_acond  ais_otro  ais_pared  ais_techos  ais_ventan  \
# 0        9        2           2         2          2           2           2
# 1        9        2           2         9          9           9           9
# 2        9        2           2         2          2           2           2
# 3        9        2           2         2          2           2           2
# 4        9        2           2         2          2           2           2
#
#   antiguedad  auto_pick bano_comp  ... tam_loc tanque_gas  tel_fijo  tenencia  \
# 0                     2         1  ...       1          2         1         1
# 1         10          1         2  ...       1          2         1         1
# 2                     2         2  ...       1          2         1         1
# 3         10          1         1  ...       1          1         1         3
# 4                     2         1  ...       1          2         2         1
#
#    tinaco_azo  tipo_adqui  tipo_viv  tot_hog  tv_paga  uso_compar
# 0           1                     1        1        1           2
# 1           1                     2        1        1           2
# 2           1                     2        1        1           2
# 3           1           1         2        1        1           2
# 4           1                     1        1        2           2
#
# [5 rows x 80 columns]

# %%
file = "../../../../../../dataframes/enh/df_09.csv"

# %%
df_09.to_csv(file,index = False, header = True, sep = ',', encoding = 'utf-8')
