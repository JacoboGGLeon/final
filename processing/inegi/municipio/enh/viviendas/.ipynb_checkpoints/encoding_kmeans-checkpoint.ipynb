# %%
library(SpatEntropy)
library(ggplot2)
library(stats)
library(factoextra)
library(clusterCrit)
library(scatterplot3d)
library(kmed)
library(plotly)
# Out:
# Loading required package: spatstat
# Loading required package: spatstat.data
# Loading required package: nlme
# Loading required package: rpart
#
# spatstat 1.58-2       (nickname: ‘Not Even Wrong’)
# For an introduction to spatstat, type ‘beginner’
#
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ
#
# Attaching package: ‘plotly’
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following object is masked from ‘package:graphics’:
#
#     layout

# %%
file = "../../../../../../dataframes/enh/vivienda/df_encoding.csv"

# %%
#cargar
df <- read.csv(file = file)
data <- df
head(data)
# Out:
#   antiguedad bano_comp bano_excus bano_regad cuart_dorm focos_ahor focos_inca
# 1 0.3535354  0.1111111 0.0000000  0          0.125      0.10101010 0.00000000
# 2 0.1010101  0.2222222 0.0000000  0          0.125      0.10101010 0.00000000
# 3 0.2424242  0.2222222 0.0000000  0          0.125      0.00000000 0.16666667
# 4 0.1010101  0.1111111 0.0000000  0          0.125      0.17171717 0.00000000
# 5 0.3838384  0.1111111 0.0000000  0          0.000      0.02020202 0.00000000
# 6 0.1515152  0.0000000 0.1666667  0          0.000      0.00000000 0.02222222
#   num_cuarto aire_acond_1 aire_acond_2 ⋯ tipo_viv_4 tipo_viv_5 tot_hog_1
# 1 0.26666667 0            1            ⋯ 0          0          1
# 2 0.20000000 0            1            ⋯ 0          0          1
# 3 0.20000000 0            1            ⋯ 0          0          1
# 4 0.26666667 0            1            ⋯ 0          0          1
# 5 0.06666667 0            1            ⋯ 0          0          1
# 6 0.00000000 0            1            ⋯ 0          0          1
#   tot_hog_2 tot_hog_3 tot_hog_4 tv_paga_1 tv_paga_2 uso_compar_1 uso_compar_2
# 1 0         0         0         1         0         0            1
# 2 0         0         0         1         0         0            1
# 3 0         0         0         1         0         0            1
# 4 0         0         0         1         0         0            1
# 5 0         0         0         0         1         0            1
# 6 0         0         0         1         0         1            0

# %%
ncol(data)
# Out:
# [1] 159

# %%
data <- as.matrix(data)

range_k = 2:10
dunn_kmeans <- c()
set.seed(123)

for (k in range_k) {
  set.seed(123)
  
  kmeans <- stats::kmeans(x = data, centers = k, nstart = 25)
  
  index_internal_kmeans <- clusterCrit::intCriteria(traj = data,
                                                    part = as.integer(kmeans$cluster), 
                                                    crit = "dunn")
  dunn_kmeans[k-1] <- index_internal_kmeans$dunn
}
# Out:
# Warning message:
# “did not converge in 10 iterations”Warning message:
# “did not converge in 10 iterations”

# %%
max(dunn_kmeans)
# Out:
# [1] 0.1955903

# %%
plot_dunn_kmeans <- ggplot2::qplot(x = range_k, 
                                   y = dunn_kmeans, 
                                   geom = 'line', 
                                   main = 'Algoritmo: k-means | Distancia: Euclidean', 
                                   xlab = 'k centroides', 
                                   ylab = 'Índice Dunn')


plot_dunn_kmeans  + 
theme_bw() + #ylim(0,0.3) + 
geom_vline(xintercept = range_k[which.max(dunn_kmeans)], linetype = 2, color='red') +
theme(plot.title = element_text(hjust = 0.5)) +
ggsave(filename = "../../../../../../images/enh/dunn_euclidean_encoding.png", dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
kmeans <- stats::kmeans(x = data, 
                        centers = range_k[which.max(dunn_kmeans)], 
                        nstart = 25)

# %%
plot_kmeans <- factoextra::fviz_cluster(object = kmeans,
                                        data = data,
                                        stand = F, 
                                        geom =  'point', 
                                        ellipse.type = 'convex',
                                        ellipse = T,
                                        main = paste('Algoritmo: k-means | Distancia: Euclidean | k centroides:', range_k[which.max(dunn_kmeans)]),
                                        outlier.color = 'black',
                                        show.clust.cent = T)

plot_kmeans + 
theme_bw() +
theme(legend.position = 'bottom') + 
theme(plot.title = element_text(hjust = 0.5)) +
ggsave(filename = "../../../../../../images/enh/kmeans_euclidean_one_hot.png", 
       dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
file = "../../../../../../dataframes/enh/vivienda/df_encoding_cluster.csv"

# %%
write.csv(kmeans$cluster, 
          file = file,
          row.names=F)
