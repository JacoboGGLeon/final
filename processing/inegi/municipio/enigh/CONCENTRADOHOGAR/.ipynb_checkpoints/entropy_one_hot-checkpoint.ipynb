# %%
library(SpatEntropy)
library(ggplot2)
library(stats)
library(factoextra)
library(clusterCrit)
library(scatterplot3d)
# Out:
# Loading required package: spatstat
# Loading required package: spatstat.data
# Loading required package: nlme
# Loading required package: rpart
#
# spatstat 1.58-2       (nickname: ‘Not Even Wrong’)
# For an introduction to spatstat, type ‘beginner’
#
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %%
file = '../../../../../../dataframes/enigh/CONCENTRADOHOGAR/mixed/df_encoding.csv'

# %%
df <- read.csv(file = file)
data <- df
head(data)
# Out:
#   edad_jefe percep_ing perc_ocupa ing_cor    ingtrab    trabajo    sueldos
# 1 0.2820513 0.2        0.2222222  0.05766597 0.05600359 0.05600359 0.05816475
# 2 0.8333333 0.1        0.0000000  0.03619238 0.00000000 0.00000000 0.00000000
# 3 0.3333333 0.1        0.1111111  0.04818465 0.04162817 0.04162817 0.04333269
# 4 0.3846154 0.1        0.1111111  0.04150861 0.06293463 0.06293463 0.05666460
# 5 0.7307692 0.1        0.0000000  0.08671385 0.00000000 0.00000000 0.00000000
# 6 0.5384615 0.6        0.3333333  0.07702109 0.06981120 0.06046435 0.06298828
#   horas_extr comisiones aguinaldo  ⋯ p65mas_5 ocupados_0 ocupados_1 ocupados_2
# 1 0          0          0.01599024 ⋯ 0        0          0          1
# 2 0          0          0.00000000 ⋯ 0        1          0          0
# 3 0          0          0.01119154 ⋯ 0        0          1          0
# 4 0          0          0.01717771 ⋯ 0        0          1          0
# 5 0          0          0.00000000 ⋯ 0        1          0          0
# 6 0          0          0.01590891 ⋯ 0        0          0          0
#   ocupados_3 ocupados_4 ocupados_5 ocupados_6 ocupados_7 ocupados_8
# 1 0          0          0          0          0          0
# 2 0          0          0          0          0          0
# 3 0          0          0          0          0          0
# 4 0          0          0          0          0          0
# 5 0          0          0          0          0          0
# 6 1          0          0          0          0          0

# %%
ncol(data)
# Out:
# [1] 203

# %%
data_names <- c()
data_entropy <- c()

for (column in 1:ncol(data)) {
#    print(names(data[column]))
    entropy <- SpatEntropy::shannonX(data = matrix(data[column]))
  
  data_names <- append(x = data_names, values = names(data[column]))
  data_entropy <- append(x = data_entropy, values = entropy$shannon)
}

# %%
df_entropy <- cbind(data.frame(data_names, data_entropy)) 
head(df_entropy)
# Out:
#   data_names data_entropy
# 1 edad_jefe  4.115715
# 2 percep_ing 1.494721
# 3 perc_ocupa 1.376241
# 4 ing_cor    7.436011
# 5 ingtrab    6.675486
# 6 trabajo    6.080898

# %%
order_df_entropy <- df_entropy[order(df_entropy$data_entropy, decreasing = T), ]
head(order_df_entropy)
# Out:
#    data_names data_entropy
# 4  ing_cor    7.436011
# 36 gasto_mon  7.435709
# 71 transporte 7.215884
# 58 vivienda   7.166427
# 37 alimentos  7.153190
# 83 personales 7.066486

# %%
ggplot(df_entropy, aes(y=data_names, x=data_entropy)) + 
    theme_bw() +
    ggtitle('Entropía de las variables del data set con encoding ConcentradoHogar/ENIGH') + 
    xlab('Nats') +
    ylab("Variables")+
    theme(plot.title = element_text(hjust = 0.5))+
    geom_point()+
    ggsave(filename = "../../../../../../images/enigh/CONCENTRADOHOGAR/entropy_one_hot.png", dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
ggplot(data = data, 
       aes(y=data$ing_cor, 
           x=data$gasto_mon))+
    theme_bw() +
    ggtitle('Dos variables con mayor entropía del data set mixto ConcentradoHogar/ENIGH') + 
    xlab('Ingreso corriente') +
    ylab("Gasto corriente monetario")+
    theme(plot.title = element_text(hjust = 0.5))+
    geom_point()+
    ggsave(filename = "../../../../../../images/enigh/CONCENTRADOHOGAR/entropy_encoding_2_var.png", dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
png("../../../../../../images/enigh/CONCENTRADOHOGAR/entropy_encoding_3_var.png")
scatterplot3d(y=data$ing_cor, 
              x=data$gasto_mon,
              z=data$transporte, pch = 19, 
              color = "black", 
              main="Tres variables con mayor entropía del data set mixto ConcentradoHogar/ENIGH",
              xlab = 'Ingreso corriente', 
              ylab = 'Gasto corriente monetario',
              zlab = 'Gasto en transporte') 
dev.off()
# Out:
# pdf
#   2

# %%
file = '../../../../../../dataframes/enigh/CONCENTRADOHOGAR/df_entropy_encoding.csv'

# %%
write.csv(order_df_entropy, 
          file = file,
          row.names=FALSE)
