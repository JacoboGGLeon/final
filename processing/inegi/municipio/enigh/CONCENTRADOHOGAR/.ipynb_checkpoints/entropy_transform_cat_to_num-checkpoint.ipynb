# %%
library(SpatEntropy)
library(ggplot2)
library(stats)
library(factoextra)
library(clusterCrit)
library(scatterplot3d)
# Out:
# Loading required package: spatstat
# Loading required package: spatstat.data
# Loading required package: nlme
# Loading required package: rpart
#
# spatstat 1.58-2       (nickname: ‘Not Even Wrong’)
# For an introduction to spatstat, type ‘beginner’
#
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %%
file = '../../../../../../dataframes/enigh/CONCENTRADOHOGAR/mixed/df_transform_cat_to_num.csv'

# %%
df <- read.csv(file = file)
data <- df
head(data)
# Out:
#   tam_loc   est_socio clase_hog sexo_jefe edad_jefe educa_jefe tot_integ
# 1 0.9607617 0.8632429 0.8274668 0.6560877 0.2820513 0.5868436  0.2279284
# 2 0.9607617 0.8632429 0.9873053 0.6560877 0.8333333 0.5868436  0.8009233
# 3 0.9607617 0.8632429 0.5764570 1.0000000 0.3333333 0.5868436  0.4489325
# 4 0.9607617 0.8632429 0.9873053 0.6560877 0.3846154 0.4477784  0.8009233
# 5 0.9607617 0.8632429 0.9873053 0.6560877 0.7307692 0.4477784  0.8009233
# 6 0.9607617 0.8632429 0.8274668 0.6560877 0.5384615 0.7201385  0.9890364
#   hombres   mujeres   mayores   ⋯ cuota_viv mater_serv  material   servicio
# 1 0.4102712 0.8309290 0.5556838 ⋯ 0         0.000000000 0.00000000 0
# 2 0.4102712 0.9290248 0.9001731 ⋯ 0         0.000000000 0.00000000 0
# 3 0.6901327 0.3819965 0.3115984 ⋯ 0         0.000000000 0.00000000 0
# 4 0.4102712 0.9290248 0.9001731 ⋯ 0         0.000000000 0.00000000 0
# 5 0.4102712 0.9290248 0.9001731 ⋯ 0         0.000000000 0.00000000 0
# ...

# %%
ncol(data)
# Out:
# [1] 117

# %%
data_names <- c()
data_entropy <- c()

for (column in 1:ncol(data)) {
#    print(names(data[column]))
    entropy <- SpatEntropy::shannonX(data = matrix(data[column]))
  
  data_names <- append(x = data_names, values = names(data[column]))
  data_entropy <- append(x = data_entropy, values = entropy$shannon)
}

# %%
df_entropy <- cbind(data.frame(data_names, data_entropy)) 
head(df_entropy)
# Out:
#   data_names data_entropy
# 1 tam_loc    0.2054088
# 2 est_socio  1.0104823
# 3 clase_hog  1.0209569
# 4 sexo_jefe  0.6435964
# 5 edad_jefe  4.1157145
# 6 educa_jefe 2.0518012

# %%
order_df_entropy <- df_entropy[order(df_entropy$data_entropy, decreasing = T), ]
head(order_df_entropy)
# Out:
#    data_names data_entropy
# 17 ing_cor    7.436011
# 49 gasto_mon  7.435709
# 84 transporte 7.215884
# 71 vivienda   7.166427
# 50 alimentos  7.153190
# 96 personales 7.066486

# %%
ggplot(df_entropy, aes(y=data_names, x=data_entropy)) + 
    theme_bw() +
    ggtitle('Entropía de las variables del data set mixto ConcentradoHogar/ENIGH') + 
    xlab('Nats') +
    ylab("Variables")+
    theme(plot.title = element_text(hjust = 0.5))+
    geom_point()+
    ggsave(filename = "../../../../../../images/enigh/CONCENTRADOHOGAR/entropy_transform.png", dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
ggplot(data = data, 
       aes(y=data$ing_cor, 
           x=data$gasto_mon))+
    theme_bw() +
    ggtitle('Dos variables con mayor entropía del data set mixto ConcentradoHogar/ENIGH') + 
    xlab('Ingreso corriente') +
    ylab("Gasto corriente monetario")+
    theme(plot.title = element_text(hjust = 0.5))+
    geom_point()+
    ggsave(filename = "../../../../../../images/enigh/CONCENTRADOHOGAR/entropy_transform_2_var.png", dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
png("../../../../../../images/enigh/CONCENTRADOHOGAR/entropy_transform_3_var.png")
scatterplot3d(y=data$ing_cor, 
              x=data$gasto_mon,
              z=data$transporte, pch = 19, 
              color = "black", 
              main="Tres variables con mayor entropía del data set mixto ConcentradoHogar/ENIGH",
              xlab = 'Ingreso corriente', 
              ylab = 'Gasto corriente monetario',
              zlab = 'Gasto en transporte') 
dev.off()
# Out:
# pdf
#   2

# %%
file = '../../../../../../dataframes/enigh/CONCENTRADOHOGAR/mixed/df_entropy_tranform_cat_to_num.csv'

# %%
write.csv(order_df_entropy, 
          file = file,
          row.names=FALSE)
