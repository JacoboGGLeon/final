# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file = '../../../../../../dataframes/enigh/HOGARES/df_09.csv'

# %%
df = pd.read_csv(file)

# %%
df.shape
# Out:
# (1733, 136)

# %%
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#    huespedes huesp_come  num_trab_d trab_come  acc_alim1  acc_alim2  \
# 0          0                      0                    2          2
# 1          0                      0                    2          2
# 2          0                      0                    2          2
# 3          0                      0                    2          2
# 4          0                      0                    2          2
#
#    acc_alim3  acc_alim4  acc_alim5  acc_alim6  ... bene_licon cond_licon  \
# 0          2          2          2          2  ...          2
# 1          2          2          2          2  ...          2
# 2          2          2          2          2  ...          2
# 3          2          2          2          2  ...          2
# 4          2          2          2          2  ...          2
#
#   lts_licon otros_lts diconsa frec_dicon cond_dicon pago_dicon otro_pago  \
# 0                           1          3
# 1                           1          3
# 2                           1          2          1          2
# 3                           9
# 4                           2
#
#   CVE_MUN
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#
# [5 rows x 136 columns]

# %%
df_copy = df.copy()

# %%
df_copy.replace(to_replace=' ', value=np.NaN, inplace=True)

# %%
df_copy.replace(to_replace=np.NaN, value=-1, inplace=True)

# %%
l = []
bandera = np.NAN
for column in df_copy.columns:
    if df_copy[column].dtype == np.int64:
        bandera = 'entero'
    elif df_copy[column].dtype == np.float64:
        bandera = 'flotante'
    else:
        bandera = 'otro'
        
    try:
        df_copy[column] =df_copy[column].astype('int64')
    except:
        l.append(column)
        
    print('COLUMNA: ', column)
    print('TIPO: ', bandera)
    print('NUNIQUE: ', df_copy[column].nunique())
    print('UNIQUE: ', df_copy[column].unique())
    print('VALUE COUNTS ', df_copy[column].value_counts())
    print('\n')
# Out:
# COLUMNA:  huespedes
# TIPO:  entero
# NUNIQUE:  1
# UNIQUE:  [0]
# VALUE COUNTS  0    1733
# Name: huespedes, dtype: int64
#
#
# COLUMNA:  huesp_come
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [-1]
# VALUE COUNTS  -1    1733
# Name: huesp_come, dtype: int64
#
#
# COLUMNA:  num_trab_d
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    1717
# 1      14
# 2       2
# Name: num_trab_d, dtype: int64
#
#
# COLUMNA:  trab_come
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [-1  1  2  0]
# VALUE COUNTS  -1    1717
#  1      12
#  0       2
#  2       2
# Name: trab_come, dtype: int64
#
#
# COLUMNA:  acc_alim1
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1264
# 1     469
# Name: acc_alim1, dtype: int64
#
#
# COLUMNA:  acc_alim2
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1625
# 1     108
# Name: acc_alim2, dtype: int64
#
#
# COLUMNA:  acc_alim3
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1444
# 1     289
# Name: acc_alim3, dtype: int64
#
#
# COLUMNA:  acc_alim4
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1419
# 1     314
# Name: acc_alim4, dtype: int64
#
#
# COLUMNA:  acc_alim5
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1598
# 1     135
# Name: acc_alim5, dtype: int64
#
#
# COLUMNA:  acc_alim6
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1501
# 1     232
# Name: acc_alim6, dtype: int64
#
#
# COLUMNA:  acc_alim7
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  1  2]
# VALUE COUNTS  -1    1204
#  2     382
#  1     147
# Name: acc_alim7, dtype: int64
#
#
# COLUMNA:  acc_alim8
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  2  1]
# VALUE COUNTS  -1    1204
#  2     416
#  1     113
# Name: acc_alim8, dtype: int64
#
#
# COLUMNA:  acc_alim9
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  2  1]
# VALUE COUNTS  -1    1204
#  2     500
#  1      29
# Name: acc_alim9, dtype: int64
#
#
# COLUMNA:  acc_alim10
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  1  2]
# VALUE COUNTS  -1    1404
#  2     216
#  1     113
# Name: acc_alim10, dtype: int64
#
#
# COLUMNA:  acc_alim11
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  1  2]
# VALUE COUNTS  -1    1404
#  2     193
#  1     136
# Name: acc_alim11, dtype: int64
#
#
# COLUMNA:  acc_alim12
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  1  2]
# VALUE COUNTS  -1    1404
#  2     241
#  1      88
# Name: acc_alim12, dtype: int64
#
#
# COLUMNA:  acc_alim13
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  1  2]
# VALUE COUNTS  -1    1404
#  2     240
#  1      89
# Name: acc_alim13, dtype: int64
#
#
# COLUMNA:  acc_alim14
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  2  1]
# VALUE COUNTS  -1    1404
#  2     294
#  1      35
# Name: acc_alim14, dtype: int64
#
#
# COLUMNA:  acc_alim15
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  2  1]
# VALUE COUNTS  -1    1404
#  2     289
#  1      40
# Name: acc_alim15, dtype: int64
#
#
# COLUMNA:  acc_alim16
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  2  1]
# VALUE COUNTS  -1    1404
#  2     305
#  1      24
# Name: acc_alim16, dtype: int64
#
#
# COLUMNA:  alim17_1
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 4 3 1 5 2 0 6]
# VALUE COUNTS  7    1463
# 3      69
# 5      59
# 4      50
# 2      45
# 1      18
# 0      15
# 6      14
# Name: alim17_1, dtype: int64
#
#
# COLUMNA:  alim17_2
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [1 3 2 7 0 5 4 6]
# VALUE COUNTS  1    497
# 2    460
# 0    287
# 3    267
# 7    123
# 4     53
# 5     40
# 6      6
# Name: alim17_2, dtype: int64
#
#
# COLUMNA:  alim17_3
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [3 7 4 5 2 0 6 1]
# VALUE COUNTS  7    777
# 3    260
# 2    217
# 5    166
# 4    140
# 6     61
# 1     58
# 0     54
# Name: alim17_3, dtype: int64
#
#
# COLUMNA:  alim17_4
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [3 2 7 5 4 1 6 0]
# VALUE COUNTS  7    824
# 3    224
# 2    185
# 5    143
# 1    104
# 4    103
# 0     90
# 6     60
# Name: alim17_4, dtype: int64
#
#
# COLUMNA:  alim17_5
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [2 6 7 4 3 0 1 5]
# VALUE COUNTS  3    417
# 2    359
# 7    286
# 1    211
# 4    201
# 5    142
# 0     72
# 6     45
# Name: alim17_5, dtype: int64
#
#
# COLUMNA:  alim17_6
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 3 1 5 2 4 6 0]
# VALUE COUNTS  2    423
# 3    405
# 7    284
# 1    232
# 4    168
# 0    107
# 5     84
# 6     30
# Name: alim17_6, dtype: int64
#
#
# COLUMNA:  alim17_7
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [1 0 2 3 4 5 7 6]
# VALUE COUNTS  0    728
# 1    595
# 2    223
# 3    112
# 4     33
# 7     27
# 5      9
# 6      6
# Name: alim17_7, dtype: int64
#
#
# COLUMNA:  alim17_8
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [3 7 2 4 5 0 1 6]
# VALUE COUNTS  7    518
# 3    319
# 2    272
# 1    187
# 4    163
# 0    137
# 5    101
# 6     36
# Name: alim17_8, dtype: int64
#
#
# COLUMNA:  alim17_9
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [2 4 7 6 0 5 1 3]
# VALUE COUNTS  7    950
# 3    190
# 2    153
# 0    126
# 1     96
# 4     88
# 5     86
# 6     44
# Name: alim17_9, dtype: int64
#
#
# COLUMNA:  alim17_10
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 3 1 0 4 5 2 6]
# VALUE COUNTS  7    1462
# 3      62
# 0      45
# 2      44
# 5      41
# 4      36
# 1      29
# 6      14
# Name: alim17_10, dtype: int64
#
#
# COLUMNA:  alim17_11
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 0 6 3 5 1 2 4]
# VALUE COUNTS  7    1333
# 0      97
# 3      74
# 2      72
# 5      57
# 1      53
# 4      34
# 6      13
# Name: alim17_11, dtype: int64
#
#
# COLUMNA:  alim17_12
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 6 0 4 5 2 1 3]
# VALUE COUNTS  7    1323
# 0     105
# 3      81
# 2      63
# 5      59
# 4      41
# 1      39
# 6      22
# Name: alim17_12, dtype: int64
#
#
# COLUMNA:  acc_alim18
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 3 2]
# VALUE COUNTS  1    1672
# 3      46
# 2      15
# Name: acc_alim18, dtype: int64
#
#
# COLUMNA:  telefono
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    1165
# 2     568
# Name: telefono, dtype: int64
#
#
# COLUMNA:  celular
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    1485
# 2     248
# Name: celular, dtype: int64
#
#
# COLUMNA:  tv_paga
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  2    967
# 1    766
# Name: tv_paga, dtype: int64
#
#
# COLUMNA:  conex_inte
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    1042
# 2     691
# Name: conex_inte, dtype: int64
#
#
# COLUMNA:  num_auto
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 2 3 4]
# VALUE COUNTS  0    1142
# 1     490
# 2      86
# 3      13
# 4       2
# Name: num_auto, dtype: int64
#
#
# COLUMNA:  anio_auto
# TIPO:  otro
# NUNIQUE:  29
# UNIQUE:  [-1 10 15  0 13  8 96 14  1 75  9 16  2  6 11 98  7 12 95  4  5  3 99 97
#  88 94 80 91 93]
# VALUE COUNTS  -1     1142
#  15      93
#  14      81
#  13      66
#  12      53
#  10      47
#  16      47
#  11      32
#  8       27
#  9       25
#  6       23
#  5       17
#  7       16
#  4       13
#  0       11
#  2        8
#  98       7
#  3        5
#  1        5
#  96       3
#  99       3
#  95       2
#  75       1
#  80       1
#  88       1
#  91       1
#  93       1
#  94       1
#  97       1
# Name: anio_auto, dtype: int64
#
#
# COLUMNA:  num_van
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 3]
# VALUE COUNTS  0    1619
# 1     105
# 2       8
# 3       1
# Name: num_van, dtype: int64
#
#
# COLUMNA:  anio_van
# TIPO:  otro
# NUNIQUE:  19
# UNIQUE:  [-1 10 12  3 16 11 14  8  4 15  9 13  7  1 99 96  0  6  5]
# VALUE COUNTS  -1     1619
#  14      15
#  16      12
#  15      12
#  13      12
#  10      12
#  12       9
#  11       9
#  8        8
#  9        6
#  7        5
#  6        2
#  5        2
#  4        2
#  3        2
#  1        2
#  99       2
#  96       1
#  0        1
# Name: anio_van, dtype: int64
#
#
# COLUMNA:  num_pickup
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [0 1]
# VALUE COUNTS  0    1712
# 1      21
# Name: num_pickup, dtype: int64
#
#
# COLUMNA:  anio_pickup
# TIPO:  otro
# NUNIQUE:  16
# UNIQUE:  [-1 16 96 10  7 12 15 13  5  6  9 94 90 78 95 14]
# VALUE COUNTS  -1     1712
#  15       4
#  13       2
#  10       2
#  6        2
#  96       1
#  95       1
#  94       1
#  90       1
#  78       1
#  16       1
#  14       1
#  12       1
#  9        1
#  7        1
#  5        1
# Name: anio_pickup, dtype: int64
#
#
# COLUMNA:  num_moto
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    1683
# 1      48
# 2       2
# Name: num_moto, dtype: int64
#
#
# COLUMNA:  anio_moto
# TIPO:  otro
# NUNIQUE:  10
# UNIQUE:  [-1 13 14 16 15  8 10  7 11 12]
# VALUE COUNTS  -1     1683
#  14      12
#  15      10
#  16       9
#  13       8
#  10       6
#  8        2
#  12       1
#  11       1
#  7        1
# Name: anio_moto, dtype: int64
#
#
# COLUMNA:  num_bici
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 3]
# VALUE COUNTS  0    1614
# 1     100
# 2      14
# 3       5
# Name: num_bici, dtype: int64
#
#
# COLUMNA:  anio_bici
# TIPO:  otro
# NUNIQUE:  21
# UNIQUE:  [-1 11 13 12  6 10 14  9 15  3 16 96  0  8 99  2 84 70  4 94  5]
# VALUE COUNTS  -1     1614
#  15      17
#  10      16
#  13      15
#  16      14
#  14      13
#  6       10
#  11      10
#  12       7
#  96       3
#  0        3
#  8        2
#  70       1
#  84       1
#  9        1
#  94       1
#  5        1
#  4        1
#  3        1
#  2        1
#  99       1
# Name: anio_bici, dtype: int64
#
#
# COLUMNA:  num_trici
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [0 1]
# VALUE COUNTS  0    1730
# 1       3
# Name: num_trici, dtype: int64
#
#
# COLUMNA:  anio_trici
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [-1  6 16  9]
# VALUE COUNTS  -1     1730
#  16       1
#  9        1
#  6        1
# Name: anio_trici, dtype: int64
#
#
# COLUMNA:  num_carret
# TIPO:  entero
# NUNIQUE:  1
# UNIQUE:  [0]
# VALUE COUNTS  0    1733
# Name: num_carret, dtype: int64
#
#
# COLUMNA:  anio_carret
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [-1]
# VALUE COUNTS  -1    1733
# Name: anio_carret, dtype: int64
#
#
# COLUMNA:  num_canoa
# TIPO:  entero
# NUNIQUE:  1
# UNIQUE:  [0]
# VALUE COUNTS  0    1733
# Name: num_canoa, dtype: int64
#
#
# COLUMNA:  anio_canoa
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [-1]
# VALUE COUNTS  -1    1733
# Name: anio_canoa, dtype: int64
#
#
# COLUMNA:  num_otro
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [0 1]
# VALUE COUNTS  0    1732
# 1       1
# Name: num_otro, dtype: int64
#
#
# COLUMNA:  anio_otro
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1 14]
# VALUE COUNTS  -1     1732
#  14       1
# Name: anio_otro, dtype: int64
#
#
# COLUMNA:  num_ester
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [1 0 2 3]
# VALUE COUNTS  1    956
# 0    733
# 2     36
# 3      8
# Name: num_ester, dtype: int64
#
#
# COLUMNA:  anio_ester
# TIPO:  otro
# NUNIQUE:  36
# UNIQUE:  [ 6 -1 13 14 15 90  4 11 96 12 10  5  1 98 16  8  9  0 92 99 86 85  7  3
#   2 76 89 80 70 95 97 91 82 84 87 75]
# VALUE COUNTS  -1     733
#  6     117
#  11     98
#  10     97
#  13     90
#  12     84
#  14     72
#  8      71
#  15     50
#  1      48
#  0      44
#  9      43
#  5      27
#  16     24
#  4      19
#  3      16
#  7      16
#  96     15
#  2      11
#  86      9
#  90      9
#  98      8
#  99      6
#  95      6
#  76      4
#  97      3
#  91      2
#  85      2
#  89      2
#  92      1
#  87      1
#  75      1
#  84      1
#  82      1
#  80      1
#  70      1
# Name: anio_ester, dtype: int64
#
#
# COLUMNA:  num_grab
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    1418
# 1     311
# 2       4
# Name: num_grab, dtype: int64
#
#
# COLUMNA:  anio_grab
# TIPO:  otro
# NUNIQUE:  30
# UNIQUE:  [-1  5 12 94  3  6 10  9 90  7  1 15 13 14 95 11 99 91  4  0 96 16  8 86
#  80  2 98 82 76 97]
# VALUE COUNTS  -1     1418
#  6       46
#  10      30
#  11      27
#  8       24
#  12      22
#  14      20
#  13      19
#  15      17
#  0       16
#  1       14
#  96      14
#  9       10
#  3        9
#  16       9
#  5        7
#  2        6
#  4        5
#  80       3
#  94       3
#  7        2
#  98       2
#  95       2
#  97       2
#  90       1
#  99       1
#  76       1
#  82       1
#  86       1
#  91       1
# Name: anio_grab, dtype: int64
#
#
# COLUMNA:  num_radio
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 2 3 4]
# VALUE COUNTS  0    1407
# 1     310
# 2      12
# 3       3
# 4       1
# Name: num_radio, dtype: int64
#
#
# COLUMNA:  anio_radio
# TIPO:  otro
# NUNIQUE:  34
# UNIQUE:  [-1 96 15 11  6 10 13 90  8  0 14 16 12  1 92 86  5 95 98  9  4 97  2 87
#  99 80  3 70 66 76 88 91 93 84]
# VALUE COUNTS  -1     1407
#  6       39
#  0       32
#  11      32
#  10      20
#  14      20
#  96      19
#  12      19
#  16      18
#  15      18
#  13      15
#  1       15
#  9       10
#  8        9
#  86       6
#  2        6
#  5        6
#  95       6
#  90       5
#  3        4
#  80       3
#  76       3
#  98       3
#  99       3
#  97       3
#  4        2
#  66       2
#  91       2
#  84       1
#  92       1
#  88       1
#  87       1
#  70       1
#  93       1
# Name: anio_radio, dtype: int64
#
#
# COLUMNA:  num_tva
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [0 1 2 3 4 5]
# VALUE COUNTS  0    1070
# 1     560
# 2      80
# 3      17
# 4       5
# 5       1
# Name: num_tva, dtype: int64
#
#
# COLUMNA:  anio_tva
# TIPO:  otro
# NUNIQUE:  39
# UNIQUE:  [-1 '01' '06' '95' '13' '08' '10' '12' '96' '00' '14' '09' '07' '97' '11'
#  '92' '80' '90' '05' '86' '16' '98' '93' '15' '03' '89' '04' '02' '94'
#  '85' '81' '99' '79' '73' '78' '84' '&' '87' '91']
# VALUE COUNTS  -1    1070
# 06     115
# 00      70
# 01      55
# 08      45
# 96      42
# 10      37
# 09      28
# 14      26
# 04      25
# 05      24
# 11      24
# 02      19
# 13      19
# 12      17
# 15      16
# 03      13
# 99      11
# 07      11
# 16      10
# 90       8
# 98       8
# 86       6
# 95       5
# 97       5
# 93       4
# 94       3
# 80       3
# 81       2
# 85       2
# 89       2
# &        1
# 91       1
# 87       1
# 78       1
# 79       1
# 84       1
# 73       1
# 92       1
# Name: anio_tva, dtype: int64
#
#
# COLUMNA:  num_tvd
# TIPO:  entero
# NUNIQUE:  7
# UNIQUE:  [1 0 2 4 3 5 7]
# VALUE COUNTS  1    1003
# 0     323
# 2     290
# 3      94
# 4      17
# 5       5
# 7       1
# Name: num_tvd, dtype: int64
#
#
# COLUMNA:  anio_tvd
# TIPO:  otro
# NUNIQUE:  21
# UNIQUE:  [15 -1 13 14 16  0 12 11 10  9  8  7  6 98  1 96  5  2  3 90  4]
# VALUE COUNTS   15    462
# -1     323
#  14    272
#  13    213
#  12    102
#  11     99
#  16     85
#  10     65
#  9      32
#  8      24
#  6      21
#  7       6
#  1       6
#  5       5
#  0       5
#  3       4
#  98      3
#  4       2
#  2       2
#  90      1
#  96      1
# Name: anio_tvd, dtype: int64
#
#
# COLUMNA:  num_dvd
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [1 2 0 3 5]
# VALUE COUNTS  1    893
# 0    761
# 2     62
# 3     16
# 5      1
# Name: num_dvd, dtype: int64
#
#
# COLUMNA:  anio_dvd
# TIPO:  otro
# NUNIQUE:  22
# UNIQUE:  [13  6 14 15 10 -1  1  9  2 11 12 16  8 99  0  7 96  5  4  3 95 70]
# VALUE COUNTS  -1     761
#  14    167
#  13    137
#  15    127
#  12    120
#  10     89
#  11     73
#  6      72
#  16     45
#  9      45
#  8      35
#  0      12
#  1      11
#  5      10
#  2       7
#  4       6
#  7       5
#  3       5
#  96      3
#  70      1
#  95      1
#  99      1
# Name: anio_dvd, dtype: int64
#
#
# COLUMNA:  num_video
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    1597
# 1     129
# 2       7
# Name: num_video, dtype: int64
#
#
# COLUMNA:  anio_video
# TIPO:  otro
# NUNIQUE:  25
# UNIQUE:  [-1  5 95  3  7 99  8 10  0 11  1 12  4  6  9 96 13 90 91 15  2 98 14 94
#  87]
# VALUE COUNTS  -1     1597
#  6       16
#  0       15
#  96      13
#  1       10
#  12      10
#  8        7
#  14       7
#  10       7
#  11       6
#  3        5
#  5        5
#  9        5
#  95       4
#  98       4
#  13       3
#  90       3
#  2        3
#  99       2
#  91       2
#  15       2
#  7        2
#  4        2
#  94       2
#  87       1
# Name: anio_video, dtype: int64
#
#
# COLUMNA:  num_licua
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [1 0 2 4]
# VALUE COUNTS  1    1596
# 0     110
# 2      25
# 4       2
# Name: num_licua, dtype: int64
#
#
# COLUMNA:  anio_licua
# TIPO:  otro
# NUNIQUE:  40
# UNIQUE:  [10 11 14 12 13 15  6 94 16 -1  9  7 92  1  4  8  0 96  5 90 99 97 98 91
#   2 86 56 95  3 70 89 75 82 76 79 93 80 66 88 85]
# VALUE COUNTS   10    165
#  6     161
#  11    144
#  14    143
#  13    130
#  12    129
#  15    121
# -1     110
#  8      94
#  9      85
#  16     68
#  1      61
#  96     52
#  0      51
#  5      34
#  7      32
#  4      24
#  98     17
#  99     16
#  86     15
#  2      13
#  3      12
#  90     12
#  95      9
#  97      5
#  92      4
#  80      4
#  94      4
#  91      4
#  70      2
#  76      2
#  85      2
#  93      1
#  66      1
#  56      1
#  88      1
#  82      1
#  79      1
#  75      1
#  89      1
# Name: anio_licua, dtype: int64
#
#
# COLUMNA:  num_tosta
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 0 2]
# VALUE COUNTS  0    1365
# 1     367
# 2       1
# Name: num_tosta, dtype: int64
#
#
# COLUMNA:  anio_tosta
# TIPO:  otro
# NUNIQUE:  32
# UNIQUE:  [98 -1 15 10 14  6 13  2  9 16  7  0  8  1 96 12 89 92 11  3 91 85 99  5
#  80  4 66 81 76 68 93 95]
# VALUE COUNTS  -1     1365
#  6       44
#  10      38
#  12      35
#  13      32
#  14      30
#  11      25
#  9       24
#  8       22
#  15      18
#  96      16
#  0       14
#  16      10
#  1        9
#  98       8
#  5        7
#  7        7
#  2        4
#  3        4
#  99       4
#  92       3
#  4        2
#  93       2
#  76       2
#  95       1
#  80       1
#  91       1
#  89       1
#  85       1
#  66       1
#  68       1
#  81       1
# Name: anio_tosta, dtype: int64
#
#
# COLUMNA:  num_micro
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 0 2]
# VALUE COUNTS  1    1100
# 0     625
# 2       8
# Name: num_micro, dtype: int64
#
#
# COLUMNA:  anio_micro
# TIPO:  otro
# NUNIQUE:  33
# UNIQUE:  [11 12 14 10 -1 13 15  6  0  7 98  2  8  9  5  1 96 95 91  4 90 97 16 78
#  99  3 80 94 85 82 87 89 92]
# VALUE COUNTS  -1     625
#  10    131
#  6     129
#  12    107
#  14    106
#  11     98
#  8      90
#  13     75
#  15     70
#  9      47
#  1      33
#  0      31
#  16     30
#  5      26
#  7      22
#  3      20
#  4      20
#  2      15
#  96     13
#  98     10
#  95      7
#  90      6
#  97      5
#  99      4
#  94      3
#  91      3
#  85      1
#  92      1
#  89      1
#  78      1
#  80      1
#  82      1
#  87      1
# Name: anio_micro, dtype: int64
#
#
# COLUMNA:  num_refri
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [ 1  0  2 14]
# VALUE COUNTS  1     1574
# 0      151
# 2        7
# 14       1
# Name: num_refri, dtype: int64
#
#
# COLUMNA:  anio_refri
# TIPO:  otro
# NUNIQUE:  42
# UNIQUE:  [ 6 11 12 10 -1 96  8 95 14 13  4  1  9 87  5  7  2 16 97 94 15 89  0 92
#   3 76 98 93 86 99 91 80 75 90 84 66 83 70 85 88 78 52]
# VALUE COUNTS   6     181
#  10    152
# -1     151
#  11    119
#  1     111
#  12    102
#  14    100
#  13    100
#  9      85
#  8      81
#  15     80
#  0      73
#  96     52
#  4      47
#  7      41
#  5      38
#  16     37
#  2      24
#  3      22
#  95     17
#  99     16
#  98     16
#  86     14
#  90     14
#  97     13
#  91     13
#  92      9
#  94      4
#  80      3
#  89      3
#  70      2
#  84      2
#  85      2
#  78      1
#  93      1
#  87      1
#  88      1
#  76      1
#  83      1
#  52      1
#  66      1
#  75      1
# Name: anio_refri, dtype: int64
#
#
# COLUMNA:  num_estuf
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 0 2]
# VALUE COUNTS  1    1647
# 0      78
# 2       8
# Name: num_estuf, dtype: int64
#
#
# COLUMNA:  anio_estuf
# TIPO:  otro
# NUNIQUE:  46
# UNIQUE:  [ 7  6 12 10 -1 93 15  1  9  8 13 86  5 95  2 16  4 97 99 14 96 98 11  0
#  70 94 92 90 85 76  3 88 79 91 80 84 74 73 82 71 78 81 72 89 66 83]
# VALUE COUNTS   6     156
#  10    146
#  11    107
#  14    103
#  1     101
#  9      96
#  0      94
#  8      83
#  15     81
#  96     80
#  12     80
# -1      78
#  13     76
#  16     48
#  5      47
#  7      46
#  4      39
#  2      33
#  98     31
#  86     30
#  99     29
#  90     18
#  3      17
#  97     17
#  95     17
#  91     13
#  80     12
#  94      7
#  76      5
#  70      5
#  93      5
#  85      5
#  89      4
#  88      3
#  78      3
#  92      3
#  84      3
#  74      2
#  79      2
#  71      2
#  73      1
#  82      1
#  81      1
#  66      1
#  72      1
#  83      1
# Name: anio_estuf, dtype: int64
#
#
# COLUMNA:  num_lavad
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [1 0 2 5]
# VALUE COUNTS  1    1375
# 0     345
# 2      11
# 5       2
# Name: num_lavad, dtype: int64
#
#
# COLUMNA:  anio_lavad
# TIPO:  otro
# NUNIQUE:  33
# UNIQUE:  [ 9  6 14 13 -1  1 96 15 12  7  8 16  5 90 99  3  2 10 11  0  4 92 94 98
#  97 80 91 95 86 82 81 79 85]
# VALUE COUNTS  -1     345
#  10    144
#  6     134
#  14    130
#  11    114
#  12    106
#  13    105
#  15     90
#  8      86
#  1      65
#  0      62
#  9      60
#  16     49
#  7      38
#  4      36
#  96     35
#  2      31
#  5      31
#  99     12
#  3      11
#  98     10
#  80      8
#  90      7
#  95      6
#  97      4
#  94      3
#  91      3
#  92      2
#  86      2
#  85      1
#  82      1
#  79      1
#  81      1
# Name: anio_lavad, dtype: int64
#
#
# COLUMNA:  num_planc
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [1 0 2 3 5]
# VALUE COUNTS  1    1492
# 0     187
# 2      47
# 3       6
# 5       1
# Name: num_planc, dtype: int64
#
#
# COLUMNA:  anio_planc
# TIPO:  otro
# NUNIQUE:  35
# UNIQUE:  [14 11 15 -1  1 16  9 12  5 13  2 10 98  8  7  4  0 91  6 96 90 94  3 86
#  95 79 92 80 88 99 78 57 84 85 76]
# VALUE COUNTS   15    214
#  14    189
# -1     187
#  13    176
#  12    143
#  11    130
#  16    115
#  10    112
#  6      97
#  9      73
#  8      66
#  0      37
#  1      36
#  2      22
#  96     19
#  7      18
#  4      16
#  5      16
#  98     11
#  3       8
#  99      8
#  86      7
#  90      7
#  91      5
#  80      4
#  94      4
#  95      3
#  79      2
#  85      2
#  76      1
#  78      1
#  84      1
#  88      1
#  92      1
#  57      1
# Name: anio_planc, dtype: int64
#
#
# COLUMNA:  num_maqui
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 4]
# VALUE COUNTS  0    1498
# 1     230
# 2       4
# 4       1
# Name: num_maqui, dtype: int64
#
#
# COLUMNA:  anio_maqui
# TIPO:  otro
# NUNIQUE:  50
# UNIQUE:  [-1 '85' '09' '12' '80' '99' '06' '10' '08' '01' '90' '07' '96' '15' '72'
#  '76' '75' '02' '94' '13' '98' '16' '11' '84' '14' '86' '73' '66' '04'
#  '81' '95' '69' '70' '55' '03' '79' '00' '60' '97' '88' '65' '56' '91'
#  '57' '83' '&' '89' '05' '71' '92']
# VALUE COUNTS  -1    1498
# 96      15
# 06      15
# 86      15
# 01      13
# 76      12
# 10      11
# 13      11
# 90       9
# 12       9
# 14       9
# 04       8
# 09       8
# 11       8
# 00       7
# 80       6
# 95       6
# 15       5
# 16       5
# 08       5
# 85       4
# 94       4
# 98       4
# 70       4
# 81       3
# 66       3
# 02       3
# 05       2
# 03       2
# 73       2
# 60       2
# 84       2
# 71       2
# 99       2
# 91       2
# 69       2
# 56       2
# 75       1
# 55       1
# 79       1
# 83       1
# 88       1
# 97       1
# 92       1
# 07       1
# 89       1
# 65       1
# &        1
# 57       1
# 72       1
# Name: anio_maqui, dtype: int64
#
#
# COLUMNA:  num_venti
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 2 3 4]
# VALUE COUNTS  0    1349
# 1     348
# 2      25
# 3       7
# 4       4
# Name: num_venti, dtype: int64
#
#
# COLUMNA:  anio_venti
# TIPO:  otro
# NUNIQUE:  30
# UNIQUE:  [-1 11 14 15 12 13  8  1 10  9  7 89  0  2  6 16 86  4 98 96 93 80 91  5
#  95 90 99 97 75 85]
# VALUE COUNTS  -1     1349
#  14      46
#  13      37
#  6       36
#  11      35
#  12      33
#  10      30
#  15      30
#  9       22
#  8       21
#  16      18
#  1       15
#  0       15
#  4        7
#  2        5
#  5        5
#  98       5
#  7        4
#  96       4
#  95       3
#  90       3
#  93       2
#  89       1
#  97       1
#  91       1
#  99       1
#  75       1
#  80       1
#  85       1
#  86       1
# Name: anio_venti, dtype: int64
#
#
# COLUMNA:  num_aspir
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 6]
# VALUE COUNTS  0    1452
# 1     277
# 2       3
# 6       1
# Name: num_aspir, dtype: int64
#
#
# COLUMNA:  anio_aspir
# TIPO:  otro
# NUNIQUE:  29
# UNIQUE:  [-1 10  0  7 98 11 14  1  9 13 95  8 12  2  6 16 15 75 99  5 70 85  4 91
#  80 82 96 94 88]
# VALUE COUNTS  -1     1452
#  12      36
#  14      28
#  13      26
#  10      24
#  8       22
#  6       21
#  15      21
#  11      18
#  9       15
#  1       14
#  0       11
#  16      10
#  7        7
#  4        4
#  99       3
#  5        3
#  98       3
#  96       3
#  2        2
#  95       2
#  75       1
#  80       1
#  70       1
#  82       1
#  94       1
#  91       1
#  88       1
#  85       1
# Name: anio_aspir, dtype: int64
#
#
# COLUMNA:  num_compu
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [1 0 2 3 5 8 4 7]
# VALUE COUNTS  0    896
# 1    689
# 2     97
# 3     41
# 5      4
# 4      3
# 8      2
# 7      1
# Name: num_compu, dtype: int64
#
#
# COLUMNA:  anio_compu
# TIPO:  otro
# NUNIQUE:  25
# UNIQUE:  [15 -1 16 11 12  8 14 13  1  9 10  3  0 86  6 99 98  7 96  4  5 91 88  2
#  95]
# VALUE COUNTS  -1     896
#  14    141
#  15    136
#  13    119
#  12     86
#  11     79
#  10     73
#  16     48
#  6      35
#  8      34
#  9      23
#  0      12
#  7      10
#  5       9
#  1       8
#  4       8
#  3       5
#  96      3
#  98      2
#  91      1
#  88      1
#  99      1
#  95      1
#  86      1
#  2       1
# Name: anio_compu, dtype: int64
#
#
# COLUMNA:  num_impre
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 3]
# VALUE COUNTS  0    1292
# 1     428
# 2      10
# 3       3
# Name: num_impre, dtype: int64
#
#
# COLUMNA:  anio_impre
# TIPO:  otro
# NUNIQUE:  19
# UNIQUE:  [-1 14 15 16 11  9 12 13 10  6  8  7  4  5 98  1  2  0  3]
# VALUE COUNTS  -1     1292
#  15      88
#  14      72
#  13      63
#  12      46
#  10      38
#  11      35
#  16      33
#  8       14
#  6       10
#  9       10
#  7        9
#  4        7
#  1        5
#  0        4
#  3        3
#  5        2
#  98       1
#  2        1
# Name: anio_impre, dtype: int64
#
#
# COLUMNA:  num_juego
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 3 2 4]
# VALUE COUNTS  0    1452
# 1     247
# 2      20
# 3      11
# 4       3
# Name: num_juego, dtype: int64
#
#
# COLUMNA:  anio_juego
# TIPO:  otro
# NUNIQUE:  20
# UNIQUE:  [-1 14 15  9 13 16 10 11  1  6  8  2  5 12  0 85  3  4  7 96]
# VALUE COUNTS  -1     1452
#  15      56
#  14      50
#  13      40
#  11      26
#  16      25
#  12      17
#  10      16
#  8       11
#  9       11
#  6        8
#  1        5
#  5        4
#  7        2
#  4        2
#  0        2
#  2        2
#  3        2
#  96       1
#  85       1
# Name: anio_juego, dtype: int64
#
#
# COLUMNA:  esc_radio
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    1066
# 2     667
# Name: esc_radio, dtype: int64
#
#
# COLUMNA:  er_aparato
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [ 1 -1]
# VALUE COUNTS   1    950
# -1    783
# Name: er_aparato, dtype: int64
#
#
# COLUMNA:  er_celular
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  2]
# VALUE COUNTS  -1    1606
#  2     127
# Name: er_celular, dtype: int64
#
#
# COLUMNA:  er_compu
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  3]
# VALUE COUNTS  -1    1708
#  3      25
# Name: er_compu, dtype: int64
#
#
# COLUMNA:  er_aplicac
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  4]
# VALUE COUNTS  -1    1722
#  4      11
# Name: er_aplicac, dtype: int64
#
#
# COLUMNA:  er_tv
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  5]
# VALUE COUNTS  -1    1724
#  5       9
# Name: er_tv, dtype: int64
#
#
# COLUMNA:  er_otro
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  6]
# VALUE COUNTS  -1    1707
#  6      26
# Name: er_otro, dtype: int64
#
#
# COLUMNA:  recib_tvd
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [ 2 -1  1]
# VALUE COUNTS  -1    1186
#  2     313
#  1     234
# Name: recib_tvd, dtype: int64
#
#
# COLUMNA:  tsalud1_h
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 2 3 6]
# VALUE COUNTS  0    1377
# 1     305
# 2      46
# 3       3
# 6       2
# Name: tsalud1_h, dtype: int64
#
#
# COLUMNA:  tsalud1_m
# TIPO:  entero
# NUNIQUE:  20
# UNIQUE:  [30 20 15 10 45 40  5  2 25 55 35 50  0 18  7 13 59  3 33 23]
# VALUE COUNTS  30    470
# 0     275
# 20    270
# 15    169
# 10    161
# 40    136
# 5      77
# 45     74
# 25     45
# 50     24
# 35     14
# 2       3
# 7       3
# 59      3
# 55      3
# 3       2
# 13      1
# 23      1
# 33      1
# 18      1
# Name: tsalud1_m, dtype: int64
#
#
# COLUMNA:  habito_1
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  1]
# VALUE COUNTS  -1    1337
#  1     396
# Name: habito_1, dtype: int64
#
#
# COLUMNA:  habito_2
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  2]
# VALUE COUNTS  -1    1314
#  2     419
# Name: habito_2, dtype: int64
#
#
# COLUMNA:  habito_3
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  3]
# VALUE COUNTS  -1    1188
#  3     545
# Name: habito_3, dtype: int64
#
#
# COLUMNA:  habito_4
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [ 4 -1]
# VALUE COUNTS  -1    1553
#  4     180
# Name: habito_4, dtype: int64
#
#
# COLUMNA:  habito_5
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  5]
# VALUE COUNTS  -1    1050
#  5     683
# Name: habito_5, dtype: int64
#
#
# COLUMNA:  habito_6
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  6]
# VALUE COUNTS  -1    1667
#  6      66
# Name: habito_6, dtype: int64
#
#
# COLUMNA:  consumo
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  2  1]
# VALUE COUNTS   2    745
# -1    497
#  1    491
# Name: consumo, dtype: int64
#
#
# COLUMNA:  nr_viv
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1  1]
# VALUE COUNTS  -1    1731
#  1       2
# Name: nr_viv, dtype: int64
#
#
# COLUMNA:  tarjeta
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1151
# 1     582
# Name: tarjeta, dtype: int64
#
#
# COLUMNA:  pagotarjet
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1426
# 1     307
# Name: pagotarjet, dtype: int64
#
#
# COLUMNA:  regalotar
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1647
# 1      86
# Name: regalotar, dtype: int64
#
#
# COLUMNA:  regalodado
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1590
# 1     143
# Name: regalodado, dtype: int64
#
#
# COLUMNA:  autocons
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1648
# 1      85
# Name: autocons, dtype: int64
#
#
# COLUMNA:  regalos
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    930
# 2    803
# Name: regalos, dtype: int64
#
#
# COLUMNA:  remunera
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1483
# 1     250
# Name: remunera, dtype: int64
#
#
# COLUMNA:  transferen
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1207
# 1     526
# Name: transferen, dtype: int64
#
#
# COLUMNA:  parto_g
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1729
# 1       4
# Name: parto_g, dtype: int64
#
#
# COLUMNA:  embarazo_g
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1713
# 1      20
# Name: embarazo_g, dtype: int64
#
#
# COLUMNA:  negcua
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1665
# 1      68
# Name: negcua, dtype: int64
#
#
# COLUMNA:  est_alim
# TIPO:  entero
# NUNIQUE:  224
# UNIQUE:  [ 2100   900  1700  1200  3100  3300  2500  2300   600  1800  6000  2120
#   2800  7000  3390  2900  3150  2400  1600  1000   800  3000  4000  3500
#   8700 35000  5360  2600  2200  4300  4500  5500  8000  5000  5900 10000
#   4900  5300  2820  4400  7600  4200  6500  6900  1400  3160  5200 10500
#   7200 20000  9000  4600  6600  3700  1450  3600  4800  5100  4100 12400
#   4710  1500  1090  7500  3900  5700  8800 12000  3800  4700     0  6800
#   5600  8500  3200  2000  1900  4020  3356  2296  2270  1950  3080  4250
#   3400  6550  5250  4090 11000  8200  2570 11800  2848  4390  6720  4884
#   3698 14150  6100  4076  5392  6650  4350  8900  1520  6200  1960  2700
#   5400  2280 16000  7100  8750  8680  7840  9900   700  5950  1920  5580
#   2240  2950  3950  4096  2250  3580  1220  5560  6300  3780  6360  7800
#   1050  5050  7700  9500  4950  6700  3360  2550  5800  5792  4240  2160
#   4560  8600  1660  2840  6850  4828  1826  5150 11080  3920   750  2088
#    200   450   500   560  1300  3550  1710  1150  8400   400   300  3750
#   1650  8100  4414  1480  6545  3050  1350  5760   100  1460  8050  6150
#   1100 12500  9576  4360 12300  2480  3820  3076 22000  7300  3280  2650
#   2940 15500  5820  2050  5550  3350 10800  6400   650 16500  3825  5135
#   3320  2350  3850  1084  9320 11500 14000  9100  2620  6050  7050  5420
#  24000 19000  9600  1215  2150  2648 14300  3670]
# VALUE COUNTS  3000     115
# 4000      91
# 2500      90
# 2000      77
# 3500      71
# 5000      68
# 4500      68
# 6000      56
# 1500      46
# 2800      41
# 5500      34
# 7000      30
# 4300      30
# 1000      29
# 3600      27
# 3200      26
# 3800      26
# 1800      26
# 1200      24
# 2400      23
# 8000      23
# 2200      22
# 4200      20
# 6500      20
# 2300      20
# 3700      19
# 1600      18
# 1400      16
# 2600      16
# 3400      16
#         ...
# 2848       1
# 4950       1
# 5760       1
# 11080      1
# 22000      1
# 2840       1
# 4884       1
# 2820       1
# 750        1
# 4828       1
# 5135       1
# 1084       1
# 1090       1
# 9320       1
# 1350       1
# 3390       1
# 5420       1
# 3356       1
# 5392       1
# 3320       1
# 5360       1
# 11500      1
# 3280       1
# 1220       1
# 1215       1
# 15500      1
# 7300       1
# 5250       1
# 1150       1
# 3080       1
# Name: est_alim, Length: 224, dtype: int64
#
#
# COLUMNA:  est_trans
# TIPO:  otro
# NUNIQUE:  87
# UNIQUE:  [ 700   20  350  300 2400  800  290  250  500 1300   60   -1  600 1000
#   750  100    0 1100 2000 1200  200  280  560 2300  900 1600  630  400
#   480 1150 2500 1500  260   50  160  645  150 1700 3000 1400  360  240
#   450  420  720 4160  220  192  650   30 1800  850 1950  120   40 1040
#  4960 1840 2100 3200  440 3300 1680  128 3500 2200   24   80  135  610
#  2320  460 1120  320 1480  352  164  340  550 2900  840  520  170  950
#   380 4000 2700]
# VALUE COUNTS   0       219
#  500     183
#  1000    138
#  200     122
#  300     117
#  600      98
#  100      90
#  400      89
#  800      89
#  1500     57
#  1200     46
#  700      42
#  2000     41
#  250      38
#  50       30
# -1        29
#  900      25
#  150      23
#  350      17
#  1300     17
#  1100     16
#  3000     14
#  1600     13
#  1400     13
#  2500     12
#  450      11
#  480      11
#  240       9
#  1800      8
#  650       8
#         ...
#  352       1
#  1840      1
#  950       1
#  3300      1
#  4960      1
#  1040      1
#  4160      1
#  2900      1
#  24        1
#  1120      1
#  1950      1
#  128       1
#  135       1
#  380       1
#  2700      1
#  2400      1
#  164       1
#  170       1
#  610       1
#  550       1
#  520       1
#  2300      1
#  2320      1
#  460       1
#  290       1
#  440       1
#  320       1
#  340       1
#  1480      1
#  645       1
# Name: est_trans, Length: 87, dtype: int64
#
#
# COLUMNA:  bene_licon
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  2    1539
# 1     194
# Name: bene_licon, dtype: int64
#
#
# COLUMNA:  cond_licon
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  2  1]
# VALUE COUNTS  -1    1539
#  2     188
#  1       6
# Name: cond_licon, dtype: int64
#
#
# COLUMNA:  lts_licon
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  [-1  2  1  3  5  4  7]
# VALUE COUNTS  -1    1539
#  2      85
#  1      72
#  3      30
#  5       3
#  4       3
#  7       1
# Name: lts_licon, dtype: int64
#
#
# COLUMNA:  otros_lts
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [-1 18]
# VALUE COUNTS  -1     1732
#  18       1
# Name: otros_lts, dtype: int64
#
#
# COLUMNA:  diconsa
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 9 2]
# VALUE COUNTS  2    1015
# 9     372
# 1     346
# Name: diconsa, dtype: int64
#
#
# COLUMNA:  frec_dicon
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [ 3  2 -1  1]
# VALUE COUNTS  -1    1387
#  3     294
#  2      49
#  1       3
# Name: frec_dicon, dtype: int64
#
#
# COLUMNA:  cond_dicon
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [-1  1  2]
# VALUE COUNTS  -1    1681
#  2      47
#  1       5
# Name: cond_dicon, dtype: int64
#
#
# COLUMNA:  pago_dicon
# TIPO:  otro
# NUNIQUE:  6
# UNIQUE:  [-1  2  1  5  7  3]
# VALUE COUNTS  -1    1681
#  1      25
#  7      15
#  2       9
#  3       2
#  5       1
# Name: pago_dicon, dtype: int64
#
#
# COLUMNA:  otro_pago
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  [ -1  15  20  10  22 300  30]
# VALUE COUNTS  -1      1718
#  20        7
#  15        4
#  300       1
#  30        1
#  22        1
#  10        1
# Name: otro_pago, dtype: int64
#
#
# COLUMNA:  CVE_MUN
# TIPO:  entero
# NUNIQUE:  16
# UNIQUE:  [ 2  3  4  5  6  7  8 10 11 12 13 14 15 16 17  9]
# VALUE COUNTS  7     292
# 15    222
# 5     187
# 12    130
# 10    123
# 17    114
# 14     98
# 3      88
# 6      87
# 13     81
# 2      78
# 11     76
# 16     74
# 4      42
# 8      23
# 9      18
# Name: CVE_MUN, dtype: int64

# %%
l
# Out:
# ['anio_tva', 'anio_maqui']

# %%
threshold = round(df_copy.shape[0]*.8)
threshold
# Out:
# 1386

# %%
l = []
for column in df_copy.columns:
    na_column =  df_copy[column].value_counts().get(-1)
    if(na_column != None):
        if (df_copy.shape[0] - na_column < threshold):
            print(column, ': ', df_copy.shape[0] - na_column, ' - ', threshold)
            print(column, 'd e l e t e d')
            l.append(column)
# Out:
# huesp_come :  0  -  1386
# huesp_come d e l e t e d
# trab_come :  16  -  1386
# trab_come d e l e t e d
# acc_alim7 :  529  -  1386
# acc_alim7 d e l e t e d
# acc_alim8 :  529  -  1386
# acc_alim8 d e l e t e d
# acc_alim9 :  529  -  1386
# acc_alim9 d e l e t e d
# acc_alim10 :  329  -  1386
# acc_alim10 d e l e t e d
# acc_alim11 :  329  -  1386
# acc_alim11 d e l e t e d
# acc_alim12 :  329  -  1386
# acc_alim12 d e l e t e d
# acc_alim13 :  329  -  1386
# acc_alim13 d e l e t e d
# acc_alim14 :  329  -  1386
# acc_alim14 d e l e t e d
# acc_alim15 :  329  -  1386
# acc_alim15 d e l e t e d
# acc_alim16 :  329  -  1386
# acc_alim16 d e l e t e d
# anio_auto :  591  -  1386
# anio_auto d e l e t e d
# anio_van :  114  -  1386
# anio_van d e l e t e d
# anio_pickup :  21  -  1386
# anio_pickup d e l e t e d
# anio_moto :  50  -  1386
# anio_moto d e l e t e d
# anio_bici :  119  -  1386
# anio_bici d e l e t e d
# anio_trici :  3  -  1386
# anio_trici d e l e t e d
# anio_carret :  0  -  1386
# anio_carret d e l e t e d
# anio_canoa :  0  -  1386
# anio_canoa d e l e t e d
# anio_otro :  1  -  1386
# anio_otro d e l e t e d
# anio_ester :  1000  -  1386
# anio_ester d e l e t e d
# anio_grab :  315  -  1386
# anio_grab d e l e t e d
# anio_radio :  326  -  1386
# anio_radio d e l e t e d
# anio_tva :  663  -  1386
# anio_tva d e l e t e d
# anio_dvd :  972  -  1386
# anio_dvd d e l e t e d
# anio_video :  136  -  1386
# anio_video d e l e t e d
# anio_tosta :  368  -  1386
# anio_tosta d e l e t e d
# anio_micro :  1108  -  1386
# anio_micro d e l e t e d
# anio_maqui :  235  -  1386
# anio_maqui d e l e t e d
# anio_venti :  384  -  1386
# anio_venti d e l e t e d
# anio_aspir :  281  -  1386
# anio_aspir d e l e t e d
# anio_compu :  837  -  1386
# anio_compu d e l e t e d
# anio_impre :  441  -  1386
# anio_impre d e l e t e d
# anio_juego :  281  -  1386
# anio_juego d e l e t e d
# er_aparato :  950  -  1386
# er_aparato d e l e t e d
# er_celular :  127  -  1386
# er_celular d e l e t e d
# er_compu :  25  -  1386
# er_compu d e l e t e d
# er_aplicac :  11  -  1386
# er_aplicac d e l e t e d
# er_tv :  9  -  1386
# er_tv d e l e t e d
# er_otro :  26  -  1386
# er_otro d e l e t e d
# recib_tvd :  547  -  1386
# recib_tvd d e l e t e d
# habito_1 :  396  -  1386
# habito_1 d e l e t e d
# habito_2 :  419  -  1386
# habito_2 d e l e t e d
# habito_3 :  545  -  1386
# habito_3 d e l e t e d
# habito_4 :  180  -  1386
# habito_4 d e l e t e d
# habito_5 :  683  -  1386
# habito_5 d e l e t e d
# habito_6 :  66  -  1386
# habito_6 d e l e t e d
# consumo :  1236  -  1386
# consumo d e l e t e d
# nr_viv :  2  -  1386
# nr_viv d e l e t e d
# cond_licon :  194  -  1386
# cond_licon d e l e t e d
# lts_licon :  194  -  1386
# lts_licon d e l e t e d
# otros_lts :  1  -  1386
# otros_lts d e l e t e d
# frec_dicon :  346  -  1386
# frec_dicon d e l e t e d
# cond_dicon :  52  -  1386
# cond_dicon d e l e t e d
# pago_dicon :  52  -  1386
# pago_dicon d e l e t e d
# otro_pago :  15  -  1386
# otro_pago d e l e t e d

# %%
df_copy.drop(labels=l, axis=1, inplace=True)

# %%
df_copy.shape
# Out:
# (1733, 79)

# %%
df_copy.replace(to_replace=-1, value=np.NaN, inplace=True)

# %%
msno.matrix(df_copy, fontsize=50, sparkline=False, labels=False)
plt.xlabel('Columnas', fontsize=20)
plt.ylabel('Observaciones', fontsize=20)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09.png', dpi=300)
# Out:
# Text(0, 0.5, 'Observaciones')

# %%
msno.bar(df_copy, fontsize=10, labels=False)
plt.xlabel('Columnas', fontsize=20)
plt.ylabel('Observaciones', fontsize=20)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09.png', dpi=300)
# Out:
# Text(0, 0.5, 'Observaciones')

# %%
file = '../../../../../../dataframes/enigh/HOGARES/df_09_clean.csv'

# %%
df_copy.to_csv(file,index = False, header = True, sep = ',', encoding = 'utf-8')
