# %%
library(SpatEntropy)
library(ggplot2)
library(stats)
library(factoextra)
library(clusterCrit)
library(scatterplot3d)
# Out:
# Loading required package: spatstat
# Loading required package: spatstat.data
# Loading required package: nlme
# Loading required package: rpart
#
# spatstat 1.58-2       (nickname: ‘Not Even Wrong’)
# For an introduction to spatstat, type ‘beginner’
#
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %%
file = '../../../../../../dataframes/enigh/HOGARES/df_transform_cat_to_num.csv'

# %%
df <- read.csv(file = file)
data <- df
head(data)
# Out:
#   num_trab_d acc_alim1 acc_alim2 acc_alim3 acc_alim4 acc_alim5 acc_alim6
# 1 0.9907675  0.729371  0.9376803 0.8332372 0.8188113 0.9221004 0.8661281
# 2 0.9907675  0.729371  0.9376803 0.8332372 0.8188113 0.9221004 0.8661281
# 3 0.9907675  0.729371  0.9376803 0.8332372 0.8188113 0.9221004 0.8661281
# 4 0.9907675  0.729371  0.9376803 0.8332372 0.8188113 0.9221004 0.8661281
# 5 0.9907675  0.729371  0.9376803 0.8332372 0.8188113 0.9221004 0.8661281
# 6 0.9907675  0.729371  0.9376803 0.8332372 0.8188113 0.9221004 0.8661281
#   alim17_1  alim17_2  alim17_3  ⋯ regalos   remunera  transferen parto_g
# 1 1.0000000 0.1428571 0.4285714 ⋯ 0.5366417 0.8557415 0.6964801  0.9976919
# 2 1.0000000 0.4285714 0.4285714 ⋯ 0.5366417 0.8557415 1.0000000  0.9976919
# 3 0.5714286 0.2857143 1.0000000 ⋯ 0.5366417 0.8557415 0.6964801  0.9976919
# 4 0.4285714 0.1428571 0.5714286 ⋯ 1.0000000 1.0000000 0.6964801  0.9976919
# 5 1.0000000 1.0000000 1.0000000 ⋯ 0.5366417 0.8557415 1.0000000  0.9976919
# 6 1.0000000 0.1428571 1.0000000 ⋯ 1.0000000 0.8557415 0.6964801  0.9976919
#   embarazo_g negcua    est_alim   est_trans   bene_licon diconsa
# 1 0.9884593  0.9607617 0.06000000 0.141129032 0.8880554  1.0000000
# 2 0.9884593  0.9607617 0.02571429 0.004032258 0.8880554  1.0000000
# 3 0.9884593  0.9607617 0.04857143 0.070564516 0.8880554  1.0000000
# 4 0.9884593  0.9607617 0.03428571 0.060483871 0.8880554  0.8003462
# 5 0.9884593  0.9607617 0.08857143 0.060483871 0.8880554  0.5856896
# 6 0.9884593  1.0000000 0.09428571 0.483870968 0.8880554  1.0000000

# %%
ncol(data)
# Out:
# [1] 77

# %%
data_names <- c()
data_entropy <- c()

for (column in 1:ncol(data)) {
#    print(names(data[column]))
    entropy <- SpatEntropy::shannonX(data = matrix(data[column]))
  
  data_names <- append(x = data_names, values = names(data[column]))
  data_entropy <- append(x = data_entropy, values = entropy$shannon)
}

# %%
df_entropy <- cbind(data.frame(data_names, data_entropy)) 
head(df_entropy)
# Out:
#   data_names data_entropy
# 1 num_trab_d 0.0559230
# 2 acc_alim1  0.5838834
# 3 acc_alim2  0.2333031
# 4 acc_alim3  0.4507160
# 5 acc_alim4  0.4731912
# 6 acc_alim5  0.2736092

# %%
order_df_entropy <- df_entropy[order(df_entropy$data_entropy, decreasing = T), ]
head(order_df_entropy)
# Out:
#    data_names data_entropy
# 74 est_alim   4.319120
# 75 est_trans  3.310052
# 49 anio_estuf 3.282109
# 47 anio_refri 3.204282
# 51 anio_lavad 3.111690
# 43 anio_licua 3.033139

# %%
ggplot(df_entropy, aes(y=data_names, x=data_entropy)) + 
    theme_bw() +
    ggtitle('Entropía del conjunto de datos Hogares de la ENIGH') + 
    xlab('Nats') +
    ylab("Variables")+
    theme(plot.title = element_text(hjust = 0.5))+
    geom_point()+
    ggsave(filename = "../../../../../../images/enigh/HOGARES/entropy_transform.png", dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
ggplot(data = data, 
       aes(y=data$est_alim, 
           x=data$est_trans))+
    theme_bw() +
    ggtitle('Dos variables con mayor entropía del data set transformado Hogares/ENIGH') + 
    xlab('est_trans') +
    ylab("est_alim")+
    theme(plot.title = element_text(hjust = 0.5))+
    geom_point()+
    ggsave(filename = "../../../../../../images/enigh/HOGARES/entropy_transform_2_var.png", dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
png("../../../../../../images/enigh/HOGARES/entropy_transform_3_var.png")
scatterplot3d(y=data$est_alim, 
              x=data$est_trans,
              z=data$anio_estuf, pch = 19, 
              color = "black", 
              main="Tres variables con mayor entropía en Hogares de la ENIGH",
              xlab = 'est_alim', 
              ylab = 'est_trans',
              zlab = 'anio_estuf') 
dev.off()
# Out:
# pdf
#   2

# %%
file = '../../../../../../dataframes/enigh/HOGARES/df_entropy_tranform_cat_to_num.csv'

# %%
write.csv(order_df_entropy, 
          file = file,
          row.names=FALSE)
