# %%
library(SpatEntropy)
library(ggplot2)
library(stats)
library(factoextra)
library(clusterCrit)
library(scatterplot3d)
# Out:
# Loading required package: spatstat
# Loading required package: spatstat.data
# Loading required package: nlme
# Loading required package: rpart
#
# spatstat 1.58-2       (nickname: ‘Not Even Wrong’)
# For an introduction to spatstat, type ‘beginner’
#
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %%
file = '../../../../../../dataframes/enigh/HOGARES/df_09_impute.csv'

# %%
df <- read.csv(file = file)
data <- df
head(data)
# Out:
#   num_trab_d acc_alim1 acc_alim2 acc_alim3 acc_alim4 acc_alim5 acc_alim6
# 1 0          2         2         2         2         2         2
# 2 0          2         2         2         2         2         2
# 3 0          2         2         2         2         2         2
# 4 0          2         2         2         2         2         2
# 5 0          2         2         2         2         2         2
# 6 0          2         2         2         2         2         2
#   alim17_1 alim17_2 alim17_3 ⋯ regalos remunera transferen parto_g embarazo_g
# 1 7        1        3        ⋯ 1       2        2          2       2
# 2 7        3        3        ⋯ 1       2        1          2       2
# 3 4        2        7        ⋯ 1       2        2          2       2
# 4 3        1        4        ⋯ 2       1        2          2       2
# 5 7        7        7        ⋯ 1       2        1          2       2
# 6 7        1        7        ⋯ 2       2        2          2       2
#   negcua est_alim est_trans bene_licon diconsa
# 1 2      2100      700      2          1
# 2 2       900       20      2          1
# 3 2      1700      350      2          1
# 4 2      1200      300      2          9
# 5 2      3100      300      2          2
# 6 1      3300     2400      2          1

# %%
data$huespedes <- NULL

# %%
ncol(data)
# Out:
# [1] 75

# %%
data_names <- c()
data_entropy <- c()

for (column in 1:ncol(data)) {
#    print(names(data[column]))
    entropy <- SpatEntropy::shannonX(data = matrix(data[column]))
  
  data_names <- append(x = data_names, values = names(data[column]))
  data_entropy <- append(x = data_entropy, values = entropy$shannon)
}

# %%
df_entropy <- cbind(data.frame(data_names, data_entropy)) 
head(df_entropy)
# Out:
#   data_names data_entropy
# 1 num_trab_d 0.0559230
# 2 acc_alim1  0.5838834
# 3 acc_alim2  0.2333031
# 4 acc_alim3  0.4507160
# 5 acc_alim4  0.4731912
# 6 acc_alim5  0.2736092

# %%
order_df_entropy <- df_entropy[order(df_entropy$data_entropy, decreasing = T), ]
head(order_df_entropy)
# Out:
#    data_names data_entropy
# 72 est_alim   4.319120
# 73 est_trans  3.310052
# 47 anio_estuf 3.282109
# 45 anio_refri 3.204282
# 49 anio_lavad 3.111690
# 41 anio_licua 3.033139

# %%
ggplot(df_entropy, aes(y=data_names, x=data_entropy)) + 
    theme_bw() +
    ggtitle('Entropía de las variables del data set mixto Hogares/ENIGH') + 
    xlab('Nats') +
    ylab("Variables")+
    theme(plot.title = element_text(hjust = 0.5))+
    geom_point()+
    ggsave(filename = "../../../../../../images/enigh/HOGARES/entropy_og.png", dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
ggplot(data = data, 
       aes(y=data$est_alim, 
           x=data$est_trans))+
    theme_bw() +
    ggtitle('Dos variables con mayor entropía del data set mixto Hogares/ENIGH') + 
    xlab('est_trans') +
    ylab("est_alim")+
    theme(plot.title = element_text(hjust = 0.5))+
    geom_point()+
    ggsave(filename = "../../../../../../images/enigh/HOGARES/entropy_og_2_var.png", dpi = 300)
# Out:
# Saving 7 x 7 in image
# plot without title

# %%
png("../../../../../../images/enigh/HOGARES/entropy_og_3_var.png")
scatterplot3d(y=data$est_alim, 
              x=data$est_trans,
              z=data$anio_estuf, pch = 19, 
              color = "black", 
              main="Tres variables con mayor entropía del data set mixto Hogares/ENIGH",
              xlab = 'est_alim', 
              ylab = 'est_trans',
              zlab = 'anio_estuf') 
dev.off()
# Out:
# pdf
#   2

# %%
file = '../../../../../../dataframes/enigh/HOGARES/df_entropy_og_mixed.csv'

# %%
write.csv(order_df_entropy, 
          file = file,
          row.names=FALSE)
