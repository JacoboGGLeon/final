# %%
import pandas as pd
import missingno as msno
import numpy as np
from missingpy import MissForest

# %%
file = '../../../../../../dataframes/enigh/HOGARES/df_09_clean.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    huespedes  num_trab_d  acc_alim1  acc_alim2  acc_alim3  acc_alim4  \
# 0          0           0          2          2          2          2
# 1          0           0          2          2          2          2
# 2          0           0          2          2          2          2
# 3          0           0          2          2          2          2
# 4          0           0          2          2          2          2
#
#    acc_alim5  acc_alim6  alim17_1  alim17_2  ...  remunera  transferen  \
# 0          2          2         7         1  ...         2           2
# 1          2          2         7         3  ...         2           1
# 2          2          2         4         2  ...         2           2
# 3          2          2         3         1  ...         1           2
# 4          2          2         7         7  ...         2           1
#
#    parto_g  embarazo_g  negcua  est_alim  est_trans  bene_licon  diconsa  \
# 0        2           2       2      2100      700.0           2        1
# 1        2           2       2       900       20.0           2        1
# 2        2           2       2      1700      350.0           2        1
# 3        2           2       2      1200      300.0           2        9
# 4        2           2       2      3100      300.0           2        2
#
#    CVE_MUN
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#
# [5 rows x 79 columns]

# %%
df_copy = df.copy()

# %%
df_copy[['anio_tvd','anio_licua', 'anio_refri', 'anio_estuf', 'anio_lavad', 'anio_planc']].astype(str)
# Out:
#      anio_tvd anio_licua anio_refri anio_estuf anio_lavad anio_planc
# 0        15.0       10.0        6.0        7.0        9.0       14.0
# 1         nan       11.0       11.0        6.0        6.0       11.0
# 2        15.0       14.0       12.0       12.0       14.0       14.0
# 3        15.0       12.0       10.0       10.0       13.0       15.0
# 4        13.0       14.0        nan        nan        nan        nan
# 5        14.0       13.0       96.0        6.0        1.0       11.0
# 6        15.0       13.0        8.0        6.0        6.0       15.0
# 7        16.0       13.0       95.0       93.0       96.0       14.0
# 8        16.0       15.0       14.0       15.0       15.0        nan
# 9         nan       13.0       13.0       15.0        6.0       15.0
# 10        0.0        6.0        4.0        1.0       13.0        1.0
# 11       15.0       94.0        1.0        1.0        nan       16.0
# 12       13.0       12.0       10.0        9.0        nan       11.0
# 13       15.0       16.0       14.0       12.0       12.0       15.0
# 14       16.0        nan        9.0       10.0       12.0        9.0
# 15       12.0       14.0        9.0        9.0        7.0        9.0
# 16       15.0       11.0        6.0        6.0        8.0       12.0
# 17       15.0       15.0       10.0        8.0        8.0       14.0
# 18       11.0        9.0       12.0        6.0       15.0        5.0
# 19       10.0        7.0        1.0       15.0        nan       15.0
# 20       14.0       15.0       10.0       13.0       16.0       15.0
# 21       15.0       15.0        6.0        6.0        5.0       12.0
# 22       15.0       12.0       14.0        9.0        9.0       12.0
# 23       11.0       92.0       87.0       86.0       90.0       12.0
# 24       15.0       13.0        5.0        5.0        5.0       13.0
# 25        nan       11.0       95.0       95.0       99.0       12.0
# 26       16.0        1.0        nan        6.0        nan       14.0
# 27       15.0       14.0        7.0        7.0        3.0       13.0
# 28        nan        nan        2.0        2.0        2.0        2.0
# 29       15.0       15.0        6.0        1.0        8.0       14.0
# ...       ...        ...        ...        ...        ...        ...
# 1703     16.0       13.0       10.0       10.0       14.0       15.0
# 1704     15.0       10.0       11.0       10.0       14.0       13.0
# 1705     13.0       12.0       14.0       14.0       15.0       10.0
# 1706     15.0       10.0       14.0       10.0       13.0       15.0
# 1707     12.0       14.0       10.0       10.0        0.0       12.0
# 1708     14.0       15.0       99.0       14.0       15.0       15.0
# 1709     14.0       10.0        9.0        0.0        2.0        2.0
# 1710     13.0       12.0       13.0       13.0       14.0       16.0
# 1711     15.0        2.0        2.0        2.0        1.0        3.0
# 1712      nan       10.0        9.0       98.0       12.0        0.0
# 1713     15.0        6.0        0.0       98.0        0.0        4.0
# 1714     14.0        8.0       12.0       10.0       15.0       15.0
# 1715      nan       14.0       14.0       14.0       14.0       14.0
# 1716     15.0       13.0       11.0        7.0       13.0       13.0
# 1717     16.0        4.0        nan       96.0        nan       11.0
# 1718     15.0       11.0       15.0       14.0       14.0        6.0
# 1719     15.0        nan        nan       15.0        nan        nan
# 1720     15.0        nan        nan       12.0        nan        0.0
# 1721      nan       10.0        nan       16.0        nan        9.0
# 1722      nan       10.0        nan       13.0        8.0        nan
# 1723      nan       11.0        nan       11.0       14.0       15.0
# 1724      nan        6.0        nan        6.0        nan       16.0
# 1725     15.0        5.0       10.0       10.0       10.0       15.0
# 1726     15.0       10.0       10.0       15.0        nan        6.0
# 1727      nan        9.0        nan       12.0        1.0       13.0
# 1728      nan       13.0        nan        0.0        0.0       13.0
# 1729     13.0       15.0        nan       10.0        nan       15.0
# 1730     12.0       14.0       13.0        4.0       11.0       16.0
# 1731      nan       11.0       11.0        6.0        nan        nan
# 1732     15.0       12.0       14.0       14.0        nan        nan
#
# [1733 rows x 6 columns]

# %%
df_copy.replace(to_replace=np.NaN,
                                  value= -1,
                                  inplace=True)

# %%
for column in df_copy.columns:
    df_copy[column] = df_copy[column].astype('int64')

# %%
df_copy.replace(to_replace=-1,
                                  value=np.NaN,
                                  inplace=True)

# %%
df_copy.shape
# Out:
# (1733, 79)

# %%
msno.bar(df_copy, fontsize=10)
#plt.xlabel('Columnas', fontsize=30)
#plt.ylabel('Observaciones', fontsize=30)
#plt.savefig('../../../images/envipe/df_tmod_vic_envipe2016_09_nan_ident.png', dpi=300)

# %%
df_copy.replace(to_replace=np.NaN,
                                  value= -1,
                                  inplace=True)

# %%
threshold = round(df_copy.shape[0]*1)
threshold
# Out:
# 1733

# %%
l = []
for column in df_copy.columns:
    na_column =  df_copy[column].value_counts().get(-1)
    if(na_column != None):
        print(column, ': ', df_copy.shape[0] - na_column, ' - ', threshold)
        if (df_copy.shape[0] - na_column < threshold):
            l.append(column)
# Out:
# anio_tvd :  1410  -  1733
# anio_licua :  1623  -  1733
# anio_refri :  1582  -  1733
# anio_estuf :  1655  -  1733
# anio_lavad :  1388  -  1733
# anio_planc :  1546  -  1733
# est_trans :  1704  -  1733

# %%
l
# Out:
# ['anio_tvd',
#  'anio_licua',
#  'anio_refri',
#  'anio_estuf',
#  'anio_lavad',
#  'anio_planc',
#  'est_trans']

# %%
df_copy[df_copy.columns[~df_copy.columns.isin(l)]].head()
# Out:
#    huespedes  num_trab_d  acc_alim1  acc_alim2  acc_alim3  acc_alim4  \
# 0          0           0          2          2          2          2
# 1          0           0          2          2          2          2
# 2          0           0          2          2          2          2
# 3          0           0          2          2          2          2
# 4          0           0          2          2          2          2
#
#    acc_alim5  acc_alim6  alim17_1  alim17_2  ...  regalos  remunera  \
# 0          2          2         7         1  ...        1         2
# 1          2          2         7         3  ...        1         2
# 2          2          2         4         2  ...        1         2
# 3          2          2         3         1  ...        2         1
# 4          2          2         7         7  ...        1         2
#
#    transferen  parto_g  embarazo_g  negcua  est_alim  bene_licon  diconsa  \
# 0           2        2           2       2      2100           2        1
# 1           1        2           2       2       900           2        1
# 2           2        2           2       2      1700           2        1
# 3           2        2           2       2      1200           2        9
# 4           1        2           2       2      3100           2        2
#
#    CVE_MUN
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#
# [5 rows x 72 columns]

# %%
df_copy.replace(to_replace=-1,value=np.NaN,inplace=True)

# %%
imputer = MissForest()
X_imputed = imputer. fit_transform(df_copy)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6

# %%
df_copy_copy = df_copy.copy()

# %%
df_copy_copy = pd.DataFrame(data=X_imputed, columns=df_copy_copy.columns)

# %%
for column in df_copy_copy.columns:
    df_copy_copy[column] = df_copy_copy[column].astype('int64')

# %%
df_copy_copy.isnull().any().any()
# Out:
# False

# %%
df_copy_copy.shape
# Out:
# (1733, 79)

# %%
df.shape
# Out:
# (1733, 79)

# %%
list_ids = ['CVE_MUN']

# %%
df_copy_copy.drop(labels=list_ids, axis=1, inplace=True)

# %%
file = '../../../../../../dataframes/enigh/HOGARES/df_09_impute.csv'

# %%
file = '../../../../../../dataframes/enigh/HOGARES/df_09_impute.csv'

# %%
df_copy_copy.to_csv(file,index = False, header = True, sep = ',', encoding = 'utf-8')

# %%
l = []
bandera = np.NAN
for column in df_copy_copy.columns:
    if df_copy_copy[column].dtype == np.int64:
        bandera = 'entero'
    elif df_copy_copy[column].dtype == np.float64:
        bandera = 'flotante'
    else:
        bandera = 'otro'
    
    try:
        df_copy_copy[column] = df_copy_copy[column].astype('int64')
    except:
        l.append(column)
        
    print('COLUMNA: ', column)
    print('TIPO: ', bandera)
    print('NUNIQUE: ', df_copy_copy[column].nunique())
    print('UNIQUE: ', df_copy_copy[column].unique())
    print('VALUE COUNTS ', df_copy_copy[column].value_counts().sort_index())
    print('\n')
# Out:
# COLUMNA:  huespedes
# TIPO:  entero
# NUNIQUE:  1
# UNIQUE:  [0]
# VALUE COUNTS  0    1733
# Name: huespedes, dtype: int64
#
#
# COLUMNA:  num_trab_d
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    1717
# 1      14
# 2       2
# Name: num_trab_d, dtype: int64
#
#
# COLUMNA:  acc_alim1
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     469
# 2    1264
# Name: acc_alim1, dtype: int64
#
#
# COLUMNA:  acc_alim2
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     108
# 2    1625
# Name: acc_alim2, dtype: int64
#
#
# COLUMNA:  acc_alim3
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     289
# 2    1444
# Name: acc_alim3, dtype: int64
#
#
# COLUMNA:  acc_alim4
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     314
# 2    1419
# Name: acc_alim4, dtype: int64
#
#
# COLUMNA:  acc_alim5
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     135
# 2    1598
# Name: acc_alim5, dtype: int64
#
#
# COLUMNA:  acc_alim6
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     232
# 2    1501
# Name: acc_alim6, dtype: int64
#
#
# COLUMNA:  alim17_1
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 4 3 1 5 2 0 6]
# VALUE COUNTS  0      15
# 1      18
# 2      45
# 3      69
# 4      50
# 5      59
# 6      14
# 7    1463
# Name: alim17_1, dtype: int64
#
#
# COLUMNA:  alim17_2
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [1 3 2 7 0 5 4 6]
# VALUE COUNTS  0    287
# 1    497
# 2    460
# 3    267
# 4     53
# 5     40
# 6      6
# 7    123
# Name: alim17_2, dtype: int64
#
#
# COLUMNA:  alim17_3
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [3 7 4 5 2 0 6 1]
# VALUE COUNTS  0     54
# 1     58
# 2    217
# 3    260
# 4    140
# 5    166
# 6     61
# 7    777
# Name: alim17_3, dtype: int64
#
#
# COLUMNA:  alim17_4
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [3 2 7 5 4 1 6 0]
# VALUE COUNTS  0     90
# 1    104
# 2    185
# 3    224
# 4    103
# 5    143
# 6     60
# 7    824
# Name: alim17_4, dtype: int64
#
#
# COLUMNA:  alim17_5
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [2 6 7 4 3 0 1 5]
# VALUE COUNTS  0     72
# 1    211
# 2    359
# 3    417
# 4    201
# 5    142
# 6     45
# 7    286
# Name: alim17_5, dtype: int64
#
#
# COLUMNA:  alim17_6
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 3 1 5 2 4 6 0]
# VALUE COUNTS  0    107
# 1    232
# 2    423
# 3    405
# 4    168
# 5     84
# 6     30
# 7    284
# Name: alim17_6, dtype: int64
#
#
# COLUMNA:  alim17_7
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [1 0 2 3 4 5 7 6]
# VALUE COUNTS  0    728
# 1    595
# 2    223
# 3    112
# 4     33
# 5      9
# 6      6
# 7     27
# Name: alim17_7, dtype: int64
#
#
# COLUMNA:  alim17_8
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [3 7 2 4 5 0 1 6]
# VALUE COUNTS  0    137
# 1    187
# 2    272
# 3    319
# 4    163
# 5    101
# 6     36
# 7    518
# Name: alim17_8, dtype: int64
#
#
# COLUMNA:  alim17_9
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [2 4 7 6 0 5 1 3]
# VALUE COUNTS  0    126
# 1     96
# 2    153
# 3    190
# 4     88
# 5     86
# 6     44
# 7    950
# Name: alim17_9, dtype: int64
#
#
# COLUMNA:  alim17_10
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 3 1 0 4 5 2 6]
# VALUE COUNTS  0      45
# 1      29
# 2      44
# 3      62
# 4      36
# 5      41
# 6      14
# 7    1462
# Name: alim17_10, dtype: int64
#
#
# COLUMNA:  alim17_11
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 0 6 3 5 1 2 4]
# VALUE COUNTS  0      97
# 1      53
# 2      72
# 3      74
# 4      34
# 5      57
# 6      13
# 7    1333
# Name: alim17_11, dtype: int64
#
#
# COLUMNA:  alim17_12
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [7 6 0 4 5 2 1 3]
# VALUE COUNTS  0     105
# 1      39
# 2      63
# 3      81
# 4      41
# 5      59
# 6      22
# 7    1323
# Name: alim17_12, dtype: int64
#
#
# COLUMNA:  acc_alim18
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 3 2]
# VALUE COUNTS  1    1672
# 2      15
# 3      46
# Name: acc_alim18, dtype: int64
#
#
# COLUMNA:  telefono
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    1165
# 2     568
# Name: telefono, dtype: int64
#
#
# COLUMNA:  celular
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    1485
# 2     248
# Name: celular, dtype: int64
#
#
# COLUMNA:  tv_paga
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    766
# 2    967
# Name: tv_paga, dtype: int64
#
#
# COLUMNA:  conex_inte
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    1042
# 2     691
# Name: conex_inte, dtype: int64
#
#
# COLUMNA:  num_auto
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 2 3 4]
# VALUE COUNTS  0    1142
# 1     490
# 2      86
# 3      13
# 4       2
# Name: num_auto, dtype: int64
#
#
# COLUMNA:  num_van
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 3]
# VALUE COUNTS  0    1619
# 1     105
# 2       8
# 3       1
# Name: num_van, dtype: int64
#
#
# COLUMNA:  num_pickup
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [0 1]
# VALUE COUNTS  0    1712
# 1      21
# Name: num_pickup, dtype: int64
#
#
# COLUMNA:  num_moto
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    1683
# 1      48
# 2       2
# Name: num_moto, dtype: int64
#
#
# COLUMNA:  num_bici
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 3]
# VALUE COUNTS  0    1614
# 1     100
# 2      14
# 3       5
# Name: num_bici, dtype: int64
#
#
# COLUMNA:  num_trici
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [0 1]
# VALUE COUNTS  0    1730
# 1       3
# Name: num_trici, dtype: int64
#
#
# COLUMNA:  num_carret
# TIPO:  entero
# NUNIQUE:  1
# UNIQUE:  [0]
# VALUE COUNTS  0    1733
# Name: num_carret, dtype: int64
#
#
# COLUMNA:  num_canoa
# TIPO:  entero
# NUNIQUE:  1
# UNIQUE:  [0]
# VALUE COUNTS  0    1733
# Name: num_canoa, dtype: int64
#
#
# COLUMNA:  num_otro
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [0 1]
# VALUE COUNTS  0    1732
# 1       1
# Name: num_otro, dtype: int64
#
#
# COLUMNA:  num_ester
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [1 0 2 3]
# VALUE COUNTS  0    733
# 1    956
# 2     36
# 3      8
# Name: num_ester, dtype: int64
#
#
# COLUMNA:  num_grab
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    1418
# 1     311
# 2       4
# Name: num_grab, dtype: int64
#
#
# COLUMNA:  num_radio
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 2 3 4]
# VALUE COUNTS  0    1407
# 1     310
# 2      12
# 3       3
# 4       1
# Name: num_radio, dtype: int64
#
#
# COLUMNA:  num_tva
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [0 1 2 3 4 5]
# VALUE COUNTS  0    1070
# 1     560
# 2      80
# 3      17
# 4       5
# 5       1
# Name: num_tva, dtype: int64
#
#
# COLUMNA:  num_tvd
# TIPO:  entero
# NUNIQUE:  7
# UNIQUE:  [1 0 2 4 3 5 7]
# VALUE COUNTS  0     323
# 1    1003
# 2     290
# 3      94
# 4      17
# 5       5
# 7       1
# Name: num_tvd, dtype: int64
#
#
# COLUMNA:  anio_tvd
# TIPO:  entero
# NUNIQUE:  33
# UNIQUE:  [15 13 14 16  0 12 11 10  9  8  7  6 31 98 29  1 96  5 18 50 32 28 40 38
#   2  3 23 33 20 90 22 19  4]
# VALUE COUNTS  0       5
# 1       6
# 2       2
# 3       4
# 4       2
# 5       5
# 6      21
# 7       6
# 8      24
# 9      33
# 10     66
# 11    126
# 12    198
# 13    345
# 14    312
# 15    465
# 16     89
# 18      2
# 19      1
# 20      2
# 22      1
# 23      1
# 28      2
# 29      2
# 31      2
# 32      1
# 33      1
# 38      2
# 40      1
# 50      1
# 90      1
# 96      1
# 98      3
# Name: anio_tvd, dtype: int64
#
#
# COLUMNA:  num_dvd
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [1 2 0 3 5]
# VALUE COUNTS  0    761
# 1    893
# 2     62
# 3     16
# 5      1
# Name: num_dvd, dtype: int64
#
#
# COLUMNA:  num_video
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    1597
# 1     129
# 2       7
# Name: num_video, dtype: int64
#
#
# COLUMNA:  num_licua
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [1 0 2 4]
# VALUE COUNTS  0     110
# 1    1596
# 2      25
# 4       2
# Name: num_licua, dtype: int64
#
#
# COLUMNA:  anio_licua
# TIPO:  entero
# NUNIQUE:  72
# UNIQUE:  [10 11 14 12 13 15  6 94 16  9  7 92  1 44  4  8  0 96  5 90 99 97 98 35
#  59 34 58 91  2 42 86 18 56 95 31 20  3 36 70 63 89 62 55 65 75 61 82 60
#  23 76 79 68 50 48 93 33 32 80 66 39 64 30 38 17 88 85 46 54 41 40 19 45]
# VALUE COUNTS  0      51
# 1      61
# 2      13
# 3      12
# 4      24
# 5      34
# 6     161
# 7      33
# 8      96
# 9      88
# 10    174
# 11    159
# 12    142
# 13    138
# 14    153
# 15    124
# 16     70
# 17      2
# 18      1
# 19      1
# 20      1
# 23      2
# 30      2
# 31      2
# 32      1
# 33      1
# 34      1
# 35      2
# 36      1
# 38      1
#      ...
# 58      1
# 59      4
# 60      1
# 61      1
# 62      1
# 63      1
# 64      1
# 65      1
# 66      1
# 68      1
# 70      2
# 75      1
# 76      2
# 79      1
# 80      4
# 82      1
# 85      2
# 86     15
# 88      1
# 89      1
# 90     12
# 91      4
# 92      4
# 93      1
# 94      4
# 95      9
# 96     52
# 97      5
# 98     17
# 99     16
# Name: anio_licua, Length: 72, dtype: int64
#
#
# COLUMNA:  num_tosta
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 0 2]
# VALUE COUNTS  0    1365
# 1     367
# 2       1
# Name: num_tosta, dtype: int64
#
#
# COLUMNA:  num_micro
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 0 2]
# VALUE COUNTS  0     625
# 1    1100
# 2       8
# Name: num_micro, dtype: int64
#
#
# COLUMNA:  num_refri
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [ 1  0  2 14]
# VALUE COUNTS  0      151
# 1     1574
# 2        7
# 14       1
# Name: num_refri, dtype: int64
#
#
# COLUMNA:  anio_refri
# TIPO:  entero
# NUNIQUE:  78
# UNIQUE:  [ 6 11 12 10 96  8 95 14 13  4  1  9 87  5 23  7  2 41 16 97 94 15 89  0
#  92  3 76 22 98 36 19 32 33 59 20 93 86 60 99 72 91 64 21 80 46 27 30 75
#  18 37 90 50 84 66 63 83 70 40 57 26 31 17 85 88 35 48 45 65 51 78 52 82
#  29 43 38 25 28 55]
# VALUE COUNTS  0      73
# 1     111
# 2      24
# 3      23
# 4      47
# 5      38
# 6     181
# 7      42
# 8      86
# 9      94
# 10    166
# 11    130
# 12    118
# 13    110
# 14    108
# 15     84
# 16     39
# 17      1
# 18      4
# 19      4
# 20      4
# 21      1
# 22      3
# 23      2
# 25      1
# 26      1
# 27      1
# 28      1
# 29      2
# 30      6
#      ...
# 59      1
# 60      1
# 63      1
# 64      1
# 65      1
# 66      1
# 70      2
# 72      1
# 75      1
# 76      1
# 78      1
# 80      3
# 82      1
# 83      1
# 84      2
# 85      2
# 86     14
# 87      1
# 88      1
# 89      3
# 90     14
# 91     13
# 92      9
# 93      1
# 94      4
# 95     17
# 96     52
# 97     13
# 98     16
# 99     16
# Name: anio_refri, Length: 78, dtype: int64
#
#
# COLUMNA:  num_estuf
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 0 2]
# VALUE COUNTS  0      78
# 1    1647
# 2       8
# Name: num_estuf, dtype: int64
#
#
# COLUMNA:  anio_estuf
# TIPO:  entero
# NUNIQUE:  67
# UNIQUE:  [ 7  6 12 10 15 93  1  9  8 13 86  5 95  2 16  4 97 99 14 96 98 11  0 70
#  94 92 90 85 17 19 21 30 76 33  3 88 79 39 26 91 25 27 35 22 37 28 36 80
#  32 84 24 74 73 82 71 78 81 72 23 18 41 45 89 66 34 20 83]
# VALUE COUNTS  0      94
# 1     101
# 2      33
# 3      17
# 4      39
# 5      47
# 6     156
# 7      46
# 8      83
# 9      98
# 10    150
# 11    109
# 12     87
# 13     80
# 14    113
# 15     83
# 16     50
# 17      5
# 18      3
# 19      4
# 20      3
# 21      2
# 22      4
# 23      1
# 24      1
# 25      2
# 26      1
# 27      1
# 28      2
# 30      3
#      ...
# 41      1
# 45      2
# 66      1
# 70      5
# 71      2
# 72      1
# 73      1
# 74      2
# 76      6
# 78      3
# 79      2
# 80     12
# 81      1
# 82      1
# 83      1
# 84      3
# 85      5
# 86     30
# 88      3
# 89      4
# 90     18
# 91     13
# 92      3
# 93      5
# 94      7
# 95     17
# 96     80
# 97     17
# 98     31
# 99     29
# Name: anio_estuf, Length: 67, dtype: int64
#
#
# COLUMNA:  num_lavad
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [1 0 2 5]
# VALUE COUNTS  0     345
# 1    1375
# 2      11
# 5       2
# Name: num_lavad, dtype: int64
#
#
# COLUMNA:  anio_lavad
# TIPO:  entero
# NUNIQUE:  72
# UNIQUE:  [ 9  6 14 13 15  1 96 20 11 12  7  8 16  5 90 99 25  3  2 47 10 48  0  4
#  67 92 94 26 19 98 97 80 65 17 64 30 66 22 91 61 39 27 23 95 51 63 60 49
#  18 62 36 34 52 86 21 69 55 37 82 38 58 32 81 50 44 79 33 57 85 46 59 29]
# VALUE COUNTS  0      62
# 1      65
# 2      31
# 3      11
# 4      37
# 5      32
# 6     140
# 7      51
# 8     102
# 9     100
# 10    176
# 11    161
# 12    140
# 13    131
# 14    142
# 15     98
# 16     62
# 17      6
# 18      7
# 19      2
# 20      4
# 21      4
# 22      5
# 23      4
# 25      2
# 26      2
# 27      4
# 29      1
# 30      4
# 32      1
#      ...
# 51      2
# 52      4
# 55      1
# 57      3
# 58      1
# 59      2
# 60      1
# 61      3
# 62      3
# 63      3
# 64      1
# 65      2
# 66      3
# 67      1
# 69      1
# 79      1
# 80      8
# 81      1
# 82      1
# 85      1
# 86      2
# 90      7
# 91      3
# 92      2
# 94      3
# 95      6
# 96     35
# 97      4
# 98     10
# 99     12
# Name: anio_lavad, Length: 72, dtype: int64
#
#
# COLUMNA:  num_planc
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [1 0 2 3 5]
# VALUE COUNTS  0     187
# 1    1492
# 2      47
# 3       6
# 5       1
# Name: num_planc, dtype: int64
#
#
# COLUMNA:  anio_planc
# TIPO:  entero
# NUNIQUE:  64
# UNIQUE:  [14 11 15 13  1 16  9 12  5  2 10 98 55  8  7  4  0 91 18  6 96 17 90 35
#  67 66 20 50 94 64 56  3 19 49 38 26 86 95 73 68 74 76 79 92 28 75 80 88
#  21 70 99 31 78 41 22 24 42 25 57 84 85 40 23 43]
# VALUE COUNTS  0      37
# 1      36
# 2      22
# 3       8
# 4      16
# 5      16
# 6      97
# 7      21
# 8      68
# 9      81
# 10    127
# 11    154
# 12    173
# 13    200
# 14    198
# 15    218
# 16    121
# 17      4
# 18      5
# 19      4
# 20      6
# 21      2
# 22      1
# 23      1
# 24      2
# 25      2
# 26      1
# 28      1
# 31      1
# 35      3
#      ...
# 43      1
# 49      1
# 50      1
# 55      1
# 56      2
# 57      1
# 64      2
# 66      4
# 67      1
# 68      3
# 70      1
# 73      1
# 74      2
# 75      2
# 76      2
# 78      2
# 79      2
# 80      4
# 84      2
# 85      2
# 86      7
# 88      1
# 90      7
# 91      5
# 92      1
# 94      4
# 95      3
# 96     19
# 98     11
# 99      8
# Name: anio_planc, Length: 64, dtype: int64
#
#
# COLUMNA:  num_maqui
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 4]
# VALUE COUNTS  0    1498
# 1     230
# 2       4
# 4       1
# Name: num_maqui, dtype: int64
#
#
# COLUMNA:  num_venti
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 2 3 4]
# VALUE COUNTS  0    1349
# 1     348
# 2      25
# 3       7
# 4       4
# Name: num_venti, dtype: int64
#
#
# COLUMNA:  num_aspir
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 6]
# VALUE COUNTS  0    1452
# 1     277
# 2       3
# 6       1
# Name: num_aspir, dtype: int64
#
#
# COLUMNA:  num_compu
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [1 0 2 3 5 8 4 7]
# VALUE COUNTS  0    896
# 1    689
# 2     97
# 3     41
# 4      3
# 5      4
# 7      1
# 8      2
# Name: num_compu, dtype: int64
#
#
# COLUMNA:  num_impre
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 3]
# VALUE COUNTS  0    1292
# 1     428
# 2      10
# 3       3
# Name: num_impre, dtype: int64
#
#
# COLUMNA:  num_juego
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 3 2 4]
# VALUE COUNTS  0    1452
# 1     247
# 2      20
# 3      11
# 4       3
# Name: num_juego, dtype: int64
#
#
# COLUMNA:  esc_radio
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    1066
# 2     667
# Name: esc_radio, dtype: int64
#
#
# COLUMNA:  tsalud1_h
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 1 2 3 6]
# VALUE COUNTS  0    1377
# 1     305
# 2      46
# 3       3
# 6       2
# Name: tsalud1_h, dtype: int64
#
#
# COLUMNA:  tsalud1_m
# TIPO:  entero
# NUNIQUE:  20
# UNIQUE:  [30 20 15 10 45 40  5  2 25 55 35 50  0 18  7 13 59  3 33 23]
# VALUE COUNTS  0     275
# 2       3
# 3       2
# 5      77
# 7       3
# 10    161
# 13      1
# 15    169
# 18      1
# 20    270
# 23      1
# 25     45
# 30    470
# 33      1
# 35     14
# 40    136
# 45     74
# 50     24
# 55      3
# 59      3
# Name: tsalud1_m, dtype: int64
#
#
# COLUMNA:  tarjeta
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     582
# 2    1151
# Name: tarjeta, dtype: int64
#
#
# COLUMNA:  pagotarjet
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     307
# 2    1426
# Name: pagotarjet, dtype: int64
#
#
# COLUMNA:  regalotar
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1      86
# 2    1647
# Name: regalotar, dtype: int64
#
#
# COLUMNA:  regalodado
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     143
# 2    1590
# Name: regalodado, dtype: int64
#
#
# COLUMNA:  autocons
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1      85
# 2    1648
# Name: autocons, dtype: int64
#
#
# COLUMNA:  regalos
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    930
# 2    803
# Name: regalos, dtype: int64
#
#
# COLUMNA:  remunera
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     250
# 2    1483
# Name: remunera, dtype: int64
#
#
# COLUMNA:  transferen
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     526
# 2    1207
# Name: transferen, dtype: int64
#
#
# COLUMNA:  parto_g
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1       4
# 2    1729
# Name: parto_g, dtype: int64
#
#
# COLUMNA:  embarazo_g
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1      20
# 2    1713
# Name: embarazo_g, dtype: int64
#
#
# COLUMNA:  negcua
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1      68
# 2    1665
# Name: negcua, dtype: int64
#
#
# COLUMNA:  est_alim
# TIPO:  entero
# NUNIQUE:  224
# UNIQUE:  [ 2100   900  1700  1200  3100  3300  2500  2300   600  1800  6000  2120
#   2800  7000  3390  2900  3150  2400  1600  1000   800  3000  4000  3500
#   8700 35000  5360  2600  2200  4300  4500  5500  8000  5000  5900 10000
#   4900  5300  2820  4400  7600  4200  6500  6900  1400  3160  5200 10500
#   7200 20000  9000  4600  6600  3700  1450  3600  4800  5100  4100 12400
#   4710  1500  1090  7500  3900  5700  8800 12000  3800  4700     0  6800
#   5600  8500  3200  2000  1900  4020  3356  2296  2270  1950  3080  4250
#   3400  6550  5250  4090 11000  8200  2570 11800  2848  4390  6720  4884
#   3698 14150  6100  4076  5392  6650  4350  8900  1520  6200  1960  2700
#   5400  2280 16000  7100  8750  8680  7840  9900   700  5950  1920  5580
#   2240  2950  3950  4096  2250  3580  1220  5560  6300  3780  6360  7800
#   1050  5050  7700  9500  4950  6700  3360  2550  5800  5792  4240  2160
#   4560  8600  1660  2840  6850  4828  1826  5150 11080  3920   750  2088
#    200   450   500   560  1300  3550  1710  1150  8400   400   300  3750
#   1650  8100  4414  1480  6545  3050  1350  5760   100  1460  8050  6150
#   1100 12500  9576  4360 12300  2480  3820  3076 22000  7300  3280  2650
#   2940 15500  5820  2050  5550  3350 10800  6400   650 16500  3825  5135
#   3320  2350  3850  1084  9320 11500 14000  9100  2620  6050  7050  5420
#  24000 19000  9600  1215  2150  2648 14300  3670]
# VALUE COUNTS  0         6
# 100       2
# 200       3
# 300       2
# 400       2
# 450       1
# 500       4
# 560       1
# 600       7
# 650       1
# 700       2
# 750       1
# 800      13
# 900      13
# 1000     29
# 1050      2
# 1084      1
# 1090      1
# 1100      3
# 1150      1
# 1200     24
# 1215      1
# 1220      1
# 1300      7
# 1350      1
# 1400     16
# 1450      2
# 1460      1
# 1480      1
# 1500     46
#          ..
# 8900      1
# 9000     15
# 9100      1
# 9320      1
# 9500      5
# 9576      1
# 9600      1
# 9900      2
# 10000     8
# 10500     4
# 10800     1
# 11000     4
# 11080     1
# 11500     1
# 11800     1
# 12000     4
# 12300     1
# 12400     1
# 12500     1
# 14000     1
# 14150     1
# 14300     1
# 15500     1
# 16000     2
# 16500     1
# 19000     1
# 20000     2
# 22000     1
# 24000     1
# 35000     1
# Name: est_alim, Length: 224, dtype: int64
#
#
# COLUMNA:  est_trans
# TIPO:  entero
# NUNIQUE:  115
# UNIQUE:  [ 700   20  350  300 2400  800  290  250  500 1300   60  935  600 1000
#   750  100    0 1100 2000 1200  200  732  280  560 2300  900 1214 1600
#   630  756  400  480  490 1150 2500 1500  260   50  160  645  150 1700
#  3000  331 1400  360  240  450  621  783  838  420  720 4160  220  192
#   650  297  375   30 1800  850 1950  120   40 1040 4960 1840 2100 3200
#   440  895 3300 1680  128 3500 2200   24   80  135  610 2320  690  454
#   460 1120  320  312 1480  352  801  483  833  164  273  592  340  453
#   283  550  676  382  259 2900  840  468  520  170  950  544  326  380
#  4000  503 2700]
# VALUE COUNTS  0       219
# 20        3
# 24        1
# 30        2
# 40        2
# 50       30
# 60        5
# 80        5
# 100      90
# 120       5
# 128       1
# 135       1
# 150      23
# 160       3
# 164       1
# 170       1
# 192       2
# 200     122
# 220       3
# 240       9
# 250      38
# 259       1
# 260       2
# 273       1
# 280       6
# 283       1
# 290       1
# 297       1
# 300     117
# 312       1
#        ...
# 1120      1
# 1150      2
# 1200     46
# 1214      1
# 1300     17
# 1400     13
# 1480      1
# 1500     57
# 1600     13
# 1680      2
# 1700      3
# 1800      8
# 1840      1
# 1950      1
# 2000     41
# 2100      2
# 2200      2
# 2300      1
# 2320      1
# 2400      1
# 2500     12
# 2700      1
# 2900      1
# 3000     14
# 3200      2
# 3300      1
# 3500      2
# 4000      2
# 4160      1
# 4960      1
# Name: est_trans, Length: 115, dtype: int64
#
#
# COLUMNA:  bene_licon
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1     194
# 2    1539
# Name: bene_licon, dtype: int64
#
#
# COLUMNA:  diconsa
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 9 2]
# VALUE COUNTS  1     346
# 2    1015
# 9     372
# Name: diconsa, dtype: int64

# %% [markdown]
# # limpiar 99s en años,días y meses de naciomiento

# %%
df_copy_copy_copy = df_copy_copy.copy()

# %%
df_copy_copy_copy[(df_copy_copy_copy.nac_anio == 9999)].shape
# Out:
# (29, 72)

# %%
df_copy_copy_copy[(df_copy_copy_copy.nac_mes == 99)].shape
# Out:
# (4901, 72)

# %%
df_copy_copy_copy[(df_copy_copy_copy.nac_dia == 99)].shape
# Out:
# (6036, 72)

# %%
df_copy_copy_copy.nac_anio.replace(to_replace=9999, 
                                   value=np.NaN, 
                                   inplace=True)

# %%
df_copy_copy_copy.nac_mes.replace(to_replace=99, 
                                   value=np.NaN, 
                                   inplace=True)

# %%
df_copy_copy_copy.nac_dia.replace(to_replace=99, 
                                   value=np.NaN, 
                                   inplace=True)

# %%
imputer = MissForest()
X_X_imputed = imputer. fit_transform(df_copy_copy_copy)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8

# %%
df_copy_copy = df_copy_copy_copy.copy()

# %%
df_copy_copy = pd.DataFrame(data=X_X_imputed, columns=df_copy_copy_copy.columns)

# %%
for column in df_copy_copy.columns:
    df_copy_copy[column] = df_copy_copy[column].astype('int64')

# %%
df_copy_copy.isnull().any().any()
# Out:
# False

# %%
df_copy_copy.shape
# Out:
# (76397, 72)

# %%
df.shape
# Out:
# (76397, 75)

# %%
list_edad = ["eda5c", "eda7c", "eda12c", "eda19c", ]

# %%
df_copy_copy.drop(labels=list_edad, axis=1, inplace=True)

# %%
file = "../../../../../dataframes/enoe/SDEMT/df_09_impute.csv"

# %%
df_copy_copy.to_csv(file,index = False, header = True, sep = ',', encoding = 'utf-8')

# %%
l = []
bandera = np.NAN
for column in df_copy_copy.columns:
    if df_copy_copy[column].dtype == np.int64:
        bandera = 'entero'
    elif df_copy_copy[column].dtype == np.float64:
        bandera = 'flotante'
    else:
        bandera = 'otro'
    
    try:
        df_copy_copy[column] = df_copy_copy[column].astype('int64')
    except:
        l.append(column)
        
    print('COLUMNA: ', column)
    print('TIPO: ', bandera)
    print('NUNIQUE: ', df_copy_copy[column].nunique())
    print('UNIQUE: ', df_copy_copy[column].unique())
    print('VALUE COUNTS ', df_copy_copy[column].value_counts().sort_index())
    print('\n')
# Out:
# COLUMNA:  est
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [10 30 20 40]
# VALUE COUNTS  10      635
# 20    35413
# 30    32529
# 40     7820
# Name: est, dtype: int64
#
#
# COLUMNA:  t_loc
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [1 2 3 4]
# VALUE COUNTS  1    71139
# 2     1491
# 3      740
# 4     3027
# Name: t_loc, dtype: int64
#
#
# COLUMNA:  sex
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    37074
# 2    39323
# Name: sex, dtype: int64
#
#
# COLUMNA:  eda
# TIPO:  entero
# NUNIQUE:  99
# UNIQUE:  [46 48 23 18 36 31 10  9 32 42 40 75 15  8 43 35  0 68 37 27 33 16 21 85
#  63 24 59 54 61 56 17 26 22 45 51 30 28  5  2 65  6  1 50 47 64 67 34 12
#  52 25 20 19 11 91 53 71 14 13  7  3 44 60 78 89 69 84 57 62 29 77 66 39
#  79 38 70 41 88 55 92 74 58  4 49 82 80 73 90 72 81 76 95 83 94 97 87 98
#  93 86 96]
# VALUE COUNTS  0      740
# 1      880
# 2      866
# 3      977
# 4      924
# 5     1002
# 6      967
# 7     1060
# 8     1104
# 9     1030
# 10    1116
# 11    1044
# 12    1086
# 13    1080
# 14    1113
# 15    1228
# 16    1203
# 17    1094
# 18    1174
# 19    1208
# 20    1162
# 21    1292
# 22    1303
# 23    1225
# 24    1225
# 25    1262
# 26    1295
# 27    2145
# 28    1249
# 29    1167
#       ...
# 69     444
# 70     504
# 71     417
# 72     341
# 73     402
# 74     354
# 75     325
# 76     306
# 77     261
# 78     264
# 79     221
# 80     278
# 81     201
# 82     174
# 83     150
# 84     159
# 85     135
# 86     115
# 87      91
# 88      96
# 89      72
# 90      64
# 91      49
# 92      40
# 93      33
# 94      27
# 95      26
# 96      10
# 97      14
# 98      29
# Name: eda, Length: 99, dtype: int64
#
#
# COLUMNA:  nac_dia
# TIPO:  entero
# NUNIQUE:  31
# UNIQUE:  [31 28 17 12  6  7 30 29 18 22 25 15 14 19 20 21 24 27 16 23  1  9  3 13
#   5 26 10  8  4  2 11]
# VALUE COUNTS  1     2425
# 2     2399
# 3     2352
# 4     2376
# 5     2453
# 6     2325
# 7     2238
# 8     2363
# 9     2206
# 10    2809
# 11    2480
# 12    3053
# 13    3044
# 14    3224
# 15    3569
# 16    3327
# 17    2723
# 18    2622
# 19    2413
# 20    2553
# 21    2479
# 22    2229
# 23    2137
# 24    2412
# 25    2206
# 26    2290
# 27    2176
# 28    2229
# 29    1957
# 30    2178
# 31    1150
# Name: nac_dia, dtype: int64
#
#
# COLUMNA:  nac_mes
# TIPO:  entero
# NUNIQUE:  12
# UNIQUE:  [ 3  8 10  4 12  1  9 11  6  5  7  2]
# VALUE COUNTS  1     5800
# 2     5575
# 3     6256
# 4     6429
# 5     7457
# 6     8150
# 7     7037
# 8     6191
# 9     5944
# 10    5846
# 11    5804
# 12    5908
# Name: nac_mes, dtype: int64
#
#
# COLUMNA:  nac_anio
# TIPO:  entero
# NUNIQUE:  104
# UNIQUE:  [1969 1967 1992 1997 1979 1984 2005 2006 1983 1973 1975 1940 2000 2007
#  1972 1980 2015 1947 1978 1988 1982 1999 1994 1930 1952 1991 1956 1961
#  1954 1959 1998 1989 1993 1970 1964 1985 1987 2010 2013 1951 2009 1965
#  1968 1948 2003 1963 1950 1990 1995 1996 2004 1981 1924 1944 2001 2002
#  2008 1971 1955 2014 1937 1926 1946 1931 1958 1953 1986 1938 1949 1976
#  1936 1977 1962 2012 1945 1974 1927 1960 1923 1966 1941 1957 2011 1934
#  1935 1942 1925 1943 1933 1939 1920 1932 1928 1921 1913 1917 1918 1922
#  1929 2016 1919 1916 1915 2017]
# VALUE COUNTS  1913       1
# 1915       1
# 1916       2
# 1917      22
# 1918      15
# 1919       5
# 1920      12
# 1921      19
# 1922      39
# 1923      33
# 1924      21
# 1925      58
# 1926      66
# 1927      71
# 1928      87
# 1929      90
# 1930     127
# 1931     124
# 1932     147
# 1933     143
# 1934     189
# 1935     194
# 1936     242
# 1937     284
# 1938     228
# 1939     311
# 1940     269
# 1941     325
# 1942     385
# 1943     361
#         ...
# 1988    1189
# 1989    1190
# 1990    1302
# 1991    1299
# 1992    1184
# 1993    1248
# 1994    1327
# 1995    1283
# 1996    1179
# 1997    1188
# 1998    1172
# 1999    1114
# 2000    1193
# 2001    1215
# 2002    1124
# 2003    1091
# 2004    1056
# 2005    1065
# 2006    1164
# 2007    1003
# 2008    1116
# 2009    1038
# 2010     962
# 2011     916
# 2012    1024
# 2013     946
# 2014     864
# 2015     884
# 2016     632
# 2017     139
# Name: nac_anio, Length: 104, dtype: int64
#
#
# COLUMNA:  l_nac_c
# TIPO:  entero
# NUNIQUE:  39
# UNIQUE:  [ 15   9  16 200  20  13  21  30  11 221 400  10  17   4   7  24  32  19
#   12   1  22  29  14  31  26   5  28   8 415   3  25   6  23  27   2  18
#  300 225  33]
# VALUE COUNTS  1         37
# 2         47
# 3          5
# 4         17
# 5         62
# 6         26
# 7        296
# 8        104
# 9      60212
# 10       242
# 11      1285
# 12      1242
# 13      1243
# 14       409
# 15      3653
# 16      1012
# 17       248
# 18        22
# 19        85
# 20      1538
# 21      1620
# 22       186
# 23        14
# 24       191
# 25        77
# 26        51
# 27        83
# 28       118
# 29       299
# 30      1430
# 31        40
# 32        92
# 33         4
# 200      154
# 221      100
# 225        6
# 300       36
# 400       73
# 415       38
# Name: l_nac_c, dtype: int64
#
#
# COLUMNA:  cs_p12
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    73870
# 2     2527
# Name: cs_p12, dtype: int64
#
#
# COLUMNA:  cs_p13_1
# TIPO:  entero
# NUNIQUE:  11
# UNIQUE:  [ 2  7  4  3  1  6  5  0  8  9 99]
# VALUE COUNTS  0      1537
# 1      6761
# 2     16197
# 3     16710
# 4     15486
# 5       267
# 6      3814
# 7     14258
# 8      1047
# 9       272
# 99       48
# Name: cs_p13_1, dtype: int64
#
#
# COLUMNA:  cs_p13_2
# TIPO:  entero
# NUNIQUE:  10
# UNIQUE:  [2 6 1 3 4 5 0 9 7 8]
# VALUE COUNTS  0     1537
# 1    10843
# 2    12118
# 3    30513
# 4     9215
# 5     3950
# 6     8081
# 7       16
# 8        7
# 9      117
# Name: cs_p13_2, dtype: int64
#
#
# COLUMNA:  cs_p17
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [2 1]
# VALUE COUNTS  1    25368
# 2    51029
# Name: cs_p17, dtype: int64
#
#
# COLUMNA:  e_con
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [5 6 1 3 4 2]
# VALUE COUNTS  1     8852
# 2     2692
# 3     1379
# 4     3798
# 5    22537
# 6    37139
# Name: e_con, dtype: int64
#
#
# COLUMNA:  salario
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2191 2401 2651]
# VALUE COUNTS  2191    38352
# 2401    35294
# 2651     2751
# Name: salario, dtype: int64
#
#
# COLUMNA:  clase1
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 0 2]
# VALUE COUNTS  0    12930
# 1    36859
# 2    26608
# Name: clase1, dtype: int64
#
#
# COLUMNA:  clase2
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [1 2 0 4 3]
# VALUE COUNTS  0    12930
# 1    35064
# 2     1795
# 3     4719
# 4    21889
# Name: clase2, dtype: int64
#
#
# COLUMNA:  clase3
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [1 4 6 3 0 2 7 5]
# VALUE COUNTS  0    39538
# 1    33948
# 2      181
# 3      626
# 4      309
# 5       19
# 6     1740
# 7       36
# Name: clase3, dtype: int64
#
#
# COLUMNA:  pos_ocu
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [3 1 0 2 4]
# VALUE COUNTS  0    41333
# 1    26107
# 2     1356
# 3     6833
# 4      768
# Name: pos_ocu, dtype: int64
#
#
# COLUMNA:  seg_soc
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [2 1 0 3]
# VALUE COUNTS  0    41333
# 1    15621
# 2    19333
# 3      110
# Name: seg_soc, dtype: int64
#
#
# COLUMNA:  rama
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [1 4 3 0 2 7 5 6]
# VALUE COUNTS  0    41333
# 1     2292
# 2     4008
# 3     7029
# 4    21165
# 5       88
# 6      278
# 7      204
# Name: rama, dtype: int64
#
#
# COLUMNA:  c_ocu11c
# TIPO:  entero
# NUNIQUE:  12
# UNIQUE:  [ 5  8  4  0  1  2  6  7  9  3 11 10]
# VALUE COUNTS  0     41333
# 1      6133
# 2      1415
# 3      1049
# 4      4552
# 5      6246
# 6      7022
# 7      2058
# 8      5847
# 9       383
# 10      262
# 11       97
# Name: c_ocu11c, dtype: int64
#
#
# COLUMNA:  ing7c
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [2 0 4 3 1 5 7 6]
# VALUE COUNTS  0    41333
# 1     4281
# 2     8679
# 3     7227
# 4     4901
# 5     2566
# 6      772
# 7     6638
# Name: ing7c, dtype: int64
#
#
# COLUMNA:  dur9c
# TIPO:  entero
# NUNIQUE:  10
# UNIQUE:  [2 1 6 0 4 3 8 5 7 9]
# VALUE COUNTS  0    41333
# 1      934
# 2     1923
# 3     2707
# 4     2984
# 5     1869
# 6    13610
# 7     5359
# 8     5548
# 9      130
# Name: dur9c, dtype: int64
#
#
# COLUMNA:  emple7c
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [1 6 0 4 2 5 3 7]
# VALUE COUNTS  0    41333
# 1     7204
# 2     8137
# 3     2236
# 4     1183
# 5     4988
# 6    10569
# 7      747
# Name: emple7c, dtype: int64
#
#
# COLUMNA:  medica5c
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [1 4 3 0 5 2]
# VALUE COUNTS  0    41333
# 1    16663
# 2      577
# 3    15044
# 4     2697
# 5       83
# Name: medica5c, dtype: int64
#
#
# COLUMNA:  buscar5c
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [2 4 0 3 1 5]
# VALUE COUNTS  0    41333
# 1      268
# 2      761
# 3      268
# 4    33753
# 5       14
# Name: buscar5c, dtype: int64
#
#
# COLUMNA:  rama_est1
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [2 3 0 4 1]
# VALUE COUNTS  0    41333
# 1      278
# 2     6388
# 3    28194
# 4      204
# Name: rama_est1, dtype: int64
#
#
# COLUMNA:  rama_est2
# TIPO:  entero
# NUNIQUE:  12
# UNIQUE:  [ 4 10  5  0  9  8  6  3  7 11  2  1]
# VALUE COUNTS  0     41537
# 1       278
# 2        88
# 3      4008
# 4      2292
# 5      7029
# 6      2704
# 7      2844
# 8      5004
# 9      3730
# 10     4362
# 11     2521
# Name: rama_est2, dtype: int64
#
#
# COLUMNA:  dur_est
# TIPO:  entero
# NUNIQUE:  7
# UNIQUE:  [2 1 4 0 3 5 6]
# VALUE COUNTS  0    41333
# 1      934
# 2     1923
# 3     5691
# 4    15479
# 5    10907
# 6      130
# Name: dur_est, dtype: int64
#
#
# COLUMNA:  ambito1
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [2 0 3 1]
# VALUE COUNTS  0    41333
# 1      278
# 2    33966
# 3      820
# Name: ambito1, dtype: int64
#
#
# COLUMNA:  ambito2
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [2 8 6 0 4 5 3 7]
# VALUE COUNTS  0    42431
# 2     8409
# 3     5502
# 4     6710
# 5     5068
# 6     3776
# 7     2521
# 8     1980
# Name: ambito2, dtype: int64
#
#
# COLUMNA:  tue1
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [3 1 0 2 4]
# VALUE COUNTS  0    41333
# 1    16487
# 2     6234
# 3    12247
# 4       96
# Name: tue1, dtype: int64
#
#
# COLUMNA:  tue2
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [5 6 1 0 4 2 3 7]
# VALUE COUNTS  0    41429
# 1    10949
# 2     5538
# 3     1122
# 4     5112
# 5    10328
# 6     1899
# 7       20
# Name: tue2, dtype: int64
#
#
# COLUMNA:  tue3
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    71285
# 1     4519
# 2      593
# Name: tue3, dtype: int64
#
#
# COLUMNA:  busqueda
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2 0 1]
# VALUE COUNTS  0    41333
# 1      268
# 2    34796
# Name: busqueda, dtype: int64
#
#
# COLUMNA:  d_ant_lab
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 2 1]
# VALUE COUNTS  0    74602
# 1     1580
# 2      215
# Name: d_ant_lab, dtype: int64
#
#
# COLUMNA:  d_cexp_est
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 3 2 1 4]
# VALUE COUNTS  0    74817
# 1      796
# 2      636
# 3       96
# 4       52
# Name: d_cexp_est, dtype: int64
#
#
# COLUMNA:  dur_des
# TIPO:  entero
# NUNIQUE:  7
# UNIQUE:  [0 3 1 2 6 4 5]
# VALUE COUNTS  0    74602
# 1      685
# 2      560
# 3      249
# 4      107
# 5       66
# 6      128
# Name: dur_des, dtype: int64
#
#
# COLUMNA:  sub_o
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 0]
# VALUE COUNTS  0    73492
# 1     2905
# Name: sub_o, dtype: int64
#
#
# COLUMNA:  s_clasifi
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [5 0 2 3 6 4]
# VALUE COUNTS  0    73492
# 2     1792
# 3       69
# 4       11
# 5     1029
# 6        4
# Name: s_clasifi, dtype: int64
#
#
# COLUMNA:  remune2c
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [0 1 2]
# VALUE COUNTS  0    50290
# 1    24462
# 2     1645
# Name: remune2c, dtype: int64
#
#
# COLUMNA:  pre_asa
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 1 2 3]
# VALUE COUNTS  0    50290
# 1    17862
# 2     8118
# 3      127
# Name: pre_asa, dtype: int64
#
#
# COLUMNA:  tip_con
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [0 5 3 2 4 6]
# VALUE COUNTS  0    50290
# 2     3295
# 3    13037
# 4       72
# 5     9544
# 6      159
# Name: tip_con, dtype: int64
#
#
# COLUMNA:  dispo
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 4 1 7 6]
# VALUE COUNTS  0    71678
# 1       27
# 4     4610
# 6       13
# 7       69
# Name: dispo, dtype: int64
#
#
# COLUMNA:  nodispo
# TIPO:  entero
# NUNIQUE:  8
# UNIQUE:  [0 3 5 9 2 8 1 4]
# VALUE COUNTS  0    54508
# 1       15
# 2      488
# 3    19590
# 4       10
# 5      701
# 8        2
# 9     1083
# Name: nodispo, dtype: int64
#
#
# COLUMNA:  c_inac5c
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [0 3 1 2 5 4]
# VALUE COUNTS  0    49789
# 1     9859
# 2    11151
# 3     3468
# 4      488
# 5     1642
# Name: c_inac5c, dtype: int64
#
#
# COLUMNA:  pnea_est
# TIPO:  entero
# NUNIQUE:  7
# UNIQUE:  [0 4 2 6 3 5 1]
# VALUE COUNTS  0    49789
# 1      109
# 2     4610
# 3     1095
# 4    18950
# 5      488
# 6     1356
# Name: pnea_est, dtype: int64
#
#
# COLUMNA:  niv_ins
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [1 2 4 3 0 5]
# VALUE COUNTS  0     5610
# 1    12152
# 2    12131
# 3    21087
# 4    25369
# 5       48
# Name: niv_ins, dtype: int64
#
#
# COLUMNA:  hij5c
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [0 2 1 3 4]
# VALUE COUNTS  0    42715
# 1    11185
# 2    12649
# 3     8248
# 4     1600
# Name: hij5c, dtype: int64
#
#
# COLUMNA:  domestico
# TIPO:  entero
# NUNIQUE:  11
# UNIQUE:  [ 4  3  0  1  9  8  2  6  5  7 10]
# VALUE COUNTS  0     12930
# 1      4850
# 2      1710
# 3     27772
# 4      2358
# 5       169
# 6      1462
# 7      8253
# 8     16406
# 9       447
# 10       40
# Name: domestico, dtype: int64
#
#
# COLUMNA:  anios_esc
# TIPO:  entero
# NUNIQUE:  25
# UNIQUE:  [ 2  6 13 11 12  0 16  3 10  8  9 15 17 14  5  7  1 19 99 18  4 21 20 22
#  23]
# VALUE COUNTS  0     14357
# 1       387
# 2       559
# 3      1091
# 4       461
# 5       940
# 6      7897
# 7      1534
# 8      2445
# 9     13026
# 10     2040
# 11     3295
# 12    12444
# 13     1330
# 14     1237
# 15     1690
# 16     7556
# 17     2658
# 18      892
# 19      203
# 20      127
# 21       70
# 22       31
# 23       10
# 99      117
# Name: anios_esc, dtype: int64
#
#
# COLUMNA:  hrsocup
# TIPO:  entero
# NUNIQUE:  103
# UNIQUE:  [  8   0  44  40  29  24  48  15  12  27  60  30  45  14  32  82  72  38
#   28  41  50  25   6  46   9  36  37  63  49  54  17  35  34  18  42  10
#   84  70  56  20   4  21  16  57  13  47  64   5  66  55  98  52  96   7
#   19  87  61  90  11  88 102  43  53  65  68  26   1  51  22  33   2   3
#   67 114  75 100  39  71  77  78  85 105  31  58  62  23  91  86  89  59
#   80  76  79 103 108 112 126  69  74 120  81  95  73]
# VALUE COUNTS  0      42397
# 1         20
# 2         75
# 3         59
# 4        144
# 5        100
# 6        210
# 7         53
# 8        247
# 9        126
# 10       294
# 11        32
# 12       415
# 13        24
# 14       124
# 15       283
# 16       367
# 17        15
# 18       345
# 19        17
# 20       598
# 21       152
# 22        56
# 23        17
# 24       857
# 25       454
# 26        26
# 27       129
# 28       262
# 29        26
#        ...
# 73         1
# 74         4
# 75        22
# 76        13
# 77        57
# 78        55
# 79         6
# 80        23
# 81         1
# 82        11
# 84       431
# 85         7
# 86        10
# 87         4
# 88        56
# 89        14
# 90        27
# 91        27
# 95         1
# 96        21
# 98        41
# 100        1
# 102        1
# 103        1
# 105       16
# 108        2
# 112        8
# 114        2
# 120        2
# 126        2
# Name: hrsocup, Length: 103, dtype: int64
#
#
# COLUMNA:  ingocup
# TIPO:  entero
# NUNIQUE:  494
# UNIQUE:  [  3000   2580   4000      0   8000   6000   5160   1000  16000   4730
#    3010   2200   6450   2150  12000   8600   2000  10000   4800   7200
#    1720   5000   4300   3200  11000   9890   3440    860   2800   2400
#    3120   6400    400   3870   2107   4400   7000   6600   9000  15000
#    3225   1290  30000   7160    800   6500   7430   5590    300   1200
#    3600  10750  18000   1920  15050   1800  17000   6020  20000   1935
#    2700   2600   1075   4500    645  14000  12900  50000   6800  25000
#   70000   2500   3612   3096    516   1548   1032    215   6880    430
#   17200   7300   7310   1500   3655   7740   7500    500   5400   5130
#    4600 160000   5375   4644   3500   1600   5600   1204  24000   9400
#    3135   9030   9460   5060    450  42000  21500   7600    559  40000
#    8400   3400   4200   2100    368   9600   4945   9800    150    600
#   13842   1806  60000  32000  21000  23000   4515   3800    301   5200
#    4816   7400  10320   3354   5500  19000  12800   1240   2795  11600
#   22000   8800   4667  31000  25800    200   2335   1505   2258   6150
#    4536    220  11610  10300   5790   4085    264  20425   2494   1300
#   13000   9450  26000  16400  11200  34000   8760   4050    520  10400
#     323   3956   3700   6321   3182   5805   2365  10200  11500  20640
#    9020    100   1376   2064   2322   2650   5100   2300    688  26091
#     452   3720   4340  19350  35000  64500  68000   1400  32180   6200
#     344   2881    774   5800   7955   3836 111250   3827   2900 100000
#    4128   5935  10600   4965  80000   4171    250   6708   8370  14233
#    4386    700  12040   3763   4100  12400   8500   9675  12600   6270
#    8900  64000  15600   2260  51600   4700    900  11800   8200   3044
#    9500   5144   5340   4280   9200   2408   3150   2236   7525  38700
#   15480   9804   3926  60200   3900  48000  66000   3300   1100  19500
#   24999  34400  21600   2167  11666  28000   8085   6235   6300   5260
#   27000 150000   6046   1762    697  36000   1900   1680   4900  30101
#    3222   1550   1590   6667   2250  89300  44000   5891   7800   2581
#    3483   3252   2752  10500    160   2838   4836   1076   3804   4360
#    4950   1613   8375   5672   9422  14400  11700  20400  12470   3890
#   90000    903   8300  27500   5750   5300  15200   2924  17630  16340
#   52000   1003   6100   3834  12500  11180   3410   3913   3110  33440
#    3850   8170   4519  32250  30100    258  14500 120000   1419   3100
#    3220   6650  55000   3780  18060   5676    548   6375  43000  25500
#    2720   4795 137600  14620   3350   4320   4580   2745   6870   4382
#    2940   4214  60206   3505   5870  16770  12384   3868   2340   6460
#    9488  16600   2460    602  13003   8240  13660  38000   3118   3216
#    7700   1700  16800   9100  35475   3590   1080   3784   6430  11825
#    5450  11100   3160   6550  12440  30960   3020   1975    731   7095
#    2156   2610  23220   3857   3698   4150   4040   4240  32700  45000
#    5900   4944  75000   7900   4870   8071   9034  27950   1596   5890
#    1360    129  13760   8700   2967    328   9005   5670    674   1591
#   18600   5020   5150  11400   2970  10900   9010   3240   7224  14800
#     254   3750   3450   5934   8084   5504   5616   3340   6370   1580
#    4802   3569   7482  18001   6900   6420  15800  11670   9780  16500
#    2993    980   5680  77406   1892    946    387   1118    240    172
#     750   7450  13500   9024  34406   4167   1433  10800   4156  31390
#    4231   1835  12700     86  19400   5700   8020   4902   1270   3070
#     550  46000   4484   4930]
# VALUE COUNTS  0         58830
# 86            1
# 100           1
# 129           1
# 150           3
# 160           1
# 172           1
# 200           7
# 215          11
# 220           1
# 240           1
# 250           2
# 254           2
# 258           4
# 264           1
# 300          13
# 301           2
# 323           2
# 328           1
# 344           9
# 368           1
# 387           1
# 400          19
# 430          65
# 450           3
# 452           1
# 500          20
# 516          12
# 520           1
# 548           1
#           ...
# 40000        66
# 42000         2
# 43000         6
# 44000         3
# 45000         4
# 46000         1
# 48000         2
# 50000        35
# 51600         1
# 52000         1
# 55000         1
# 60000        19
# 60200         1
# 60206         1
# 64000         2
# 64500         4
# 66000         1
# 68000         2
# 70000         7
# 75000         1
# 77406         1
# 80000        13
# 89300         1
# 90000         3
# 100000        2
# 111250        1
# 120000        1
# 137600        1
# 150000        2
# 160000        3
# Name: ingocup, Length: 494, dtype: int64
#
#
# COLUMNA:  ing_x_hrs
# TIPO:  entero
# NUNIQUE:  269
# UNIQUE:  [  87    0   21   34   30  128   37   44   25   16   96   41   42   19
#    31   52   13   12   23    6   29   22   35   48   46   40   33   32
#    15   51   18  124   69   24   53   28    9   11  116   17   55   77
#    95   64   58   27   49   62   43   54  188   45   93   38   20   83
#    50   60  125   65   68   36  178   10    8   14  103  200   81    7
#   290  139  271   99   72   26  120  186  744    5  145  132   39   84
#   102  104  232  333  142  250   76   66    4   75  244  166   67   63
#    82   56  310   71  173   80    2  100  193  111   47   85   70  130
#   110  155  101    3  174  465  106   61  109  180   89   90  279   73
#    74    1   59  558  115  118  147   94  158  375   92  199  348  406
#   133  160  288  600   57  134   79  165  367  150  258  625  329   88
#   179  162  387  211  187  121  574   86  220   91  206  930  697  536
#   300  112  225  119  108  620   98  400  291  253  341   78  169  114
#   126  144  277  113  872  151  209  325  273  159  129  140  346  195
#   255  135  122  272  666  127  167  214  498  308  107  242  218  237
#   287  222   97  204  201  177  234  175  217  813  213  338  248  457
#   170  500  203  105  131 1550  581  181 1440  156  750  138  265  436
#   148  123  357  164  833  598  299  189  223  317  372  240  254  216
#   276  172  285  176  280  422  208  221  283  228  230  445  484  395
#   117  143  523]
# VALUE COUNTS  0       59304
# 1          11
# 2          10
# 3          24
# 4          51
# 5          60
# 6          68
# 7          78
# 8         131
# 9         128
# 10        223
# 11        275
# 12        417
# 13        284
# 14        372
# 15        416
# 16        641
# 17        343
# 18        477
# 19        368
# 20        843
# 21        325
# 22        442
# 23        371
# 24        349
# 25        889
# 26        252
# 27        397
# 28        200
# 29        355
#         ...
# 395         1
# 400         5
# 406         1
# 422         1
# 436         2
# 445         1
# 457         1
# 465         8
# 484         1
# 498         1
# 500         3
# 523         1
# 536         1
# 558         1
# 574         1
# 581         2
# 598         1
# 600         1
# 620         2
# 625         1
# 666         2
# 697         7
# 744         1
# 750         2
# 813         1
# 833         1
# 872         1
# 930         1
# 1440        1
# 1550        1
# Name: ing_x_hrs, Length: 269, dtype: int64
#
#
# COLUMNA:  tpg_p8a
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 0]
# VALUE COUNTS  0    75100
# 1     1297
# Name: tpg_p8a, dtype: int64
#
#
# COLUMNA:  tcco
# TIPO:  entero
# NUNIQUE:  4
# UNIQUE:  [0 2 3 1]
# VALUE COUNTS  0    71772
# 1       95
# 2     1794
# 3     2736
# Name: tcco, dtype: int64
#
#
# COLUMNA:  cp_anoc
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 0]
# VALUE COUNTS  0    70767
# 1     5630
# Name: cp_anoc, dtype: int64
#
#
# COLUMNA:  imssissste
# TIPO:  entero
# NUNIQUE:  6
# UNIQUE:  [4 1 0 2 5 3]
# VALUE COUNTS  0    41333
# 1    11399
# 2     4014
# 3      208
# 4    19333
# 5      110
# Name: imssissste, dtype: int64
#
#
# COLUMNA:  ma48me1sm
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [0 1]
# VALUE COUNTS  0    76095
# 1      302
# Name: ma48me1sm, dtype: int64
#
#
# COLUMNA:  p14apoyos
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2 0 1]
# VALUE COUNTS  0    60408
# 1     2168
# 2    13821
# Name: p14apoyos, dtype: int64
#
#
# COLUMNA:  scian
# TIPO:  entero
# NUNIQUE:  22
# UNIQUE:  [ 4 19  7  0 16 12 15 18  5 14  8 20 10 11 17  9  6 21 13  3  1  2]
# VALUE COUNTS  0     41333
# 1       278
# 2         8
# 3        80
# 4      2292
# 5      4008
# 6      1018
# 7      6011
# 8      2101
# 9       743
# 10      923
# 11      290
# 12     2054
# 13       69
# 14     1668
# 15     2197
# 16     1533
# 17      444
# 18     2704
# 19     3918
# 20     2521
# 21      204
# Name: scian, dtype: int64
#
#
# COLUMNA:  t_tra
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 0 2]
# VALUE COUNTS  0    12930
# 1    62475
# 2      992
# Name: t_tra, dtype: int64
#
#
# COLUMNA:  emp_ppal
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 2 0]
# VALUE COUNTS  0    41333
# 1    17604
# 2    17460
# Name: emp_ppal, dtype: int64
#
#
# COLUMNA:  tue_ppal
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [1 2 0]
# VALUE COUNTS  0    41333
# 1    10328
# 2    24736
# Name: tue_ppal, dtype: int64
#
#
# COLUMNA:  trans_ppal
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [0 1]
# VALUE COUNTS  0    76377
# 1       20
# Name: trans_ppal, dtype: int64
#
#
# COLUMNA:  mh_fil2
# TIPO:  entero
# NUNIQUE:  5
# UNIQUE:  [1 2 3 0 4]
# VALUE COUNTS  0    41333
# 1    10328
# 2     1899
# 3    22559
# 4      278
# Name: mh_fil2, dtype: int64
#
#
# COLUMNA:  mh_col
# TIPO:  entero
# NUNIQUE:  10
# UNIQUE:  [7 1 2 0 3 6 8 9 5 4]
# VALUE COUNTS  0    41333
# 1     8927
# 2    15535
# 3     1565
# 4       80
# 5      616
# 6      740
# 7     5728
# 8     1105
# 9      768
# Name: mh_col, dtype: int64
#
#
# COLUMNA:  sec_ins
# TIPO:  entero
# NUNIQUE:  12
# UNIQUE:  [ 8  9  2  0  7  4  5  6  1 11  3 10]
# VALUE COUNTS  0     41333
# 1       876
# 2     10105
# 3       258
# 4      5248
# 5      2509
# 6      1122
# 7      2603
# 8     10328
# 9      1899
# 10       20
# 11       96
# Name: sec_ins, dtype: int64

# %%
list(df_copy_copy.columns)
# Out:
# ['est',
#  't_loc',
#  'sex',
#  'eda',
#  'nac_dia',
#  'nac_mes',
#  'nac_anio',
#  'l_nac_c',
#  'cs_p12',
#  'cs_p13_1',
#  'cs_p13_2',
#  'cs_p17',
#  'e_con',
#  'salario',
#  'clase1',
#  'clase2',
#  'clase3',
#  'pos_ocu',
#  'seg_soc',
#  'rama',
#  'c_ocu11c',
#  'ing7c',
#  'dur9c',
#  'emple7c',
#  'medica5c',
#  'buscar5c',
#  'rama_est1',
#  'rama_est2',
#  'dur_est',
#  'ambito1',
#  'ambito2',
#  'tue1',
#  'tue2',
#  'tue3',
#  'busqueda',
#  'd_ant_lab',
#  'd_cexp_est',
#  'dur_des',
#  'sub_o',
#  's_clasifi',
#  'remune2c',
#  'pre_asa',
#  'tip_con',
#  'dispo',
#  'nodispo',
#  'c_inac5c',
#  'pnea_est',
#  'niv_ins',
#  'eda5c',
#  'eda7c',
#  'eda12c',
#  'eda19c',
#  'hij5c',
#  'domestico',
#  'anios_esc',
#  'hrsocup',
#  'ingocup',
#  'ing_x_hrs',
#  'tpg_p8a',
#  'tcco',
#  'cp_anoc',
#  'imssissste',
#  'ma48me1sm',
#  'p14apoyos',
#  'scian',
#  't_tra',
#  'emp_ppal',
#  'tue_ppal',
#  'trans_ppal',
#  'mh_fil2',
#  'mh_col',
#  'sec_ins']
