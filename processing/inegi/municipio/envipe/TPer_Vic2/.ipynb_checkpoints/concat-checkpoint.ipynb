# %%
import pandas as pd
import numpy as np

# %%
file = "../../../../../../data/inegi-encuestas/municipio/envipe/envipe_2016_csv/tper_vic2_envipe2016/conjunto_de_datos/tper_vic2_envipe2016.csv"

# %%
df_01 = pd.read_csv(filepath_or_buffer=file)
df_01.head()
# Out:
#       ID_VIV           ID_HOG              ID_PER     UPM  VIV_SEL  HOGAR  \
# 0  100006.01  0100006.01.01\r  0100006.01.01.03\r  100006        1      1
# 1  100006.02  0100006.02.01\r  0100006.02.01.01\r  100006        2      1
# 2  100006.03  0100006.03.01\r  0100006.03.01.04\r  100006        3      1
# 3  100006.04  0100006.04.01\r  0100006.04.01.01\r  100006        4      1
# 4  100006.04  0100006.04.02\r  0100006.04.02.01\r  100006        4      2
#
#   RESUL_H  R_SEL AREAM  AP6_1_1  ... AP7_3_15  AP7_4_15  FAC_HOG  FAC_ELE  \
# 0     B\r      3  14\r        2  ...        2        \r      168      841
# 1     B\r      1  14\r        1  ...        2        \r      168      336
# 2     B\r      4  14\r        2  ...        2        \r      168      673
# 3     A\r      1  14\r        1  ...        2        \r      168      168
# 4     B\r      1    \r        2  ...        2        \r      168      168
#
#   FAC_HOG_AM FAC_ELE_AM  DOMINIO ESTRATO EST_DIS  UPM_DIS
# ...

# %%
df_01.shape
# Out:
# (85744, 143)

# %%
file = "../../../../../../data/inegi-encuestas/municipio/envipe/envipe_2017_csv/tper_vic2_envipe2017/conjunto_de_datos/tper_vic2.csv"

# %%
df_02 = pd.read_csv(filepath_or_buffer=file)
df_02.head()
# Out:
#       ID_VIV           ID_HOG              ID_PER     UPM  VIV_SEL  HOGAR  \
# 0  100008.01  0100008.01.01\r  0100008.01.01.01\r  100008        1      1
# 1  100008.02  0100008.02.01\r  0100008.02.01.02\r  100008        2      1
# 2  100008.04  0100008.04.01\r  0100008.04.01.01\r  100008        4      1
# 3  100008.05  0100008.05.01\r  0100008.05.01.01\r  100008        5      1
# 4  100022.01  0100022.01.01\r  0100022.01.01.03\r  100022        1      1
#
#   RESUL_H  R_SEL  SEXO  EDAD  ... AP7_3_15  AP7_4_15 FAC_HOG  FAC_ELE  \
# 0     B\r      1     1    40  ...        2        \r     204      408
# 1     B\r      2     2    70  ...        2        \r     204      611
# 2     B\r      1     1    85  ...        2        \r     204      408
# 3     A\r      1     1    28  ...        2        \r     204      408
# 4     A\r      3     1    22  ...        2        \r     198      595
#
#   FAC_HOG_AM  FAC_ELE_AM DOMINIO  ESTRATO  EST_DIS  UPM_DIS
# ...

# %%
df_02.shape
# Out:
# (92551, 149)

# %%
df_01.shape
# Out:
# (85744, 143)

# %%
frames = [df_01, df_02]

# %%
df = pd.concat(frames)
# Out:
# /Users/jacoboleon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.shape
# Out:
# (178295, 149)

# %%
df_copy=df.copy()

# %%
#list(df_copy.columns)

# %%
list_folios=['AREAM', 'DOMINIO', 'EST_DIS', 'FAC_ELE', 'FAC_ELE_AM', 'FAC_HOG', 'FAC_HOG_AM', 'HOGAR', 'ID_HOG', 'ID_PER', 'ID_VIV', 'NOM_ENT', 'NOM_MUN', 'RESUL_H', 'R_SEL', 'UPM', 'UPM_DIS', 'VIV_SEL']

# %%
df_copy.drop(labels=list_folios, axis=1, inplace=True)

# %%
df_copy = df_copy[(df_copy.CVE_ENT == 9)].copy()

# %%
df_copy.reset_index(inplace=True)
df_copy.drop(labels=['index'], axis=1, inplace=True)

# %%
df_copy.shape
# Out:
# (6203, 131)

# %%
df_copy.head(3)
# Out:
#    AP6_10_1 AP6_10_2 AP6_11_1 AP6_11_2  AP6_11_3  AP6_11_4  AP6_11_5  \
# 0         2      NaN      NaN      NaN       NaN       NaN       NaN
# 1         2      NaN      NaN      NaN       NaN       NaN       NaN
# 2         2      NaN      NaN      NaN       NaN       NaN       NaN
#
#    AP6_11_6  AP6_11_7 AP6_12_1  ... AP7_4_11  AP7_4_12  AP7_4_13  AP7_4_14  \
# 0       NaN       NaN      NaN  ...      NaN       NaN       NaN       NaN
# 1       NaN       NaN      NaN  ...      NaN       NaN       NaN       NaN
# 2       NaN       NaN      NaN  ...      NaN       NaN       NaN       NaN
#
#    AP7_4_15  CVE_ENT CVE_MUN  EDAD  ESTRATO  SEXO
# 0       NaN      9.0     2.0  65.0        3   2.0
# 1       NaN      9.0     2.0  27.0        3   2.0
# 2       NaN      9.0     2.0  57.0        3   2.0
#
# [3 rows x 131 columns]

# %%
df_copy.replace(to_replace='\r', value=np.NaN, inplace=True)

# %%
df_copy.replace(to_replace=np.NaN, value=-1, inplace=True)

# %%
df_copy.replace(to_replace=-1, value=np.NaN, inplace=True)

# %%
df_copy.replace({'0\r':0,
                 '1\r':1,
                 '2\r':2,
                 '3\r':3,
                 '4\r':4,
                 '5\r':5,
                 '6\r':6,
                 '7\r':7,
                 '8\r':8,
                 '9\r':9,
                 '99\r':99}, inplace=True)

# %%
df_copy.replace({'00\r':0,
                 '01\r':1,
                 '02\r':2,
                 '03\r':3,
                 '04\r':4,
                 '05\r':5,
                 '06\r':6,
                 '07\r':7,
                 '08\r':8,
                 '09\r':9,
                 '10\r':10,
                 '11\r':11,
                 '12\r':12,
                 '13\r':13,
                 '14\r':14,
                 '15\r':15,
                 '99\r':99,}, inplace=True)

# %%
l = []
bandera = np.NAN
for column in df_copy.columns:
    if df_copy[column].dtype == np.int64:
        bandera = 'entero'
    elif df_copy[column].dtype == np.float64:
        bandera = 'flotante'
    else:
        bandera = 'otro'
        
    try:
        df_copy[column]= df_copy[column].astype("int64")
    except:
        l.append(column)
        
    print('COLUMNA: ', column)
    print('TIPO: ', bandera)
    print('NUNIQUE: ', df_copy[column].nunique())
    print('UNIQUE: ', df_copy[column].unique())
    print('VALUE COUNTS ', df_copy[column].value_counts())
    print('\n')
# Out:
# COLUMNA:  AP6_10_1
# TIPO:  entero
# NUNIQUE:  3
# UNIQUE:  [2 1 9]
# VALUE COUNTS  2    6193
# 1       8
# 9       2
# Name: AP6_10_1, dtype: int64
#
#
# COLUMNA:  AP6_10_2
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  1.  2.]
# VALUE COUNTS  1.0    7
# 2.0    1
# Name: AP6_10_2, dtype: int64
#
#
# COLUMNA:  AP6_11_1
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  1.  2.]
# VALUE COUNTS  1.0    6
# 2.0    2
# Name: AP6_11_1, dtype: int64
#
#
# COLUMNA:  AP6_11_2
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  1.]
# VALUE COUNTS  1.0    1
# Name: AP6_11_2, dtype: int64
#
#
# COLUMNA:  AP6_11_3
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: AP6_11_3, dtype: int64)
#
#
# COLUMNA:  AP6_11_4
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: AP6_11_4, dtype: int64)
#
#
# COLUMNA:  AP6_11_5
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: AP6_11_5, dtype: int64)
#
#
# ...

# %%
l
# Out:
# ['AP6_10_2',
#  'AP6_11_1',
#  'AP6_11_2',
#  'AP6_11_3',
#  'AP6_11_4',
#  'AP6_11_5',
#  'AP6_11_6',
#  'AP6_11_7',
#  'AP6_12_1',
#  'AP6_12_2',
#  'AP6_12_3',
#  'AP6_12_4',
#  'AP6_12_5',
#  'AP6_12_6',
#  'AP6_12_7',
#  'AP6_13_1_1',
#  'AP6_13_1_2',
#  'AP6_13_1_3',
#  'AP6_13_1_4',
#  'AP6_13_2_1',
#  'AP6_13_2_2',
#  'AP6_13_2_3',
#  'AP6_13_2_4',
#  'AP6_13_3_1',
#  'AP6_13_3_2',
#  'AP6_13_3_3',
#  'AP6_13_3_4',
#  'AP6_13_4_1',
#  'AP6_13_4_2',
#  'AP6_13_4_3',
#  'AP6_13_4_4',
#  'AP6_13_5_1',
#  'AP6_13_5_2',
#  'AP6_13_5_3',
#  'AP6_13_5_4',
#  'AP6_13_6_1',
#  'AP6_13_6_2',
#  'AP6_13_6_3',
#  'AP6_13_6_4',
#  'AP6_13_7_1',
#  'AP6_13_7_2',
#  'AP6_13_7_3',
#  'AP6_13_7_4',
#  'AP6_15_2',
#  'AP6_16_1',
#  'AP6_16_2',
#  'AP6_16_3',
#  'AP6_16_4',
#  'AP6_16_5',
#  'AP6_16_6',
#  'AP6_16_7',
#  'AP6_17_1',
#  'AP6_17_2',
#  'AP6_17_3',
#  'AP6_17_4',
#  'AP6_17_5',
#  'AP6_17_6',
#  'AP6_17_7',
#  'AP6_18_1',
#  'AP6_18_2',
#  'AP6_18_3',
#  'AP6_18_4',
# ...

# %%
df_copy.shape
# Out:
# (6203, 131)

# %%
file = "../../../../../../dataframes/envipe/TPer_Vic2/df_09_concat.csv"

# %%
df_copy.to_csv(path_or_buf=file, index=False)
