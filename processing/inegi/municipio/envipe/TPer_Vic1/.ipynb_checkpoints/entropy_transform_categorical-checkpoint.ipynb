# %%
library(SpatEntropy)
library(ggplot2)
library(stats)
library(factoextra)
library(clusterCrit)
library(scatterplot3d)
# Out:
# Loading required package: spatstat
# Loading required package: spatstat.data
# Loading required package: nlme
# Loading required package: rpart
#
# spatstat 1.58-2       (nickname: ‘Not Even Wrong’)
# For an introduction to spatstat, type ‘beginner’
#
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %%
file = "../../../../../../dataframes/envipe/df_09_transform_cat_to_num.csv"

# %%
df <- read.csv(file = file)
data <- df
head(data)
# Out:
#   AP4_1 AP4_10_01 AP4_10_02 AP4_10_03 AP4_10_04 AP4_10_05 AP4_10_06 AP4_10_07
# 1 1     0.5210382 1         0.9832339 0.9098823 0.9234241 0.9900048 1.0000000
# 2 1     0.5210382 1         0.9832339 0.9098823 0.9234241 0.5595680 1.0000000
# 3 1     0.5210382 1         0.2019990 0.3121070 0.9234241 0.9900048 1.0000000
# 4 1     0.5210382 1         0.2019990 0.3121070 0.2065130 0.5595680 1.0000000
# 5 1     0.9730775 1         0.9832339 0.3121070 0.2065130 0.9900048 1.0000000
# 6 1     0.5210382 1         0.9832339 0.9098823 0.2065130 0.5595680 0.1331614
#   AP4_10_08 AP4_10_09 ⋯ AP5_3_09  AP5_3_10  AP5_4_08   AP5_4_08_C AP5_5_08
# 1 0.7580203 0.9563115 ⋯ 0.7101403 0.2315009 0.43849750 0.4642915  0.4489763
# 2 0.7580203 0.3470901 ⋯ 1.0000000 1.0000000 0.87796228 0.4642915  0.4489763
# 3 0.1188135 0.3470901 ⋯ 1.0000000 1.0000000 0.87796228 0.4481702  0.9609866
# 4 0.1188135 0.3470901 ⋯ 0.7101403 0.2315009 0.87796228 0.4481702  0.4489763
# 5 0.7580203 0.3470901 ⋯ 0.7101403 0.2315009 0.06883766 0.4481702  0.9609866
# 6 0.7580203 0.9563115 ⋯ 1.0000000 1.0000000 0.42076415 0.8305659  0.9624375
#   AP5_6_08  AP5_8     EDAD   ESTRATO  SEXO
# 1 0.3374174 0.6959536 0.5875 1.000000 1.0000000
# 2 1.0000000 0.6959536 0.1125 1.000000 1.0000000
# 3 0.8637756 0.6959536 0.4875 1.000000 1.0000000
# 4 0.8637756 1.0000000 0.5625 1.000000 0.4663872
# 5 0.3159761 0.6959536 0.5375 1.000000 0.4663872
# 6 0.8637756 0.6959536 0.0625 0.546671 1.0000000

# %%
ncol(data)
# Out:
# [1] 119

# %%
data_names <- c()
data_entropy <- c()

for (column in 1:ncol(data)) {
#    print(names(data[column]))
    entropy <- SpatEntropy::shannonX(data = matrix(data[column]))
  
  data_names <- append(x = data_names, values = names(data[column]))
  data_entropy <- append(x = data_entropy, values = entropy$shannon)
}

# %%
df_entropy <- cbind(data.frame(data_names, data_entropy)) 
head(df_entropy)
# Out:
#   data_names data_entropy
# 1 AP4_1      0.2682529
# 2 AP4_10_01  0.8028256
# 3 AP4_10_02  0.9284035
# 4 AP4_10_03  0.5940642
# 5 AP4_10_04  0.8970860
# 6 AP4_10_05  0.7744769

# %%
order_df_entropy <- df_entropy[order(df_entropy$data_entropy, decreasing = T), ]
head(order_df_entropy)
# Out:
#     data_names data_entropy
# 117 EDAD       4.145367
# 99  AP5_2_2    1.474755
# 76  AP4_7_1    1.340810
# 84  AP4_8_6    1.331879
# 98  AP5_2_1    1.319581
# 113 AP5_4_08_C 1.274367

# %%
ggplot(df_entropy, 
       aes(y=data_names, x=data_entropy)) + geom_point() + theme_light()
# Out:
# plot without title

# %%
ggplot(data = data, 
       aes(y=data$EDAD, 
           x=data$AP5_2_2)) + geom_point() + theme_light()
# Out:
# plot without title

# %%
scatterplot3d(y=data$EDAD, 
              x=data$AP5_2_2,
              z=data$AP4_7_1, pch = 19, color = "green4", main="3D Scatterplot")
# Out:
# Plot with title “3D Scatterplot”

# %%
file = "../../../../../../dataframes/envipe/df_09_entropy_transform_categorical.csv"

# %%
write.csv(order_df_entropy, 
          file = file,
          row.names=FALSE)
