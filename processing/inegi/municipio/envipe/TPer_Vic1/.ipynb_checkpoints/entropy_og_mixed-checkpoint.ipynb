# %%
library(SpatEntropy)
library(ggplot2)
library(stats)
library(factoextra)
library(clusterCrit)
library(scatterplot3d)
# Out:
# Loading required package: spatstat
# Loading required package: spatstat.data
# Loading required package: nlme
# Loading required package: rpart
#
# spatstat 1.58-2       (nickname: ‘Not Even Wrong’)
# For an introduction to spatstat, type ‘beginner’
#
# Welcome! Related Books: `Practical Guide To Cluster Analysis in R` at https://goo.gl/13EFCZ

# %%
file = "../../../../../../dataframes/envipe/df_09_impute.csv"

# %%
df <- read.csv(file = file)
data <- df
head(data)
# Out:
#   AP4_1 AP4_10_01 AP4_10_02 AP4_10_03 AP4_10_04 AP4_10_05 AP4_10_06 AP4_10_07
# 1 3     1         3         2         2         2         2         3
# 2 3     1         3         2         2         2         1         3
# 3 3     1         3         1         1         2         2         3
# 4 3     1         3         1         1         1         1         3
# 5 3     2         3         2         1         1         2         3
# 6 3     1         3         2         2         1         1         2
#   AP4_10_08 AP4_10_09 ⋯ AP5_3_09 AP5_3_10 AP5_4_08 AP5_4_08_C AP5_5_08 AP5_6_08
# 1 2         2         ⋯ 1        1        9        9          9        9
# 2 2         1         ⋯ 2        2        2        9          9        3
# 3 1         1         ⋯ 2        2        2        1          2        2
# 4 1         1         ⋯ 1        1        2        1          9        2
# 5 2         1         ⋯ 1        1        4        1          2        1
# 6 2         2         ⋯ 2        2        1        2          6        2
#   AP5_8 EDAD ESTRATO SEXO
# 1 4     65   3       2
# 2 4     27   3       2
# 3 4     57   3       2
# 4 3     63   3       1
# 5 4     61   3       1
# 6 4     23   2       2

# %%
ncol(data)
# Out:
# [1] 119

# %%
data_names <- c()
data_entropy <- c()

for (column in 1:ncol(data)) {
#    print(names(data[column]))
    entropy <- SpatEntropy::shannonX(data = matrix(data[column]))
  
  data_names <- append(x = data_names, values = names(data[column]))
  data_entropy <- append(x = data_entropy, values = entropy$shannon)
}

# %%
df_entropy <- cbind(data.frame(data_names, data_entropy)) 
head(df_entropy)
# Out:
#   data_names data_entropy
# 1 AP4_1      0.2682529
# 2 AP4_10_01  0.8028256
# 3 AP4_10_02  0.9284035
# 4 AP4_10_03  0.5940642
# 5 AP4_10_04  0.8970860
# 6 AP4_10_05  0.7744769

# %%
order_df_entropy <- df_entropy[order(df_entropy$data_entropy, decreasing = T), ]
head(order_df_entropy)
# Out:
#     data_names data_entropy
# 117 EDAD       4.145367
# 99  AP5_2_2    1.474755
# 76  AP4_7_1    1.340810
# 84  AP4_8_6    1.331879
# 98  AP5_2_1    1.319581
# 113 AP5_4_08_C 1.274367

# %%
ggplot(df_entropy, 
       aes(y=data_names, x=data_entropy)) + geom_point() + theme_light()
# Out:
# plot without title

# %%
ggplot(data = data, 
       aes(y=data$EDAD, 
           x=data$AP5_2_2)) + geom_point() + theme_light()
# Out:
# plot without title

# %%
scatterplot3d(y=data$EDAD, 
              x=data$AP5_2_2,
              z=data$AP4_7_1, pch = 19, color = "green4", main="3D Scatterplot")
# Out:
# Plot with title “3D Scatterplot”

# %%
file = "../../../../../../dataframes/envipe/df_09_og_mixed.csv"

# %%
write.csv(order_df_entropy, 
          file = "../../../../../../dataframes/enh/df_09_og_mixed.csv",
          row.names=FALSE)
