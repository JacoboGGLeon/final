# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 01

# %%
file = "../../../../../../data/inegi-encuestas/localidad/enoe/2017/2017trim1_csv/coe2t117.CSV"

# %%
df_01 = pd.read_csv(filepath_or_buffer=file, encoding='latin', low_memory=False)
df_01.head()
# Out:
#    cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  n_hog  h_mud  n_ent  \
# 0     1    9  40001  900471    101         55      2      1      0      3
# 1     1    9  40001  900471    101         55      2      1      0      3
# 2     1    9  40001  900471    101         55      2      1      0      3
# 3     1    9  40001  900471    101         80      3      1      0      3
# 4     1    9  40001  900471    101         80      3      1      0      3
#
#    ...  p11_h6  p11_m6  p11_7  p11_h7  p11_m7  p11_8  p11_h8  p11_m8  ur  fac
# 0  ...     NaN     NaN      7     1.0     0.0            NaN     NaN   1  487
# 1  ...     NaN     NaN      7    35.0     0.0            NaN     NaN   1  487
# 2  ...     NaN     NaN      7     4.0     0.0            NaN     NaN   1  487
# 3  ...     NaN     NaN      7     3.0     0.0            NaN     NaN   1  487
# 4  ...     NaN     NaN      7    36.0     0.0            NaN     NaN   1  487
#
# [5 rows x 125 columns]

# %%
df_01.shape
# Out:
# (306380, 125)

# %%
df_01[(df_01.ent == 9)].shape
# Out:
# (8073, 125)

# %%
df_01_copy = df_01[(df_01.ent == 9)].copy()

# %% [markdown]
# ## 02

# %%
file = "../../../../../../data/inegi-encuestas/localidad/enoe/2017/2017trim2_csv/coe2t217.CSV"

# %%
df_02 = pd.read_csv(filepath_or_buffer=file, encoding='latin', low_memory=False)
df_02.head()
# Out:
#    cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  n_hog  h_mud  n_ent  \
# 0     1    9  40001  900471    101         55      2      1      0      4
# 1     1    9  40001  900471    101         55      2      1      0      4
# 2     1    9  40001  900471    101         55      2      1      0      4
# 3     1    9  40001  900471    101         80      3      1      0      4
# 4     1    9  40001  900471    101         80      3      1      0      4
#
#    ...  p9_h6  p9_m6  p9_7  p9_h7  p9_m7  p9_8  p9_h8  p9_m8  ur  fac
# 0  ...    NaN    NaN          NaN    NaN          NaN    NaN   1  648
# 1  ...    NaN    NaN     7   18.0    0.0          NaN    NaN   1  648
# 2  ...    NaN    NaN     7    1.0    0.0          NaN    NaN   1  648
# 3  ...    NaN    NaN     7    7.0    0.0          NaN    NaN   1  648
# 4  ...    NaN    NaN     7    7.0    0.0          NaN    NaN   1  648
#
# [5 rows x 70 columns]

# %%
df_02.shape
# Out:
# (312033, 70)

# %%
df_02[(df_02.ent == 9)].shape
# Out:
# (8042, 70)

# %%
df_02_copy = df_02[(df_02.ent == 9)].copy()

# %% [markdown]
# ## 03

# %%
file = "../../../../../../data/inegi-encuestas/localidad/enoe/2017/2017trim3_csv/coe2t317.CSV"

# %%
df_03 = pd.read_csv(filepath_or_buffer=file, encoding='latin', low_memory=False)
df_03.head()
# Out:
#    cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  n_hog  h_mud  n_ent  \
# 0     1    9  40001  900471    101         55      2      1      0      5
# 1     1    9  40001  900471    101         55      2      1      0      5
# 2     1    9  40001  900471    101         55      2      1      0      5
# 3     1    9  40001  900471    101         80      3      1      0      5
# 4     1    9  40001  900471    101         80      3      1      0      5
#
#    ...  p9_h6  p9_m6  p9_7  p9_h7  p9_m7  p9_8  p9_h8  p9_m8  ur  fac
# 0  ...    NaN    NaN     7   10.0    0.0          NaN    NaN   1  702
# 1  ...    NaN    NaN     7   28.0    0.0          NaN    NaN   1  702
# 2  ...    NaN    NaN          NaN    NaN          NaN    NaN   1  702
# 3  ...    NaN    NaN          NaN    NaN          NaN    NaN   1  702
# 4  ...    NaN    NaN     7   42.0    0.0          NaN    NaN   1  702
#
# [5 rows x 70 columns]

# %%
df_03.shape
# Out:
# (307117, 70)

# %%
df_03[(df_03.ent == 9)].shape
# Out:
# (7772, 70)

# %%
df_03_copy = df_03[(df_03.ent == 9)].copy()

# %% [markdown]
# ## 04

# %%
file = "../../../../../../data/inegi-encuestas/localidad/enoe/2017/2017trim4_csv/coe2t417.CSV"

# %%
df_04 = pd.read_csv(filepath_or_buffer=file, encoding='latin', low_memory=False)
df_04.head()
# Out:
#    cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  n_hog  h_mud  n_ent  \
# 0     1    9  40001  900471    101          9      1      1      0      1
# 1     1    9  40001  900471    101          9      1      1      0      1
# 2     1    9  40001  900471    101          9      1      1      0      1
# 3     1    9  40001  900471    101          9      1      1      0      1
# 4     1    9  40001  900471    101         34      2      1      0      1
#
#    ...  p9_h6  p9_m6  p9_7  p9_h7  p9_m7  p9_8  p9_h8  p9_m8  ur  fac
# 0  ...    NaN    NaN          NaN    NaN          NaN    NaN   1  517
# 1  ...    NaN    NaN     7   20.0    0.0          NaN    NaN   1  517
# 2  ...    NaN    NaN     7    3.0    0.0          NaN    NaN   1  517
# 3  ...    NaN    NaN     7    3.0    0.0          NaN    NaN   1  517
# 4  ...    NaN    NaN     7    2.0    0.0          NaN    NaN   1  517
#
# [5 rows x 70 columns]

# %%
df_04.shape
# Out:
# (307759, 70)

# %%
df_04[(df_04.ent == 9)].shape
# Out:
# (7801, 70)

# %%
df_04_copy = df_04[(df_04.ent == 9)].copy()

# %% [markdown]
# ## Concat

# %%
list_columns_df_01 = list(df_01_copy.columns)
list_columns_df_02 = list(df_02_copy.columns)
list_columns_df_03 = list(df_03_copy.columns)
list_columns_df_04 = list(df_04_copy.columns)

# %%
[x for x in list_columns_df_01 if x not in list_columns_df_02]
# Out:
# []

# %%
[x for x in list_columns_df_02 if x not in list_columns_df_01]
# Out:
# []

# %%
[x for x in list_columns_df_01 if x not in list_columns_df_03]
# Out:
# []

# %%
[x for x in list_columns_df_03 if x not in list_columns_df_01]
#incorporan el ejército en septiembre y diciembre del 2016
# Out:
# []

# %%
[x for x in list_columns_df_01 if x not in list_columns_df_04]
# Out:
# []

# %%
[x for x in list_columns_df_04 if x not in list_columns_df_01]
#cambiar ENT por CVE_ENT
# Out:
# []

# %%
frames = [df_01_copy, df_02_copy, df_03_copy, df_04_copy]

# %%
df = pd.concat(frames)
# Out:
# /Users/jacoboleon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## corroborar columnas y filas

# %%
df_01_copy.shape
# Out:
# (8073, 125)

# %%
df_02_copy.shape
# Out:
# (8042, 70)

# %%
df_03_copy.shape
# Out:
# (7772, 70)

# %%
df_04_copy.shape
# Out:
# (7801, 70)

# %%
df.shape
# Out:
# (31688, 149)

# %%
df.rename(columns={'ent':'CVE_ENT',
                   'mun':'CVE_MUN', 
                   'loc': 'CVE_LOC'}, 
                  inplace=True)

# %%
#list(df.columns)

# %%
list_text = ['cd_a','con', 'upm', 'd_sem', 'n_pro_viv', 'v_sel', 'n_hog', 'h_mud', 'n_ent', 'per', 'n_ren', "CVE_ENT", "fac", "n_inf", "ur"]
df.drop(labels=list_text, axis=1, inplace=True)

# %%
df.replace(to_replace='\r',value=np.NaN,inplace=True)

# %%
df.replace(to_replace='-\r',value=np.NaN,inplace=True)

# %%
df.replace(to_replace='',value=np.NaN,inplace=True)

# %%
df.replace(to_replace=' ',value=np.NaN,inplace=True)

# %%
l = []
bandera = np.NAN
for column in df.columns:
    try:
        df[column].astype('int64')
    except:
        l.append(column)
    
    if df[column].dtype == np.int64:
        bandera = 'entero'
    elif df[column].dtype == np.float64:
        bandera = 'flotante'
    else:
        bandera = 'otro'
        
    print('COLUMNA: ', column)
    print('TIPO: ', bandera)
    print('NUNIQUE: ', df[column].nunique())
    print('UNIQUE: ', df[column].unique())
    print('VALUE COUNTS ', df[column].value_counts())
    print('\n')
# Out:
# COLUMNA:  eda
# TIPO:  entero
# NUNIQUE:  87
# UNIQUE:  [63 58 31 52 51 27 33 64 60 61 18 54 29 46 42 20 15 66 47 38 17 14 12 41
#  62 30 55 50 28 36 39 53 67 25 72 21 19 23 43 32 56 35 57 16 24 45 40 73
#  69 71 48 74 77 34 49 59 80 13 70 37 81 26 90 87 44 22 82 68 75 79 84 78
#  88 76 65 86 91 83 85 95 92 89 94 97 93 98 96]
# VALUE COUNTS  27    658
# 26    644
# 22    642
# 19    629
# 15    621
# 23    620
# 25    620
# 24    607
# 31    604
# 21    601
# 46    597
# 40    596
# 41    596
# 16    592
# 28    582
# 47    578
# 44    572
# 18    568
# 29    557
# 32    555
# 43    546
# 30    543
# 12    542
# 17    540
# 45    539
# 51    527
# 20    525
# 38    524
# 13    524
# 50    524
#      ...
# 69    241
# 70    240
# 71    217
# 73    197
# 72    183
# 75    179
# 74    176
# 80    155
# 77    145
# 76    135
# 78    133
# 79    116
# 81    109
# 82     93
# 83     83
# 84     83
# 85     68
# 86     63
# 87     49
# 89     36
# 88     35
# 90     34
# 92     22
# 91     19
# 98     16
# 95     14
# 93     10
# 94      9
# 97      3
# 96      3
# Name: eda, Length: 87, dtype: int64
#
#
# COLUMNA:  p10_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    5
# Name: p10_1, dtype: int64
#
#
# COLUMNA:  p10_2
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p10_2, dtype: int64)
#
#
# COLUMNA:  p10_3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    877
# Name: p10_3, dtype: int64
#
#
# COLUMNA:  p10_4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  ['4' nan]
# VALUE COUNTS  4    7187
# Name: p10_4, dtype: int64
#
#
# COLUMNA:  p10_9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    4
# Name: p10_9, dtype: int64
#
#
# COLUMNA:  p10a1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    15
# Name: p10a1, dtype: int64
#
#
# COLUMNA:  p10a2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    65
# Name: p10a2, dtype: int64
#
#
# COLUMNA:  p10a3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    215
# Name: p10a3, dtype: int64
#
#
# COLUMNA:  p10a4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  ['4' nan]
# VALUE COUNTS  4    7783
# Name: p10a4, dtype: int64
#
#
# COLUMNA:  p10a9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    3
# Name: p10a9, dtype: int64
#
#
# COLUMNA:  p10b
# TIPO:  flotante
# NUNIQUE:  3
# UNIQUE:  [ 1.  2.  9. nan]
# VALUE COUNTS  2.0    6430
# 1.0    1633
# 9.0      10
# Name: p10b, dtype: int64
#
#
# COLUMNA:  p11_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    1358
# Name: p11_1, dtype: int64
#
#
# COLUMNA:  p11_2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    1606
# Name: p11_2, dtype: int64
#
#
# COLUMNA:  p11_3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  ['3' nan]
# VALUE COUNTS  3    4751
# Name: p11_3, dtype: int64
#
#
# COLUMNA:  p11_4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    909
# Name: p11_4, dtype: int64
#
#
# COLUMNA:  p11_5
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '5']
# VALUE COUNTS  5    14
# Name: p11_5, dtype: int64
#
#
# COLUMNA:  p11_6
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '6']
# VALUE COUNTS  6    257
# Name: p11_6, dtype: int64
#
#
# COLUMNA:  p11_7
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  ['7' nan]
# VALUE COUNTS  7    6768
# Name: p11_7, dtype: int64
#
#
# COLUMNA:  p11_8
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '8']
# VALUE COUNTS  8    43
# Name: p11_8, dtype: int64
#
#
# COLUMNA:  p11_h1
# TIPO:  flotante
# NUNIQUE:  54
# UNIQUE:  [nan 20.  9. 12. 10. 35. 40. 45. 25. 15.  5.  7. 60. 98. 44. 30. 50. 14.
#  48.  2. 42. 46.  6. 38. 43. 52. 36. 24.  8. 29. 55.  4. 47. 41. 65. 16.
#  18. 28. 32. 70. 49. 33. 21. 39. 34. 26. 27.  1. 56.  3. 84. 72. 31. 37.
#  13.]
# VALUE COUNTS  40.0    308
# 45.0    146
# 50.0    143
# 35.0    112
# 30.0     96
# 60.0     49
# 20.0     48
# 10.0     38
# 38.0     37
# 25.0     30
# 42.0     28
# 48.0     27
# 55.0     27
# 15.0     22
# 5.0      17
# 8.0      16
# 32.0     15
# 43.0     12
# 28.0     12
# 36.0     11
# 14.0     10
# 46.0      9
# 4.0       9
# 29.0      8
# 6.0       8
# 70.0      7
# 2.0       7
# 18.0      7
# 12.0      7
# 44.0      6
# 9.0       6
# 52.0      6
# 39.0      6
# 34.0      6
# 7.0       5
# 21.0      5
# 24.0      5
# 26.0      5
# 47.0      5
# 16.0      4
# 33.0      4
# 49.0      4
# 1.0       3
# 3.0       3
# 41.0      3
# 65.0      3
# 56.0      3
# 98.0      3
# 27.0      2
# 72.0      1
# 84.0      1
# 31.0      1
# 37.0      1
# 13.0      1
# Name: p11_h1, dtype: int64
#
#
# COLUMNA:  p11_h2
# TIPO:  flotante
# NUNIQUE:  53
# UNIQUE:  [nan 30. 10.  7. 42. 40.  4. 12. 14. 70.  6. 15. 60. 20. 25. 21. 56.  5.
#  35.  8.  2. 18. 50. 47. 36.  3. 45. 66. 55. 98.  9. 24.  1. 28. 11. 16.
#  32. 46. 33. 69. 48. 41. 38. 22. 29. 52. 49. 26. 62. 58. 84. 39. 13. 19.]
# VALUE COUNTS  14.0    217
# 10.0    164
# 7.0     127
# 21.0    124
# 20.0    110
# 35.0     77
# 30.0     67
# 15.0     64
# 5.0      61
# 12.0     47
# 25.0     45
# 28.0     44
# 3.0      43
# 2.0      43
# 40.0     41
# 8.0      34
# 6.0      31
# 4.0      29
# 50.0     28
# 18.0     26
# 1.0      19
# 45.0     18
# 9.0      17
# 16.0     15
# 60.0     14
# 24.0     12
# 42.0     11
# 70.0      9
# 98.0      9
# 32.0      7
# 36.0      6
# 56.0      5
# 48.0      5
# 38.0      5
# 52.0      4
# 11.0      3
# 22.0      3
# 47.0      3
# 55.0      2
# 46.0      2
# 41.0      2
# 49.0      2
# 33.0      1
# 26.0      1
# 62.0      1
# 84.0      1
# 66.0      1
# 19.0      1
# 39.0      1
# 29.0      1
# 13.0      1
# 69.0      1
# 58.0      1
# Name: p11_h2, dtype: int64
#
#
# COLUMNA:  p11_h3
# TIPO:  flotante
# NUNIQUE:  24
# UNIQUE:  [ 1.  5.  2. nan  3.  6.  4. 14.  7.  8. 10. 12.  9. 11. 21. 98.  0. 99.
#  24. 25. 16. 20. 15. 30. 18.]
# VALUE COUNTS  2.0     1356
# 3.0     1058
# 1.0      647
# 4.0      579
# 5.0      454
# 7.0      212
# 6.0      212
# 8.0       67
# 10.0      51
# 98.0      35
# 9.0       26
# 0.0       17
# 12.0      14
# 14.0      10
# 15.0       2
# 99.0       2
# 16.0       2
# 18.0       1
# 24.0       1
# 11.0       1
# 30.0       1
# 20.0       1
# 21.0       1
# 25.0       1
# Name: p11_h3, dtype: int64
#
#
# COLUMNA:  p11_h4
# TIPO:  flotante
# NUNIQUE:  19
# UNIQUE:  [nan  3.  2.  5.  4. 15.  6.  1. 10. 14. 49.  7. 30. 20. 12.  0.  9. 98.
#   8. 48.]
# VALUE COUNTS  2.0     257
# 3.0     193
# 5.0     181
# 1.0     132
# 4.0      62
# 10.0     26
# 6.0      16
# 7.0      14
# 0.0      10
# 8.0       3
# 15.0      3
# 20.0      3
# 98.0      2
# 12.0      2
# 9.0       1
# 49.0      1
# 30.0      1
# 14.0      1
# 48.0      1
# Name: p11_h4, dtype: int64
#
#
# COLUMNA:  p11_h5
# TIPO:  flotante
# NUNIQUE:  7
# UNIQUE:  [nan  1.  4.  2. 25. 15.  8.  3.]
# VALUE COUNTS  2.0     5
# 1.0     3
# 4.0     2
# 15.0    1
# 25.0    1
# 3.0     1
# 8.0     1
# Name: p11_h5, dtype: int64
#
#
# COLUMNA:  p11_h6
# TIPO:  flotante
# NUNIQUE:  16
# UNIQUE:  [nan  3.  1.  2.  4.  0.  5.  7.  6. 10. 20. 14.  8. 25. 40. 18.  9.]
# VALUE COUNTS  2.0     71
# 1.0     59
# 3.0     41
# 5.0     28
# 4.0     18
# 6.0      8
# 7.0      7
# 10.0     6
# 8.0      6
# 14.0     3
# 20.0     3
# 25.0     2
# 0.0      2
# 9.0      1
# 18.0     1
# 40.0     1
# Name: p11_h6, dtype: int64
#
#
# COLUMNA:  p11_h7
# TIPO:  flotante
# NUNIQUE:  58
# UNIQUE:  [ 1. 35.  4.  3. 36.  2.  6.  7.  9. 20.  8. 15. 10.  5. 12. nan 25. 21.
#  14. 30. 18. 38. 28. 40. 19. 31. 16. 11. 26. 22. 42. 56. 13. 98.  0. 44.
#  50. 45. 58. 70. 24. 49. 17. 41. 27. 99. 32. 60. 48. 34. 54. 29. 23. 33.
#  52. 37. 66. 64. 51.]
# VALUE COUNTS  7.0     813
# 14.0    673
# 2.0     619
# 21.0    527
# 3.0     452
# 5.0     437
# 10.0    402
# 28.0    277
# 20.0    274
# 1.0     274
# 4.0     267
# 15.0    194
# 35.0    182
# 6.0     173
# 30.0    144
# 8.0     137
# 12.0    113
# 18.0    113
# 25.0    111
# 9.0     108
# 16.0     54
# 40.0     47
# 42.0     45
# 56.0     42
# 98.0     40
# 24.0     32
# 22.0     30
# 26.0     24
# 32.0     19
# 11.0     16
# 36.0     13
# 19.0     12
# 17.0      9
# 38.0      9
# 29.0      9
# 48.0      8
# 0.0       6
# 50.0      6
# 49.0      6
# 70.0      5
# 13.0      5
# 34.0      5
# 27.0      5
# 45.0      4
# 58.0      4
# 99.0      4
# 23.0      3
# 60.0      3
# 41.0      2
# 31.0      2
# 37.0      2
# 51.0      1
# 44.0      1
# 66.0      1
# 33.0      1
# 64.0      1
# 52.0      1
# 54.0      1
# Name: p11_h7, dtype: int64
#
#
# COLUMNA:  p11_h8
# TIPO:  flotante
# NUNIQUE:  14
# UNIQUE:  [nan  1.  6.  2.  3. 20.  5.  8.  7.  4. 14. 10. 15. 48. 40.]
# VALUE COUNTS  5.0     5
# 2.0     5
# 7.0     4
# 20.0    4
# 4.0     4
# 3.0     4
# 14.0    3
# 8.0     3
# 6.0     3
# 15.0    2
# 10.0    2
# 1.0     2
# 40.0    1
# 48.0    1
# Name: p11_h8, dtype: int64
#
#
# COLUMNA:  p11_m1
# TIPO:  flotante
# NUNIQUE:  4
# UNIQUE:  [nan  0.  3. 30. 33.]
# VALUE COUNTS  0.0     1353
# 30.0       3
# 33.0       1
# 3.0        1
# Name: p11_m1, dtype: int64
#
#
# COLUMNA:  p11_m2
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     1601
# 30.0       5
# Name: p11_m2, dtype: int64
#
#
# COLUMNA:  p11_m3
# TIPO:  flotante
# NUNIQUE:  8
# UNIQUE:  [ 0. nan 30. 50. 20.  7. 15. 40.  8.]
# VALUE COUNTS  0.0     4614
# 30.0     130
# 50.0       2
# 40.0       1
# 15.0       1
# 20.0       1
# 7.0        1
# 8.0        1
# Name: p11_m3, dtype: int64
#
#
# COLUMNA:  p11_m4
# TIPO:  flotante
# NUNIQUE:  8
# UNIQUE:  [nan  0. 30. 40. 45. 35. 50. 20. 22.]
# VALUE COUNTS  0.0     773
# 30.0    111
# 45.0      8
# 50.0      8
# 40.0      5
# 35.0      2
# 22.0      1
# 20.0      1
# Name: p11_m4, dtype: int64
#
#
# COLUMNA:  p11_m5
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     13
# 30.0     1
# Name: p11_m5, dtype: int64
#
#
# COLUMNA:  p11_m6
# TIPO:  flotante
# NUNIQUE:  3
# UNIQUE:  [nan  0. 30. 32.]
# VALUE COUNTS  0.0     249
# 30.0      7
# 32.0      1
# Name: p11_m6, dtype: int64
#
#
# COLUMNA:  p11_m7
# TIPO:  flotante
# NUNIQUE:  4
# UNIQUE:  [ 0. 30. nan  1. 20.]
# VALUE COUNTS  0.0     6700
# 30.0      64
# 20.0       2
# 1.0        2
# Name: p11_m7, dtype: int64
#
#
# COLUMNA:  p11_m8
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  0.]
# VALUE COUNTS  0.0    43
# Name: p11_m8, dtype: int64
#
#
# COLUMNA:  p6_1
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  1.]
# VALUE COUNTS  1.0    776
# Name: p6_1, dtype: int64
#
#
# COLUMNA:  p6_10
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 10.]
# VALUE COUNTS  10.0    1245
# Name: p6_10, dtype: int64
#
#
# COLUMNA:  p6_2
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  2.]
# VALUE COUNTS  2.0    704
# Name: p6_2, dtype: int64
#
#
# COLUMNA:  p6_3
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  3.]
# VALUE COUNTS  3.0    184
# Name: p6_3, dtype: int64
#
#
# COLUMNA:  p6_4
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  4.]
# VALUE COUNTS  4.0    308
# Name: p6_4, dtype: int64
#
#
# COLUMNA:  p6_5
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  5.]
# VALUE COUNTS  5.0    41
# Name: p6_5, dtype: int64
#
#
# COLUMNA:  p6_6
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  6.]
# VALUE COUNTS  6.0    96
# Name: p6_6, dtype: int64
#
#
# COLUMNA:  p6_7
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  7.]
# VALUE COUNTS  7.0    10747
# Name: p6_7, dtype: int64
#
#
# COLUMNA:  p6_8
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [ 8. nan]
# VALUE COUNTS  8.0    3020
# Name: p6_8, dtype: int64
#
#
# COLUMNA:  p6_9
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  9.]
# VALUE COUNTS  9.0    357
# Name: p6_9, dtype: int64
#
#
# COLUMNA:  p6_99
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 99.]
# VALUE COUNTS  99.0    3
# Name: p6_99, dtype: int64
#
#
# COLUMNA:  p6a1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    1389
# Name: p6a1, dtype: int64
#
#
# COLUMNA:  p6a2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    491
# Name: p6a2, dtype: int64
#
#
# COLUMNA:  p6a3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    1
# Name: p6a3, dtype: int64
#
#
# COLUMNA:  p6a4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    1454
# Name: p6a4, dtype: int64
#
#
# COLUMNA:  p6a9
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p6a9, dtype: int64)
#
#
# COLUMNA:  p6b1
# TIPO:  otro
# NUNIQUE:  8
# UNIQUE:  ['4' nan '7' '8' '2' '3' '1' '5' '6']
# VALUE COUNTS  7    5744
# 3    3162
# 2    2783
# 8    2710
# 4    1731
# 1     924
# 6      23
# 5      22
# Name: p6b1, dtype: int64
#
#
# COLUMNA:  p6b2
# TIPO:  flotante
# NUNIQUE:  343
# UNIQUE:  [3.2250e+03        nan 2.2000e+04 6.4000e+03 5.3750e+03 7.7400e+03
#  6.4500e+03 3.8700e+03 5.1600e+03 4.0000e+03 3.0960e+03 6.0000e+03
#  1.5000e+04 8.0000e+03 4.3000e+03 1.9350e+03 1.2470e+04 1.1000e+04
#  1.2000e+04 2.0000e+04 3.0000e+04 1.0750e+04 1.2900e+03 8.6000e+03
#  3.0000e+03 2.5800e+03 1.7200e+04 3.4400e+03 3.6550e+03 4.5150e+03
#  3.0100e+03 1.8000e+04 4.4000e+03 1.6000e+04 5.0000e+03 5.6000e+03
#  2.1500e+03 7.6000e+03 7.2000e+03 6.8800e+03 4.7300e+03 1.2900e+04
#  3.8680e+03 4.5000e+03 2.5000e+03 7.0000e+03 1.6000e+03 1.7200e+03
#  1.0000e+04 1.0750e+03 2.5000e+04 1.4000e+04 2.3400e+03 1.3760e+03
#  4.0000e+02 4.2000e+03 2.8000e+03 4.8000e+03 1.5050e+04 1.9000e+04
#  9.0000e+03 8.6000e+02 5.6760e+03 1.0320e+04 5.4000e+03 5.1600e+02
#  5.0000e+04 2.0000e+03 6.2000e+03 6.4600e+03 4.6000e+03 7.4000e+03
#  9.4880e+03 1.0000e+03 7.5000e+03 3.4000e+03 1.5480e+03 1.6600e+04
#  3.2000e+03 3.5000e+03 5.5900e+03 3.6000e+03 6.4500e+02 1.0500e+04
#  2.5800e+04 2.6000e+04 3.5000e+04 6.8000e+03 2.4000e+03 1.8000e+03
#  6.0000e+02 1.2040e+04 9.6750e+03 9.0300e+03 8.0000e+02 2.4000e+04
#  1.2000e+03 5.5000e+03 4.3000e+04 7.0000e+04 2.3220e+03 2.0640e+03
#  2.2000e+03 2.6000e+03 1.0600e+04 1.0200e+04 4.0850e+03 2.4600e+03
#  2.0000e+02 1.3000e+04 9.6000e+03 7.8000e+03 2.1000e+03 3.7000e+03
#  1.1200e+04 2.1500e+04 4.0000e+04 4.3000e+02 1.2600e+04 6.0200e+02
#  1.8060e+03 1.3003e+04 8.2400e+03 9.4600e+03 1.3660e+04 3.5050e+03
#  3.8000e+04 3.1180e+03 2.7000e+04 3.2160e+03 1.5050e+03 7.7000e+03
#  1.4500e+04 5.2000e+03 6.0000e+04 8.0000e+04 1.7000e+03 1.6800e+04
#  7.3100e+03 3.3540e+03 9.1000e+03 1.4000e+03 3.6000e+04 3.5475e+04
#  3.5900e+03 5.8050e+03 1.0800e+03 6.5000e+03 7.0000e+02 5.8000e+03
#  6.0200e+03 8.1700e+03 3.7840e+03 1.1610e+04 2.7950e+03 1.0320e+03
#  2.3650e+03 6.4300e+03 5.0000e+02 1.1825e+04 1.5000e+03 6.2350e+03
#  5.4500e+03 3.8000e+03 1.1800e+04 1.1100e+04 1.4400e+04 2.8000e+04
#  8.4000e+03 3.1600e+03 9.8900e+03 6.5500e+03 1.2500e+04 1.2440e+04
#  3.0960e+04 3.0200e+03 6.1500e+03 1.5000e+02 1.9750e+03 6.6000e+03
#  2.9400e+03 9.4000e+03 3.2250e+04 7.3100e+02 6.8800e+02 5.3000e+03
#  7.0950e+03 3.6120e+03 2.1560e+03 3.0000e+02 1.7000e+04 7.5250e+03
#  9.5000e+03 2.9000e+03 2.6100e+03 2.3220e+04 3.8570e+03 3.6980e+03
#  9.0000e+02 1.6340e+04 3.0100e+04 4.1500e+03 4.2140e+03 9.2000e+03
#  4.0400e+03 4.2400e+03 3.2700e+04 4.5000e+04 5.9000e+03 4.9440e+03
#  7.5000e+04 7.9000e+03 9.0000e+04 4.8700e+03 3.4000e+04 8.0710e+03
#  3.9000e+03 3.8270e+03 9.0340e+03 2.7950e+04 4.6440e+03 1.5960e+03
#  7.3000e+03 4.9000e+03 5.8900e+03 2.1500e+02 1.3600e+03 1.2900e+02
#  6.4500e+04 1.3760e+04 2.7000e+03 2.5800e+02 8.7000e+03 2.9670e+03
#  7.9550e+03 9.8000e+03 3.2800e+02 9.0050e+03 5.6700e+03 8.2000e+03
#  6.7400e+02 4.1280e+03 1.5910e+03 1.8600e+04 5.0200e+03 5.1500e+03
#  4.3860e+03 2.8380e+03 1.0400e+04 2.2360e+03 1.1400e+04 4.3400e+03
#  1.6000e+05 2.9700e+03 1.0900e+04 6.8700e+03 9.0100e+03 1.5480e+04
#  7.7400e+02 3.2400e+03 4.8160e+03 4.4000e+04 1.2400e+04 1.1180e+04
#  7.2240e+03 1.4800e+04 1.9000e+03 1.1600e+04 2.5400e+02 3.7500e+03
#  3.4500e+03 5.9340e+03 8.0840e+03 5.3400e+03 4.1000e+03 8.5000e+03
#  5.5040e+03 5.6160e+03 3.3400e+03 6.3700e+03 3.0100e+02 5.1000e+03
#  1.5800e+03 2.2500e+03 4.8020e+03 3.8700e+04 3.5690e+03 7.4820e+03
#  2.1000e+04 1.8001e+04 9.0300e+02 6.9000e+03 6.4200e+03 1.5800e+04
#  1.0000e+05 1.1670e+04 3.4400e+02 9.7800e+03 1.6500e+04 2.9930e+03
#  1.5000e+05 9.8000e+02 1.2040e+03 5.6800e+03 7.7406e+04 3.4400e+04
#  1.8920e+03 9.4600e+02 3.8700e+02 1.1180e+03 4.9450e+03 2.4000e+02
#  1.7200e+02 4.5000e+02 2.0640e+04 7.5000e+02 7.4500e+03 1.5200e+04
#  1.3500e+04 9.0240e+03 1.8060e+04 3.4406e+04 4.1670e+03 1.4330e+03
#  1.0800e+04 4.1560e+03 2.3000e+04 3.1390e+04 4.2310e+03 1.8350e+03
#  1.2700e+04 8.6000e+01 1.9400e+04 5.7000e+03 8.0200e+03 4.9020e+03
#  1.2700e+03 6.8000e+04 3.0700e+03 5.5000e+02 4.6000e+04 4.4840e+03
#  4.9300e+03 1.9350e+04]
# VALUE COUNTS  4300.0     604
# 5160.0     499
# 6450.0     476
# 6000.0     457
# 10000.0    320
# 2580.0     319
# 8000.0     285
# 3870.0     272
# 5000.0     265
# 4000.0     246
# 3440.0     237
# 2150.0     222
# 8600.0     221
# 7000.0     208
# 3000.0     182
# 12000.0    180
# 1290.0     145
# 7740.0     118
# 20000.0    112
# 3010.0     110
# 1720.0     109
# 9000.0     101
# 4730.0      98
# 15000.0     97
# 16000.0     93
# 5590.0      93
# 860.0       82
# 12900.0     77
# 30000.0     73
# 10750.0     70
#           ...
# 2900.0       1
# 4484.0       1
# 15200.0      1
# 18001.0      1
# 4150.0       1
# 32700.0      1
# 4944.0       1
# 7482.0       1
# 1596.0       1
# 3868.0       1
# 3216.0       1
# 16340.0      1
# 6550.0       1
# 3160.0       1
# 14500.0      1
# 9034.0       1
# 1433.0       1
# 8084.0       1
# 31390.0      1
# 75000.0      1
# 4816.0       1
# 3569.0       1
# 1360.0       1
# 1835.0       1
# 14400.0      1
# 27950.0      1
# 8240.0       1
# 2340.0       1
# 4167.0       1
# 12400.0      1
# Name: p6b2, Length: 343, dtype: int64
#
#
# COLUMNA:  p6c
# TIPO:  otro
# NUNIQUE:  9
# UNIQUE:  [nan '5' '4' '3' '2' '9' '1' '8' '6' '7']
# VALUE COUNTS  8    2010
# 3    1743
# 4    1328
# 9    1206
# 5     844
# 2     708
# 1     305
# 6     230
# 7      80
# Name: p6c, dtype: int64
#
#
# COLUMNA:  p6d
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  ['6' nan '3' '1' '9' '2' '4' '5']
# VALUE COUNTS  6    9641
# 1    5735
# 3    1784
# 5     102
# 2      94
# 4      61
# 9      40
# Name: p6d, dtype: int64
#
#
# COLUMNA:  p7
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  ['7' nan '5' '2' '3' '6' '1' '4']
# VALUE COUNTS  7    16987
# 5      191
# 1      123
# 2      115
# 6       27
# 4        9
# 3        5
# Name: p7, dtype: int64
#
#
# COLUMNA:  p7a
# TIPO:  flotante
# NUNIQUE:  130
# UNIQUE:  [  nan 9611. 2712. 9643. 2716. 5221. 2412. 2551. 2512. 4211. 6111. 5116.
#  5114. 4224. 2655. 9235. 9512. 5112. 3113. 2261. 2263. 9633. 2630. 5312.
#  2321. 5254. 4311. 2641. 2322. 1421. 7221. 2524. 5212. 7515. 2643. 9631.
#  9601. 2332. 1411. 3131. 8342. 2174. 9521. 2651. 2532. 4111. 5222. 2162.
#  5101. 7513. 2335. 2821. 9621. 2142. 9411. 2173. 6116. 2642. 2411. 2713.
#  7135. 2223. 2221. 7514. 9642. 2331. 2714. 7341. 4312. 3115. 2342. 2646.
#  6112. 1223. 7342. 7121. 2171. 2711. 2543. 5211. 9231. 7133. 8351. 4221.
#  9623. 4222. 7214. 1623. 5213. 8161. 5313. 1122. 3132. 5115. 9661. 7517.
#  5111. 2544. 5242. 1211. 2653. 2341. 8344. 9111. 2121. 3211. 7213. 2531.
#  9663. 2636. 2172. 1212. 8341. 2825. 7332. 7311. 7134. 2232. 3142. 2312.
#  4223. 2111. 4231. 9321. 3212. 2552. 2135. 2163. 2112. 2541. 2511.]
# VALUE COUNTS  9611.0    34
# 4224.0    30
# 4111.0    28
# 2321.0    22
# 4211.0    21
# 9521.0    19
# 9512.0    17
# 8342.0    15
# 5114.0    10
# 2322.0     8
# 2711.0     7
# 5116.0     7
# 2332.0     7
# 2335.0     6
# 7121.0     6
# 1411.0     6
# 7341.0     6
# 2716.0     6
# 9411.0     6
# 7513.0     5
# 9643.0     5
# 2331.0     5
# 2712.0     5
# 5112.0     5
# 2142.0     5
# 4222.0     4
# 7134.0     4
# 5222.0     4
# 7135.0     4
# 2512.0     4
#           ..
# 8351.0     1
# 3113.0     1
# 7517.0     1
# 2511.0     1
# 2263.0     1
# 2636.0     1
# 2112.0     1
# 7311.0     1
# 2630.0     1
# 1122.0     1
# 2524.0     1
# 5312.0     1
# 9601.0     1
# 6116.0     1
# 2111.0     1
# 3132.0     1
# 3131.0     1
# 2232.0     1
# 2173.0     1
# 9623.0     1
# 5221.0     1
# 9631.0     1
# 9633.0     1
# 2223.0     1
# 5213.0     1
# 9642.0     1
# 2642.0     1
# 7332.0     1
# 2541.0     1
# 3142.0     1
# Name: p7a, Length: 130, dtype: int64
#
#
# COLUMNA:  p7b
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '3' '2' '1']
# VALUE COUNTS  2    265
# 1    162
# 3     43
# Name: p7b, dtype: int64
#
#
# COLUMNA:  p7c
# TIPO:  flotante
# NUNIQUE:  67
# UNIQUE:  [  nan 8140. 6141. 8121. 6211. 5120. 5411. 4611. 1110. 7221. 4690. 5414.
#  3150. 4632. 6222. 9313. 8122. 9312. 6132. 5310. 2382. 6111. 3320. 9314.
#  8112. 4850. 6221. 8130. 7114. 7222. 6112. 6122. 4662. 4661. 7111. 4631.
#  6131. 4651. 5322. 4681. 8111. 7131. 3140. 4612. 7112. 4672. 2361. 5150.
#  5611. 5613. 3230. 4310. 3110. 5240. 5614. 5620. 2363. 3120. 4652. 1130.
#  5110. 3310. 4840. 2381. 4641. 5413. 4881. 5170.]
# VALUE COUNTS  8140.0    43
# 7221.0    36
# 4690.0    30
# 8121.0    19
# 4850.0    18
# 5411.0    18
# 6141.0    17
# 4611.0    17
# 6132.0    16
# 2382.0    16
# 6112.0    15
# 7222.0    14
# 4631.0    13
# 4661.0    13
# 6111.0    13
# 6211.0    13
# 4612.0    12
# 4662.0    10
# 6131.0    10
# 8112.0     8
# 5310.0     6
# 3150.0     6
# 1110.0     6
# 6222.0     5
# 5414.0     5
# 4632.0     5
# 9314.0     4
# 5240.0     4
# 3110.0     4
# 5120.0     4
#           ..
# 4310.0     3
# 2361.0     3
# 9312.0     2
# 5614.0     2
# 5620.0     2
# 5613.0     2
# 4641.0     2
# 4840.0     2
# 6221.0     2
# 4652.0     2
# 7114.0     2
# 8130.0     2
# 4681.0     2
# 3230.0     2
# 5170.0     1
# 4672.0     1
# 2363.0     1
# 4881.0     1
# 1130.0     1
# 5611.0     1
# 5150.0     1
# 6122.0     1
# 2381.0     1
# 5413.0     1
# 3310.0     1
# 5110.0     1
# 7112.0     1
# 3120.0     1
# 9313.0     1
# 8122.0     1
# Name: p7c, Length: 67, dtype: int64
#
#
# COLUMNA:  p7d
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '4' '2' '1']
# VALUE COUNTS  4    109
# 2     13
# 1      6
# Name: p7d, dtype: int64
#
#
# COLUMNA:  p7e
# TIPO:  flotante
# NUNIQUE:  12
# UNIQUE:  [nan  1.  2. 99.  3.  9. 11. 10.  4.  5.  6.  7.  8.]
# VALUE COUNTS  1.0     47
# 2.0     46
# 11.0     9
# 4.0      5
# 9.0      4
# 8.0      4
# 3.0      4
# 7.0      3
# 5.0      2
# 6.0      2
# 99.0     1
# 10.0     1
# Name: p7e, dtype: int64
#
#
# COLUMNA:  p7f
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '1' '2']
# VALUE COUNTS  1    112
# 2     16
# Name: p7f, dtype: int64
#
#
# COLUMNA:  p7f_dias
# TIPO:  otro
# NUNIQUE:  8
# UNIQUE:  [nan '2' '5' '4' '3' '1' '6' '9' '7']
# VALUE COUNTS  2    27
# 1    21
# 3    20
# 5    19
# 7    10
# 6     7
# 4     7
# 9     1
# Name: p7f_dias, dtype: int64
#
#
# COLUMNA:  p7f_horas
# TIPO:  flotante
# NUNIQUE:  27
# UNIQUE:  [nan 16.  5.  4. 15.  3.  8. 10.  9. 24.  6.  7. 40.  2. 99. 12. 18. 30.
#  14. 56. 36. 20. 13.  1. 28. 42. 25. 35.]
# VALUE COUNTS  6.0     17
# 4.0     14
# 10.0    11
# 8.0     10
# 12.0     7
# 3.0      5
# 9.0      5
# 14.0     4
# 5.0      4
# 2.0      4
# 30.0     3
# 20.0     3
# 7.0      3
# 18.0     3
# 24.0     2
# 40.0     2
# 16.0     2
# 25.0     2
# 15.0     2
# 35.0     2
# 1.0      1
# 13.0     1
# 56.0     1
# 28.0     1
# 42.0     1
# 99.0     1
# 36.0     1
# Name: p7f_horas, dtype: int64
#
#
# COLUMNA:  p7g1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    85
# Name: p7g1, dtype: int64
#
#
# COLUMNA:  p7g2
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p7g2, dtype: int64)
#
#
# COLUMNA:  p7g3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    13
# Name: p7g3, dtype: int64
#
#
# COLUMNA:  p7g9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    30
# Name: p7g9, dtype: int64
#
#
# COLUMNA:  p7gcan
# TIPO:  flotante
# NUNIQUE:  33
# UNIQUE:  [   nan  3200.  5000.   600.   400.  1500.  2000.  3000.  2191.  1200.
#   1000.   800.  3440.  1600.   300. 40000.  6000.  4000.   500.  4800.
#    700.   480. 15000.  8000.  2800.  2500.   340.  3500.  7000.  4500.
#  10000.  1800.  9000.   900.]
# VALUE COUNTS  2000.0     14
# 1000.0      8
# 1500.0      6
# 5000.0      5
# 800.0       5
# 4000.0      4
# 3000.0      4
# 6000.0      3
# 600.0       3
# 300.0       3
# 2500.0      2
# 1600.0      2
# 400.0       2
# 2191.0      2
# 10000.0     2
# 1200.0      2
# 8000.0      2
# 9000.0      1
# 7000.0      1
# 1800.0      1
# 500.0       1
# 15000.0     1
# 3500.0      1
# 2800.0      1
# 4500.0      1
# 700.0       1
# 900.0       1
# 40000.0     1
# 480.0       1
# 4800.0      1
# 3440.0      1
# 340.0       1
# 3200.0      1
# Name: p7gcan, dtype: int64
#
#
# COLUMNA:  p8_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    14
# Name: p8_1, dtype: int64
#
#
# COLUMNA:  p8_2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    500
# Name: p8_2, dtype: int64
#
#
# COLUMNA:  p8_3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    39
# Name: p8_3, dtype: int64
#
#
# COLUMNA:  p8_4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  ['4' nan]
# VALUE COUNTS  4    16904
# Name: p8_4, dtype: int64
#
#
# COLUMNA:  p8_9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    6
# Name: p8_9, dtype: int64
#
#
# COLUMNA:  p8a
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [nan '1' '3' '4' '2']
# VALUE COUNTS  3    199
# 1    131
# 4    120
# 2    100
# Name: p8a, dtype: int64
#
#
# COLUMNA:  p8b
# TIPO:  flotante
# NUNIQUE:  8
# UNIQUE:  [nan  2.  3.  4.  1.  7.  5.  6.  9.]
# VALUE COUNTS  3.0    12
# 2.0    12
# 5.0     5
# 1.0     3
# 6.0     2
# 4.0     2
# 7.0     1
# 9.0     1
# Name: p8b, dtype: int64
#
#
# COLUMNA:  p9
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  ['2' nan '1' '9']
# VALUE COUNTS  2    3210
# 1    1261
# 9       8
# Name: p9, dtype: int64
#
#
# COLUMNA:  p9_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    3855
# Name: p9_1, dtype: int64
#
#
# COLUMNA:  p9_2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    4713
# Name: p9_2, dtype: int64
#
#
# COLUMNA:  p9_3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    13748
# Name: p9_3, dtype: int64
#
#
# COLUMNA:  p9_4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    2505
# Name: p9_4, dtype: int64
#
#
# COLUMNA:  p9_5
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '5']
# VALUE COUNTS  5    30
# Name: p9_5, dtype: int64
#
#
# COLUMNA:  p9_6
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '6']
# VALUE COUNTS  6    886
# Name: p9_6, dtype: int64
#
#
# COLUMNA:  p9_7
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '7']
# VALUE COUNTS  7    19698
# Name: p9_7, dtype: int64
#
#
# COLUMNA:  p9_8
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '8']
# VALUE COUNTS  8    138
# Name: p9_8, dtype: int64
#
#
# COLUMNA:  p9_h1
# TIPO:  flotante
# NUNIQUE:  64
# UNIQUE:  [nan 40. 52. 46. 50. 36. 35.  3. 30. 32. 45. 15. 42. 43. 80. 20. 25.  1.
#  60. 28. 21. 70.  6.  5. 10. 38. 14.  8. 48. 44. 34.  4. 55. 58. 56. 24.
#  65. 12.  2.  9. 98. 33. 39. 72. 84. 16. 26. 75.  7. 22. 27. 29. 17. 41.
#  47. 49. 54. 37. 18. 62. 66. 11. 13. 19. 90.]
# VALUE COUNTS  40.0    751
# 45.0    411
# 50.0    361
# 35.0    333
# 30.0    289
# 10.0    136
# 20.0    133
# 60.0    114
# 38.0     95
# 25.0     82
# 42.0     76
# 15.0     74
# 5.0      68
# 28.0     57
# 48.0     55
# 55.0     51
# 8.0      49
# 32.0     46
# 36.0     45
# 12.0     41
# 46.0     37
# 6.0      33
# 3.0      33
# 44.0     31
# 26.0     28
# 4.0      27
# 39.0     26
# 14.0     26
# 2.0      25
# 70.0     21
#        ...
# 47.0     18
# 21.0     16
# 7.0      15
# 16.0     14
# 49.0     14
# 52.0     12
# 98.0     12
# 34.0     12
# 37.0     11
# 56.0     11
# 33.0     11
# 18.0      9
# 22.0      8
# 27.0      7
# 58.0      7
# 1.0       7
# 66.0      6
# 72.0      5
# 54.0      4
# 65.0      4
# 62.0      4
# 75.0      3
# 29.0      3
# 13.0      2
# 17.0      2
# 80.0      2
# 84.0      2
# 19.0      1
# 11.0      1
# 90.0      1
# Name: p9_h1, Length: 64, dtype: int64
#
#
# COLUMNA:  p9_h2
# TIPO:  flotante
# NUNIQUE:  63
# UNIQUE:  [nan  2. 21. 30. 20.  3. 14.  6. 56. 45.  9. 18. 77. 28. 49. 42.  5. 25.
#  10.  7. 15.  8.  1. 40. 70.  4. 12. 35. 26. 24. 55. 50. 60. 38. 16. 46.
#  36. 98. 39. 84. 22. 80. 48. 63. 91. 32. 17. 11. 33. 37. 52. 19. 43. 29.
#  66. 74. 72. 23. 54. 58. 27. 47. 31. 34.]
# VALUE COUNTS  10.0    514
# 14.0    502
# 7.0     399
# 21.0    398
# 5.0     283
# 20.0    215
# 15.0    210
# 28.0    191
# 35.0    187
# 2.0     178
# 30.0    147
# 12.0    144
# 3.0     138
# 25.0    133
# 40.0    122
# 6.0     112
# 8.0     100
# 1.0      92
# 4.0      86
# 18.0     60
# 50.0     57
# 16.0     43
# 45.0     39
# 9.0      38
# 42.0     36
# 56.0     34
# 24.0     28
# 60.0     28
# 70.0     24
# 36.0     19
#        ...
# 26.0     14
# 38.0     11
# 98.0      9
# 11.0      8
# 46.0      7
# 32.0      6
# 22.0      6
# 84.0      4
# 19.0      4
# 58.0      3
# 27.0      3
# 29.0      2
# 17.0      2
# 39.0      2
# 77.0      2
# 52.0      2
# 72.0      2
# 33.0      2
# 66.0      2
# 80.0      2
# 47.0      1
# 37.0      1
# 91.0      1
# 54.0      1
# 34.0      1
# 23.0      1
# 43.0      1
# 63.0      1
# 74.0      1
# 31.0      1
# Name: p9_h2, Length: 63, dtype: int64
#
#
# COLUMNA:  p9_h3
# TIPO:  flotante
# NUNIQUE:  24
# UNIQUE:  [nan  3.  2.  1.  4.  6.  5.  7.  9. 15. 10.  8. 98. 14.  0. 12. 21. 99.
#  16. 28. 50. 11. 20. 43. 45.]
# VALUE COUNTS  2.0     3964
# 3.0     2759
# 1.0     2071
# 4.0     1840
# 5.0     1236
# 6.0      628
# 7.0      570
# 8.0      193
# 10.0     179
# 9.0       70
# 0.0       59
# 98.0      49
# 14.0      45
# 12.0      42
# 15.0      18
# 21.0       7
# 11.0       5
# 16.0       3
# 99.0       3
# 20.0       3
# 50.0       1
# 45.0       1
# 28.0       1
# 43.0       1
# Name: p9_h3, dtype: int64
#
#
# COLUMNA:  p9_h4
# TIPO:  flotante
# NUNIQUE:  24
# UNIQUE:  [nan  5.  2.  7.  1.  3.  4. 10.  0. 20.  8.  6. 14. 21. 30.  9. 12. 98.
#  18. 15. 29. 48. 40. 42. 25.]
# VALUE COUNTS  2.0     655
# 3.0     493
# 5.0     448
# 1.0     439
# 4.0     222
# 10.0     72
# 6.0      44
# 0.0      34
# 7.0      33
# 8.0      21
# 9.0       8
# 15.0      7
# 14.0      6
# 20.0      4
# 30.0      3
# 12.0      3
# 21.0      3
# 25.0      2
# 98.0      2
# 40.0      2
# 29.0      1
# 48.0      1
# 18.0      1
# 42.0      1
# Name: p9_h4, dtype: int64
#
#
# COLUMNA:  p9_h5
# TIPO:  flotante
# NUNIQUE:  14
# UNIQUE:  [nan 10.  2.  4.  1.  3. 12. 14.  6.  8. 60. 36.  5. 21. 50.]
# VALUE COUNTS  3.0     5
# 1.0     5
# 4.0     4
# 2.0     4
# 5.0     2
# 10.0    2
# 60.0    1
# 21.0    1
# 14.0    1
# 36.0    1
# 50.0    1
# 8.0     1
# 6.0     1
# 12.0    1
# Name: p9_h5, dtype: int64
#
#
# COLUMNA:  p9_h6
# TIPO:  flotante
# NUNIQUE:  26
# UNIQUE:  [nan  2.  1.  3.  5. 27.  6.  9.  8.  0.  4. 21. 14. 20. 12. 48. 10.  7.
#  15. 16. 24. 36. 25. 18. 99. 35. 98.]
# VALUE COUNTS  2.0     230
# 1.0     200
# 3.0     137
# 5.0      73
# 4.0      59
# 6.0      52
# 7.0      36
# 8.0      26
# 10.0     21
# 14.0     12
# 9.0       7
# 12.0      6
# 21.0      6
# 20.0      5
# 0.0       3
# 35.0      2
# 15.0      2
# 27.0      1
# 25.0      1
# 24.0      1
# 16.0      1
# 48.0      1
# 36.0      1
# 98.0      1
# 99.0      1
# 18.0      1
# Name: p9_h6, dtype: int64
#
#
# COLUMNA:  p9_h7
# TIPO:  flotante
# NUNIQUE:  58
# UNIQUE:  [nan 18.  1.  7.  2.  4. 35. 26.  9. 14.  3. 56.  8.  6. 21. 10. 20. 36.
#  38. 12. 30. 24.  5. 42. 25. 34. 28. 98. 27. 40. 15. 23. 49. 70. 45. 19.
#  22. 17. 32. 16.  0. 11. 29. 37. 99. 46. 48. 50. 63. 13. 31. 60. 84. 72.
#  54. 39. 55. 44. 58.]
# VALUE COUNTS  7.0     2204
# 14.0    1988
# 2.0     1796
# 21.0    1544
# 10.0    1460
# 5.0     1279
# 3.0     1164
# 1.0      976
# 28.0     894
# 20.0     712
# 4.0      615
# 15.0     564
# 35.0     560
# 6.0      450
# 25.0     395
# 12.0     379
# 30.0     379
# 8.0      373
# 18.0     359
# 9.0      224
# 42.0     183
# 56.0     156
# 16.0     122
# 40.0     116
# 24.0      99
# 32.0      85
# 36.0      81
# 98.0      81
# 22.0      77
# 26.0      73
# 38.0      42
# 19.0      40
# 70.0      31
# 17.0      20
# 11.0      20
# 0.0       18
# 34.0      18
# 29.0      16
# 45.0      15
# 27.0      14
# 48.0      12
# 50.0      10
# 23.0       8
# 13.0       7
# 99.0       7
# 49.0       6
# 46.0       6
# 37.0       4
# 39.0       3
# 84.0       3
# 63.0       3
# 60.0       1
# 55.0       1
# 31.0       1
# 54.0       1
# 58.0       1
# 72.0       1
# 44.0       1
# Name: p9_h7, dtype: int64
#
#
# COLUMNA:  p9_h8
# TIPO:  flotante
# NUNIQUE:  28
# UNIQUE:  [nan 20.  2. 21.  8.  4.  7. 99.  3.  5. 50. 14.  1. 35. 28. 10.  6. 39.
#  98. 12. 25. 30. 15.  9. 72. 18. 40. 24. 16.]
# VALUE COUNTS  2.0     23
# 3.0     21
# 4.0     11
# 5.0     10
# 8.0      7
# 1.0      7
# 7.0      6
# 10.0     6
# 6.0      5
# 12.0     5
# 25.0     4
# 20.0     4
# 21.0     4
# 14.0     3
# 40.0     3
# 30.0     3
# 72.0     2
# 24.0     2
# 15.0     2
# 98.0     2
# 35.0     1
# 18.0     1
# 9.0      1
# 50.0     1
# 16.0     1
# 28.0     1
# 99.0     1
# 39.0     1
# Name: p9_h8, dtype: int64
#
#
# COLUMNA:  p9_m1
# TIPO:  flotante
# NUNIQUE:  3
# UNIQUE:  [nan  0. 30. 33.]
# VALUE COUNTS  0.0     3851
# 30.0       3
# 33.0       1
# Name: p9_m1, dtype: int64
#
#
# COLUMNA:  p9_m2
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     4701
# 30.0      12
# Name: p9_m2, dtype: int64
#
#
# COLUMNA:  p9_m3
# TIPO:  flotante
# NUNIQUE:  10
# UNIQUE:  [nan  0. 30. 20. 15.  1. 40. 22. 45.  5.  7.]
# VALUE COUNTS  0.0     13409
# 30.0      321
# 20.0        6
# 15.0        3
# 7.0         3
# 40.0        2
# 5.0         1
# 45.0        1
# 22.0        1
# 1.0         1
# Name: p9_m3, dtype: int64
#
#
# COLUMNA:  p9_m4
# TIPO:  flotante
# NUNIQUE:  14
# UNIQUE:  [nan  0. 30. 45. 55. 40. 35. 50. 20. 10.  3.  7. 15. 36.  4.]
# VALUE COUNTS  0.0     2181
# 30.0     231
# 45.0      49
# 20.0      11
# 40.0       9
# 15.0       8
# 35.0       4
# 10.0       3
# 50.0       3
# 55.0       2
# 36.0       1
# 7.0        1
# 4.0        1
# 3.0        1
# Name: p9_m4, dtype: int64
#
#
# COLUMNA:  p9_m5
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  0.]
# VALUE COUNTS  0.0    30
# Name: p9_m5, dtype: int64
#
#
# COLUMNA:  p9_m6
# TIPO:  flotante
# NUNIQUE:  4
# UNIQUE:  [nan  0. 30. 35. 45.]
# VALUE COUNTS  0.0     861
# 30.0     22
# 35.0      2
# 45.0      1
# Name: p9_m6, dtype: int64
#
#
# COLUMNA:  p9_m7
# TIPO:  flotante
# NUNIQUE:  8
# UNIQUE:  [nan  0. 30.  1. 40.  2. 20. 50.  8.]
# VALUE COUNTS  0.0     19574
# 30.0      114
# 40.0        3
# 20.0        2
# 1.0         2
# 50.0        1
# 8.0         1
# 2.0         1
# Name: p9_m7, dtype: int64
#
#
# COLUMNA:  p9_m8
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     137
# 30.0      1
# Name: p9_m8, dtype: int64
#
#
# COLUMNA:  p9a
# TIPO:  otro
# NUNIQUE:  8
# UNIQUE:  [nan '2' '1' '4' '3' '5' '8' '6' '9']
# VALUE COUNTS  2    1455
# 1     907
# 4     460
# 3     222
# 5      62
# 8      28
# 6       2
# 9       1
# Name: p9a, dtype: int64
#
#
# COLUMNA:  p9b
# TIPO:  otro
# NUNIQUE:  8
# UNIQUE:  [nan '6' '2' '1' '5' '4' '3' '7' '9']
# VALUE COUNTS  2    385
# 1    196
# 6    125
# 4     95
# 5     77
# 3     29
# 7     26
# 9      3
# Name: p9b, dtype: int64
#
#
# COLUMNA:  p9c
# TIPO:  flotante
# NUNIQUE:  11
# UNIQUE:  [nan  4.  1.  8.  3.  2.  5.  9. 99.  7. 10.  6.]
# VALUE COUNTS  4.0     185
# 2.0      31
# 8.0      21
# 7.0      12
# 1.0      12
# 10.0     11
# 9.0       9
# 5.0       6
# 99.0      4
# 3.0       4
# 6.0       2
# Name: p9c, dtype: int64
#
#
# COLUMNA:  p9d
# TIPO:  flotante
# NUNIQUE:  13
# UNIQUE:  [nan  9. 11.  1.  6. 12.  4.  7.  2.  3.  8. 10. 99.  5.]
# VALUE COUNTS  9.0     643
# 1.0     244
# 12.0    175
# 11.0    138
# 3.0     106
# 8.0      43
# 2.0      42
# 10.0     41
# 7.0      15
# 4.0       9
# 6.0       9
# 99.0      8
# 5.0       8
# Name: p9d, dtype: int64
#
#
# COLUMNA:  p9e
# TIPO:  flotante
# NUNIQUE:  14
# UNIQUE:  [nan  3. 11. 10.  5.  4. 12.  9. 14. 13.  6.  1.  2. 99.  7.]
# VALUE COUNTS  14.0    68
# 3.0     67
# 11.0    26
# 4.0     23
# 12.0    10
# 2.0      6
# 13.0     4
# 1.0      4
# 6.0      4
# 10.0     3
# 9.0      3
# 5.0      2
# 99.0     1
# 7.0      1
# Name: p9e, dtype: int64
#
#
# COLUMNA:  p9f
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [nan '3' '2' '9' '1']
# VALUE COUNTS  3    2539
# 2     547
# 1     132
# 9      14
# Name: p9f, dtype: int64
#
#
# COLUMNA:  p9f_anio
# TIPO:  flotante
# NUNIQUE:  66
# UNIQUE:  [  nan 2010. 2014. 2007. 1991. 2015. 2012. 2011. 2002. 2000. 2016. 2013.
#  2004. 1993. 2005. 1994. 1999. 1995. 2001. 2006. 1970. 1968. 1996. 1951.
#  1980. 2009. 1997. 9999. 1986. 1976. 1978. 1988. 1958. 2008. 2003. 1979.
#  1992. 1959. 1960. 1998. 1971. 1985. 1972. 2017. 1982. 1990. 1987. 1948.
#  1963. 1981. 1989. 1964. 1954. 1984. 1955. 1975. 1983. 1977. 1961. 1965.
#  1966. 1967. 1962. 1973. 1947. 1957. 1974.]
# VALUE COUNTS  2016.0    547
# 2015.0    445
# 2014.0    256
# 2012.0    202
# 2013.0    199
# 2017.0    132
# 2010.0    125
# 2011.0    122
# 2007.0    104
# 2006.0    100
# 2008.0     89
# 2009.0     83
# 2002.0     76
# 2000.0     71
# 1997.0     59
# 2004.0     52
# 1996.0     47
# 2001.0     45
# 2005.0     38
# 1995.0     38
# 1999.0     29
# 1992.0     28
# 2003.0     28
# 1987.0     24
# 1991.0     23
# 1990.0     22
# 1998.0     22
# 1994.0     21
# 1976.0     17
# 1986.0     17
#          ...
# 1970.0      9
# 1965.0      8
# 1967.0      7
# 1985.0      7
# 1988.0      6
# 1983.0      5
# 1982.0      5
# 1960.0      5
# 1966.0      5
# 1981.0      4
# 1979.0      4
# 1975.0      4
# 1958.0      4
# 1984.0      3
# 1959.0      3
# 1973.0      3
# 1972.0      3
# 1971.0      3
# 1974.0      2
# 1964.0      2
# 1968.0      2
# 1947.0      1
# 1957.0      1
# 1954.0      1
# 1963.0      1
# 1951.0      1
# 1962.0      1
# 1961.0      1
# 1955.0      1
# 1948.0      1
# Name: p9f_anio, Length: 66, dtype: int64
#
#
# COLUMNA:  p9f_mes
# TIPO:  flotante
# NUNIQUE:  13
# UNIQUE:  [nan 12.  5. 11.  6.  3. 10.  8. 99.  1.  9.  7.  4.  2.]
# VALUE COUNTS  12.0    149
# 1.0     105
# 2.0      73
# 10.0     63
# 11.0     62
# 9.0      45
# 8.0      43
# 3.0      43
# 6.0      36
# 7.0      34
# 99.0     16
# 5.0      13
# 4.0      11
# Name: p9f_mes, dtype: int64
#
#
# COLUMNA:  p9g
# TIPO:  flotante
# NUNIQUE:  164
# UNIQUE:  [  nan 4211. 7511. 9611. 7121. 9231. 9712. 9512. 2543. 4221. 9723. 5116.
#  7513. 2331. 8342. 2715. 5312. 9621. 7133. 4224. 4312. 2111. 4212. 2638.
#  2823. 2651. 3122. 9221. 5314. 9232. 7613. 4111. 4222. 3231. 2511. 3212.
#  3132. 5112. 2632. 4232. 5114. 7515. 3115. 2521. 9234. 9521. 7212. 9623.
#  2653. 4201. 4213. 5212. 7341. 7342. 9722. 7412. 9331. 7311. 7223. 9411.
#  5313. 7135. 4231. 3121. 2162. 9233. 3113. 2712. 3131. 5222. 5221. 2531.
#  3211. 8143. 8343. 2826. 2716. 2121. 1212. 8101. 2644. 1211. 2161. 5111.
#  2322. 8212. 9236. 2631. 8344. 9632. 2411. 2532. 1526. 2263. 3111. 2212.
#  2335. 8341. 5101. 9999. 2634. 7221. 2714. 3222. 2135. 2816. 2332. 1122.
#  7101. 2281. 9662. 2541. 3101. 9713. 5201. 5113. 8201. 2163. 1315. 2142.
#  2512. 2261. 2640. 2643. 2426. 1412. 1411. 8145. 6111. 2821. 2153. 7517.
#  9235. 2817. 7301. 1999. 2813. 2622. 2171. 2271. 9222. 2636. 8142. 2252.
#  5211. 7332. 2612. 2811. 1223. 7411. 7514. 2514. 2175. 1523. 2413. 7321.
#  5301. 8144. 2321. 2112. 9631. 9663. 2642. 9643. 9111.]
# VALUE COUNTS  4211.0    54
# 9611.0    26
# 5116.0    22
# 8342.0    21
# 9521.0    19
# 9621.0    18
# 5114.0    18
# 4111.0    16
# 3115.0    14
# 4231.0    14
# 9221.0    12
# 5313.0    12
# 7121.0    12
# 9512.0     9
# 9411.0     9
# 7513.0     9
# 3121.0     9
# 3132.0     9
# 9331.0     8
# 4224.0     8
# 3212.0     8
# 2121.0     7
# 4213.0     7
# 7341.0     7
# 3111.0     7
# 2135.0     7
# 4221.0     7
# 7135.0     7
# 9231.0     7
# 5111.0     6
#           ..
# 3222.0     1
# 2821.0     1
# 7321.0     1
# 2636.0     1
# 3131.0     1
# 2112.0     1
# 2622.0     1
# 2631.0     1
# 2111.0     1
# 1315.0     1
# 2252.0     1
# 2413.0     1
# 8101.0     1
# 7342.0     1
# 2653.0     1
# 2212.0     1
# 7301.0     1
# 2634.0     1
# 5314.0     1
# 2271.0     1
# 3113.0     1
# 5301.0     1
# 7517.0     1
# 2642.0     1
# 2521.0     1
# 7514.0     1
# 7515.0     1
# 5212.0     1
# 2153.0     1
# 2816.0     1
# Name: p9g, Length: 164, dtype: int64
#
#
# COLUMNA:  p9h
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [nan '1' '2' '3' '4']
# VALUE COUNTS  1    420
# 2    216
# 3     42
# 4      1
# Name: p9h, dtype: int64
#
#
# COLUMNA:  p9h_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    420
# Name: p9h_1, dtype: int64
#
#
# COLUMNA:  p9i
# TIPO:  flotante
# NUNIQUE:  97
# UNIQUE:  [  nan 4661. 4611. 8140. 2382. 3320. 5611. 4662. 5411. 3250. 7222. 3110.
#  6112. 4850. 9312. 9313. 5613. 2381. 4690. 7131. 5221. 4620. 6211. 4350.
#  8112. 4671. 6221. 4699. 5222. 7221. 3230. 3220. 4612. 4340. 5414. 2363.
#  2361. 4681. 8121. 3140. 3270. 5413. 4631. 5322. 4651. 3380. 3150. 5614.
#  4310. 6141. 4641. 6251. 6132. 4652. 5240. 3370. 5170. 3360. 3340. 7114.
#  6111. 3120. 6241. 3260. 8111. 9314. 6222. 3330. 5615. 4840. 4881. 5310.
#  6142. 9700. 7113. 4330. 9800. 4830. 9999. 6131. 1110. 4642. 4930. 5150.
#  4860. 8130. 4320. 5223. 6212. 4360. 2370. 3160. 1150. 5120. 4632. 5321.
#  8122. 1130.]
# VALUE COUNTS  7221.0    80
# 8140.0    40
# 5411.0    40
# 2382.0    27
# 5611.0    23
# 4850.0    21
# 4620.0    20
# 4631.0    16
# 4611.0    16
# 7222.0    15
# 3110.0    15
# 5614.0    13
# 4690.0    13
# 2361.0    12
# 4651.0    12
# 4661.0    12
# 9312.0    11
# 5613.0    10
# 6211.0    10
# 2381.0    10
# 8112.0    10
# 8121.0    10
# 6111.0     9
# 7131.0     9
# 9313.0     8
# 6141.0     8
# 3380.0     8
# 6112.0     7
# 4310.0     7
# 5221.0     7
#           ..
# 6251.0     2
# 3120.0     2
# 1130.0     2
# 9700.0     2
# 5414.0     1
# 5413.0     1
# 4642.0     1
# 4881.0     1
# 9800.0     1
# 6142.0     1
# 4360.0     1
# 5223.0     1
# 4652.0     1
# 4930.0     1
# 4320.0     1
# 4860.0     1
# 1150.0     1
# 6131.0     1
# 5615.0     1
# 4830.0     1
# 7113.0     1
# 5310.0     1
# 8122.0     1
# 5321.0     1
# 3270.0     1
# 3330.0     1
# 6241.0     1
# 3160.0     1
# 6212.0     1
# 5120.0     1
# Name: p9i, Length: 97, dtype: int64
#
#
# COLUMNA:  p9j
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '2' '1']
# VALUE COUNTS  2    595
# 1     41
# Name: p9j, dtype: int64
#
#
# COLUMNA:  p9k
# TIPO:  otro
# NUNIQUE:  6
# UNIQUE:  [nan '6' '1' '3' '9' '4' '2']
# VALUE COUNTS  6    397
# 1    209
# 3     25
# 9      3
# 2      1
# 4      1
# Name: p9k, dtype: int64
#
#
# COLUMNA:  p9l1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    249
# Name: p9l1, dtype: int64
#
#
# COLUMNA:  p9l2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    217
# Name: p9l2, dtype: int64
#
#
# COLUMNA:  p9l3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    54
# Name: p9l3, dtype: int64
#
#
# COLUMNA:  p9l4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    5
# Name: p9l4, dtype: int64
#
#
# COLUMNA:  p9l5
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '5']
# VALUE COUNTS  5    370
# Name: p9l5, dtype: int64
#
#
# COLUMNA:  p9l9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    2
# Name: p9l9, dtype: int64
#
#
# COLUMNA:  p9m1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    509
# Name: p9m1, dtype: int64
#
#
# COLUMNA:  p9m2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    2
# Name: p9m2, dtype: int64
#
#
# COLUMNA:  p9m3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    8
# Name: p9m3, dtype: int64
#
#
# COLUMNA:  p9m9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    118
# Name: p9m9, dtype: int64
#
#
# COLUMNA:  p9mcan
# TIPO:  flotante
# NUNIQUE:  82
# UNIQUE:  [   nan  2000.  2500.  3000.  4000.   350.  6000.  3500.   500.  3200.
#   8000.  1200.   100.  3400.  4800.  1000.  5000.  1500. 10300.   200.
#   3600.   300.   320.  3160.  5200.  7200.  2600. 15000.  4200.  7000.
#   2400.   400.  4500.  5600.   900.  2191.   800.  2800.  1600.  3800.
#   1400.  7500.  2401.  3870.  1560. 10000. 30000.  6400. 12000. 20000.
#   8250. 14000. 36000. 50000. 28000.   360.   600. 48000.  2200. 16000.
#  35006. 31000.  1800.  5900.  5500.  9000.  5800.  5400.  6500.  3120.
#  13000. 11200.  5100.  4600. 18000.  1290.  4400.  4300. 17286.  7800.
#   6450. 25000.  3440.]
# VALUE COUNTS  4000.0     61
# 2000.0     54
# 3000.0     43
# 6000.0     34
# 5000.0     29
# 8000.0     16
# 2400.0     15
# 1000.0     15
# 2800.0     14
# 4800.0     13
# 3600.0     13
# 3200.0     13
# 10000.0    13
# 7000.0     12
# 2401.0     12
# 2500.0     12
# 3500.0      9
# 1200.0      8
# 4500.0      6
# 1500.0      6
# 5200.0      5
# 12000.0     5
# 800.0       5
# 3400.0      5
# 1600.0      5
# 20000.0     4
# 3800.0      4
# 400.0       4
# 2191.0      3
# 9000.0      3
#            ..
# 5400.0      1
# 35006.0     1
# 7500.0      1
# 5900.0      1
# 10300.0     1
# 2600.0      1
# 31000.0     1
# 18000.0     1
# 16000.0     1
# 4400.0      1
# 25000.0     1
# 6400.0      1
# 30000.0     1
# 3160.0      1
# 1800.0      1
# 5800.0      1
# 7200.0      1
# 5600.0      1
# 320.0       1
# 360.0       1
# 5500.0      1
# 7800.0      1
# 350.0       1
# 4600.0      1
# 50000.0     1
# 1560.0      1
# 4300.0      1
# 28000.0     1
# 17286.0     1
# 3120.0      1
# Name: p9mcan, Length: 82, dtype: int64
#
#
# COLUMNA:  p9n1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    29
# Name: p9n1, dtype: int64
#
#
# COLUMNA:  p9n2
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p9n2, dtype: int64)
#
#
# COLUMNA:  p9n3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    478
# Name: p9n3, dtype: int64
#
#
# COLUMNA:  p9n4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    23
# Name: p9n4, dtype: int64
#
#
# COLUMNA:  p9n5
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '5']
# VALUE COUNTS  5    6
# Name: p9n5, dtype: int64
#
#
# COLUMNA:  p9n6
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '6']
# VALUE COUNTS  6    2692
# Name: p9n6, dtype: int64
#
#
# COLUMNA:  p9n9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    4
# Name: p9n9, dtype: int64

# %%
l
# Out:
# ['p10_1',
#  'p10_2',
#  'p10_3',
#  'p10_4',
#  'p10_9',
#  'p10a1',
#  'p10a2',
#  'p10a3',
#  'p10a4',
#  'p10a9',
#  'p10b',
#  'p11_1',
#  'p11_2',
#  'p11_3',
#  'p11_4',
#  'p11_5',
#  'p11_6',
#  'p11_7',
#  'p11_8',
#  'p11_h1',
#  'p11_h2',
#  'p11_h3',
#  'p11_h4',
#  'p11_h5',
#  'p11_h6',
#  'p11_h7',
#  'p11_h8',
#  'p11_m1',
#  'p11_m2',
#  'p11_m3',
#  'p11_m4',
#  'p11_m5',
#  'p11_m6',
#  'p11_m7',
#  'p11_m8',
#  'p6_1',
#  'p6_10',
#  'p6_2',
#  'p6_3',
#  'p6_4',
#  'p6_5',
#  'p6_6',
#  'p6_7',
#  'p6_8',
#  'p6_9',
#  'p6_99',
#  'p6a1',
#  'p6a2',
#  'p6a3',
#  'p6a4',
#  'p6a9',
#  'p6b1',
#  'p6b2',
#  'p6c',
#  'p6d',
#  'p7',
#  'p7a',
#  'p7b',
#  'p7c',
#  'p7d',
#  'p7e',
#  'p7f',
#  'p7f_dias',
#  'p7f_horas',
#  'p7g1',
#  'p7g2',
#  'p7g3',
#  'p7g9',
#  'p7gcan',
#  'p8_1',
#  'p8_2',
#  'p8_3',
#  'p8_4',
#  'p8_9',
#  'p8a',
#  'p8b',
#  'p9',
#  'p9_1',
#  'p9_2',
#  'p9_3',
#  'p9_4',
#  'p9_5',
#  'p9_6',
#  'p9_7',
#  'p9_8',
#  'p9_h1',
#  'p9_h2',
#  'p9_h3',
#  'p9_h4',
#  'p9_h5',
#  'p9_h6',
#  'p9_h7',
#  'p9_h8',
#  'p9_m1',
#  'p9_m2',
#  'p9_m3',
#  'p9_m4',
#  'p9_m5',
#  'p9_m6',
#  'p9_m7',
#  'p9_m8',
#  'p9a',
#  'p9b',
#  'p9c',
#  'p9d',
#  'p9e',
#  'p9f',
#  'p9f_anio',
#  'p9f_mes',
#  'p9g',
#  'p9h',
#  'p9h_1',
#  'p9i',
#  'p9j',
#  'p9k',
#  'p9l1',
#  'p9l2',
#  'p9l3',
#  'p9l4',
#  'p9l5',
#  'p9l9',
#  'p9m1',
#  'p9m2',
#  'p9m3',
#  'p9m9',
#  'p9mcan',
#  'p9n1',
#  'p9n2',
#  'p9n3',
#  'p9n4',
#  'p9n5',
#  'p9n6',
#  'p9n9']

# %%
df.head()
# Out:
#    eda p10_1  p10_2 p10_3 p10_4 p10_9 p10a1 p10a2 p10a3 p10a4  ... p9m3  p9m9  \
# 0   63   NaN    NaN   NaN     4   NaN   NaN   NaN   NaN     4  ...  NaN   NaN
# 1   58   NaN    NaN   NaN     4   NaN   NaN   NaN   NaN     4  ...  NaN   NaN
# 2   31   NaN    NaN   NaN     4   NaN   NaN   NaN   NaN     4  ...  NaN   NaN
# 3   52   NaN    NaN   NaN     4   NaN   NaN   NaN   NaN     4  ...  NaN   NaN
# 4   51   NaN    NaN   NaN     4   NaN   NaN   NaN   NaN     4  ...  NaN   NaN
#
#   p9mcan p9n1 p9n2 p9n3 p9n4 p9n5 p9n6 p9n9
# 0    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    NaN  NaN  NaN  NaN  NaN  NaN    6  NaN
# 2    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    NaN  NaN  NaN  NaN  NaN  NaN    6  NaN
# 4    NaN  NaN  NaN  NaN  NaN  NaN    6  NaN
#
# [5 rows x 134 columns]

# %%
df.replace(to_replace=-1,value=np.NaN,inplace=True)

# %%
file = "../../../../../../dataframes/enoe/COE1T/df_concat_2017.csv"

# %%
df.to_csv(path_or_buf=file, index=False)
