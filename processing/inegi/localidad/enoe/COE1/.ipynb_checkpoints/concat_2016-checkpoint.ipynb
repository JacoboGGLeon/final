# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 01

# %%
file = "../../../../../../data/inegi-encuestas/localidad/enoe/2016/2016trim1_csv/coe1t116.CSV"

# %%
df_01 = pd.read_csv(filepath_or_buffer=file, encoding='latin', low_memory=False)
df_01.head()
# Out:
#    r_def  cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  n_hog  h_mud  \
# 0      0     1    9  40001  900471    101         15      1      1      0
# 1      0     1    9  40001  900471    101         15      1      1      0
# 2      0     1    9  40001  900471    101         15      1      1      0
# 3      0     1    9  40001  900471    101         15      1      1      0
# 4      0     1    9  40001  900471    101         38      2      1      0
#
#    ...  p5g10  p5g11  p5g12  p5g13  p5g14  p5g15 p5g99 p5h ur  fac
# 0  ...    NaN    NaN    NaN    NaN   14.0    NaN   NaN      1  422
# 1  ...    NaN    NaN    NaN    NaN   14.0    NaN   NaN      1  422
# 2  ...    NaN    NaN    NaN    NaN   14.0    NaN   NaN      1  422
# 3  ...    NaN    NaN    NaN    NaN    NaN    NaN   NaN      1  422
# 4  ...    NaN    NaN    NaN    NaN    NaN    NaN   NaN      1  422
#
# [5 rows x 186 columns]

# %%
df_01.shape
# Out:
# (309387, 186)

# %%
df_01[(df_01.ent == 9)].shape
# Out:
# (7916, 186)

# %%
df_01_copy = df_01[(df_01.ent == 9)].copy()

# %% [markdown]
# ## 02

# %%
file = "../../../../../../data/inegi-encuestas/localidad/enoe/2016/2016trim2_csv/coe1t216.CSV"

# %%
df_02 = pd.read_csv(filepath_or_buffer=file, encoding='latin', low_memory=False)
df_02.head()
# Out:
#    r_def  cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  n_hog  h_mud  \
# 0      0     1    9  40001  900471    101         15      1      1      0
# 1      0     1    9  40001  900471    101         15      1      1      0
# 2      0     1    9  40001  900471    101         15      1      1      0
# 3      0     1    9  40001  900471    101         15      1      1      0
# 4      0     1    9  40001  900471    101         38      2      1      0
#
#    ...  p5f9  p5f10  p5f11  p5f12  p5f13  p5f14 p5f15 p5f99 ur  fac
# 0  ...   NaN    NaN    NaN    NaN    NaN   14.0   NaN   NaN  1  417
# 1  ...   NaN    NaN    NaN    NaN    NaN   14.0   NaN   NaN  1  417
# 2  ...   NaN    NaN    NaN    NaN    NaN   14.0   NaN   NaN  1  417
# 3  ...   NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN  1  417
# 4  ...   NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN  1  417
#
# [5 rows x 169 columns]

# %%
df_02.shape
# Out:
# (309697, 169)

# %%
df_02[(df_02.ent == 9)].shape
# Out:
# (8009, 169)

# %%
df_02_copy = df_02[(df_02.ent == 9)].copy()

# %% [markdown]
# ## 03

# %%
file = "../../../../../../data/inegi-encuestas/localidad/enoe/2016/2016trim3_csv/coe1t316.CSV"

# %%
df_03 = pd.read_csv(filepath_or_buffer=file, encoding='latin', low_memory=False)
df_03.head()
# Out:
#    r_def  cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  n_hog  h_mud  \
# 0      0     1    9  40001  900471    101         55      2      1      0
# 1      0     1    9  40001  900471    101         55      2      1      0
# 2      0     1    9  40001  900471    101         55      2      1      0
# 3      0     1    9  40001  900471    101         55      2      1      0
# 4      0     1    9  40001  900471    101         80      3      1      0
#
#    ...  p5f9  p5f10  p5f11  p5f12  p5f13  p5f14 p5f15 p5f99 ur  fac
# 0  ...   NaN    NaN    NaN    NaN    NaN   14.0   NaN   NaN  1  484
# 1  ...   NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN  1  484
# 2  ...   NaN    NaN    NaN    NaN    NaN   14.0   NaN   NaN  1  484
# 3  ...   NaN    NaN    NaN    NaN    NaN   14.0   NaN   NaN  1  484
# 4  ...   NaN    NaN    NaN    NaN    NaN   14.0   NaN   NaN  1  484
#
# [5 rows x 169 columns]

# %%
df_03.shape
# Out:
# (305048, 169)

# %%
df_03[(df_03.ent == 9)].shape
# Out:
# (7856, 169)

# %%
df_03_copy = df_03[(df_03.ent == 9)].copy()

# %% [markdown]
# ## 04

# %%
file = "../../../../../../data/inegi-encuestas/localidad/enoe/2016/2016trim4_csv/coe1t416.CSV"

# %%
df_04 = pd.read_csv(filepath_or_buffer=file, encoding='latin', low_memory=False)
df_04.head()
# Out:
#    r_def  cd_a  ent    con     upm  d_sem  n_pro_viv  v_sel  n_hog  h_mud  \
# 0      0     1    9  40001  900471    101         55      2      1      0
# 1      0     1    9  40001  900471    101         55      2      1      0
# 2      0     1    9  40001  900471    101         55      2      1      0
# 3      0     1    9  40001  900471    101         80      3      1      0
# 4      0     1    9  40001  900471    101         80      3      1      0
#
#    ...  p5f9  p5f10  p5f11  p5f12  p5f13  p5f14 p5f15 p5f99 ur  fac
# 0  ...   NaN    NaN    NaN    NaN    NaN   14.0   NaN   NaN  1  640
# 1  ...   NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN  1  640
# 2  ...   NaN    NaN    NaN    NaN    NaN   14.0   NaN   NaN  1  640
# 3  ...   NaN    NaN    NaN    NaN    NaN    NaN  15.0   NaN  1  640
# 4  ...   NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN  1  640
#
# [5 rows x 169 columns]

# %%
df_04.shape
# Out:
# (306110, 169)

# %%
df_04[(df_04.ent == 9)].shape
# Out:
# (7998, 169)

# %%
df_04_copy = df_04[(df_04.ent == 9)].copy()

# %% [markdown]
# ## Concat

# %%
list_columns_df_01 = list(df_01_copy.columns)
list_columns_df_02 = list(df_02_copy.columns)
list_columns_df_03 = list(df_03_copy.columns)
list_columns_df_04 = list(df_04_copy.columns)

# %%
[x for x in list_columns_df_01 if x not in list_columns_df_02]
# Out:
# ['p3j',
#  'p3l1',
#  'p3l2',
#  'p3l3',
#  'p3l4',
#  'p3l5',
#  'p3l9',
#  'p3m1',
#  'p3m2',
#  'p3m3',
#  'p3m4',
#  'p3m5',
#  'p3m6',
#  'p3m7',
#  'p3m8',
#  'p3m9',
#  'p3n',
#  'p3o',
#  'p3p1',
#  'p3p2',
#  'p3q',
#  'p3r_anio',
#  'p3r_mes',
#  'p3r',
#  'p3s',
#  'p3t_anio',
#  'p3t_mes',
#  'p5b',
#  'p5c_hlu',
#  'p5c_mlu',
#  'p5c_hma',
#  'p5c_mma',
#  'p5c_hmi',
#  'p5c_mmi',
#  'p5c_hju',
#  'p5c_mju',
#  'p5c_hvi',
#  'p5c_mvi',
#  'p5c_hsa',
#  'p5c_msa',
#  'p5c_hdo',
#  'p5c_mdo',
#  'p5c_thrs',
#  'p5c_tdia',
#  'p5d',
#  'p5e1',
#  'p5e_hlu',
#  'p5e_mlu',
#  'p5e_hma',
#  'p5e_mma',
#  'p5e_hmi',
#  'p5e_mmi',
#  'p5e_hju',
#  'p5e_mju',
#  'p5e_hvi',
#  'p5e_mvi',
#  'p5e_hsa',
#  'p5e_msa',
#  'p5e_hdo',
#  'p5e_mdo',
#  'p5e_thrs',
#  'p5e_tdia',
#  'p5f',
#  'p5g1',
#  'p5g2',
#  'p5g3',
#  'p5g4',
#  'p5g5',
#  'p5g6',
#  'p5g7',
#  'p5g8',
#  'p5g9',
#  'p5g10',
#  'p5g11',
#  'p5g12',
#  'p5g13',
#  'p5g14',
#  'p5g15',
#  'p5g99',
#  'p5h']

# %%
[x for x in list_columns_df_02 if x not in list_columns_df_01]
# Out:
# ['p2i',
#  'p2j',
#  'p2k_anio',
#  'p2k_mes',
#  'p2k',
#  'p3j1',
#  'p3j2',
#  'p3k3',
#  'p3k4',
#  'p3k5',
#  'p3k9',
#  'p3l',
#  'p5b_hlu',
#  'p5b_mlu',
#  'p5b_hma',
#  'p5b_mma',
#  'p5b_hmi',
#  'p5b_mmi',
#  'p5b_hju',
#  'p5b_mju',
#  'p5b_hvi',
#  'p5b_mvi',
#  'p5b_hsa',
#  'p5b_msa',
#  'p5b_hdo',
#  'p5b_mdo',
#  'p5b_thrs',
#  'p5b_tdia',
#  'p5c',
#  'p5d1',
#  'p5d_hlu',
#  'p5d_mlu',
#  'p5d_hma',
#  'p5d_mma',
#  'p5d_hmi',
#  'p5d_mmi',
#  'p5d_hju',
#  'p5d_mju',
#  'p5d_hvi',
#  'p5d_mvi',
#  'p5d_hsa',
#  'p5d_msa',
#  'p5d_hdo',
#  'p5d_mdo',
#  'p5d_thrs',
#  'p5d_tdia',
#  'p5e',
#  'p5f1',
#  'p5f2',
#  'p5f3',
#  'p5f4',
#  'p5f5',
#  'p5f6',
#  'p5f7',
#  'p5f8',
#  'p5f9',
#  'p5f10',
#  'p5f11',
#  'p5f12',
#  'p5f13',
#  'p5f14',
#  'p5f15',
#  'p5f99']

# %%
[x for x in list_columns_df_01 if x not in list_columns_df_03]
# Out:
# ['p3j',
#  'p3l1',
#  'p3l2',
#  'p3l3',
#  'p3l4',
#  'p3l5',
#  'p3l9',
#  'p3m1',
#  'p3m2',
#  'p3m3',
#  'p3m4',
#  'p3m5',
#  'p3m6',
#  'p3m7',
#  'p3m8',
#  'p3m9',
#  'p3n',
#  'p3o',
#  'p3p1',
#  'p3p2',
#  'p3q',
#  'p3r_anio',
#  'p3r_mes',
#  'p3r',
#  'p3s',
#  'p3t_anio',
#  'p3t_mes',
#  'p5b',
#  'p5c_hlu',
#  'p5c_mlu',
#  'p5c_hma',
#  'p5c_mma',
#  'p5c_hmi',
#  'p5c_mmi',
#  'p5c_hju',
#  'p5c_mju',
#  'p5c_hvi',
#  'p5c_mvi',
#  'p5c_hsa',
#  'p5c_msa',
#  'p5c_hdo',
#  'p5c_mdo',
#  'p5c_thrs',
#  'p5c_tdia',
#  'p5d',
#  'p5e1',
#  'p5e_hlu',
#  'p5e_mlu',
#  'p5e_hma',
#  'p5e_mma',
#  'p5e_hmi',
#  'p5e_mmi',
#  'p5e_hju',
#  'p5e_mju',
#  'p5e_hvi',
#  'p5e_mvi',
#  'p5e_hsa',
#  'p5e_msa',
#  'p5e_hdo',
#  'p5e_mdo',
#  'p5e_thrs',
#  'p5e_tdia',
#  'p5f',
#  'p5g1',
#  'p5g2',
#  'p5g3',
#  'p5g4',
#  'p5g5',
#  'p5g6',
#  'p5g7',
#  'p5g8',
#  'p5g9',
#  'p5g10',
#  'p5g11',
#  'p5g12',
#  'p5g13',
#  'p5g14',
#  'p5g15',
#  'p5g99',
#  'p5h']

# %%
[x for x in list_columns_df_03 if x not in list_columns_df_01]
#incorporan el ejército en septiembre y diciembre del 2016
# Out:
# ['p2i',
#  'p2j',
#  'p2k_anio',
#  'p2k_mes',
#  'p2k',
#  'p3j1',
#  'p3j2',
#  'p3k3',
#  'p3k4',
#  'p3k5',
#  'p3k9',
#  'p3l',
#  'p5b_hlu',
#  'p5b_mlu',
#  'p5b_hma',
#  'p5b_mma',
#  'p5b_hmi',
#  'p5b_mmi',
#  'p5b_hju',
#  'p5b_mju',
#  'p5b_hvi',
#  'p5b_mvi',
#  'p5b_hsa',
#  'p5b_msa',
#  'p5b_hdo',
#  'p5b_mdo',
#  'p5b_thrs',
#  'p5b_tdia',
#  'p5c',
#  'p5d1',
#  'p5d_hlu',
#  'p5d_mlu',
#  'p5d_hma',
#  'p5d_mma',
#  'p5d_hmi',
#  'p5d_mmi',
#  'p5d_hju',
#  'p5d_mju',
#  'p5d_hvi',
#  'p5d_mvi',
#  'p5d_hsa',
#  'p5d_msa',
#  'p5d_hdo',
#  'p5d_mdo',
#  'p5d_thrs',
#  'p5d_tdia',
#  'p5e',
#  'p5f1',
#  'p5f2',
#  'p5f3',
#  'p5f4',
#  'p5f5',
#  'p5f6',
#  'p5f7',
#  'p5f8',
#  'p5f9',
#  'p5f10',
#  'p5f11',
#  'p5f12',
#  'p5f13',
#  'p5f14',
#  'p5f15',
#  'p5f99']

# %%
[x for x in list_columns_df_01 if x not in list_columns_df_04]
# Out:
# ['p3j',
#  'p3l1',
#  'p3l2',
#  'p3l3',
#  'p3l4',
#  'p3l5',
#  'p3l9',
#  'p3m1',
#  'p3m2',
#  'p3m3',
#  'p3m4',
#  'p3m5',
#  'p3m6',
#  'p3m7',
#  'p3m8',
#  'p3m9',
#  'p3n',
#  'p3o',
#  'p3p1',
#  'p3p2',
#  'p3q',
#  'p3r_anio',
#  'p3r_mes',
#  'p3r',
#  'p3s',
#  'p3t_anio',
#  'p3t_mes',
#  'p5b',
#  'p5c_hlu',
#  'p5c_mlu',
#  'p5c_hma',
#  'p5c_mma',
#  'p5c_hmi',
#  'p5c_mmi',
#  'p5c_hju',
#  'p5c_mju',
#  'p5c_hvi',
#  'p5c_mvi',
#  'p5c_hsa',
#  'p5c_msa',
#  'p5c_hdo',
#  'p5c_mdo',
#  'p5c_thrs',
#  'p5c_tdia',
#  'p5d',
#  'p5e1',
#  'p5e_hlu',
#  'p5e_mlu',
#  'p5e_hma',
#  'p5e_mma',
#  'p5e_hmi',
#  'p5e_mmi',
#  'p5e_hju',
#  'p5e_mju',
#  'p5e_hvi',
#  'p5e_mvi',
#  'p5e_hsa',
#  'p5e_msa',
#  'p5e_hdo',
#  'p5e_mdo',
#  'p5e_thrs',
#  'p5e_tdia',
#  'p5f',
#  'p5g1',
#  'p5g2',
#  'p5g3',
#  'p5g4',
#  'p5g5',
#  'p5g6',
#  'p5g7',
#  'p5g8',
#  'p5g9',
#  'p5g10',
#  'p5g11',
#  'p5g12',
#  'p5g13',
#  'p5g14',
#  'p5g15',
#  'p5g99',
#  'p5h']

# %%
[x for x in list_columns_df_04 if x not in list_columns_df_01]
#cambiar ENT por CVE_ENT
# Out:
# ['p2i',
#  'p2j',
#  'p2k_anio',
#  'p2k_mes',
#  'p2k',
#  'p3j1',
#  'p3j2',
#  'p3k3',
#  'p3k4',
#  'p3k5',
#  'p3k9',
#  'p3l',
#  'p5b_hlu',
#  'p5b_mlu',
#  'p5b_hma',
#  'p5b_mma',
#  'p5b_hmi',
#  'p5b_mmi',
#  'p5b_hju',
#  'p5b_mju',
#  'p5b_hvi',
#  'p5b_mvi',
#  'p5b_hsa',
#  'p5b_msa',
#  'p5b_hdo',
#  'p5b_mdo',
#  'p5b_thrs',
#  'p5b_tdia',
#  'p5c',
#  'p5d1',
#  'p5d_hlu',
#  'p5d_mlu',
#  'p5d_hma',
#  'p5d_mma',
#  'p5d_hmi',
#  'p5d_mmi',
#  'p5d_hju',
#  'p5d_mju',
#  'p5d_hvi',
#  'p5d_mvi',
#  'p5d_hsa',
#  'p5d_msa',
#  'p5d_hdo',
#  'p5d_mdo',
#  'p5d_thrs',
#  'p5d_tdia',
#  'p5e',
#  'p5f1',
#  'p5f2',
#  'p5f3',
#  'p5f4',
#  'p5f5',
#  'p5f6',
#  'p5f7',
#  'p5f8',
#  'p5f9',
#  'p5f10',
#  'p5f11',
#  'p5f12',
#  'p5f13',
#  'p5f14',
#  'p5f15',
#  'p5f99']

# %%
frames = [df_01_copy, df_02_copy, df_03_copy, df_04_copy]

# %%
df = pd.concat(frames)
# Out:
# /Users/jacoboleon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## corroborar columnas y filas

# %%
df_01_copy.shape
# Out:
# (7916, 186)

# %%
df_02_copy.shape
# Out:
# (8009, 169)

# %%
df_03_copy.shape
# Out:
# (7856, 169)

# %%
df_04_copy.shape
# Out:
# (7998, 169)

# %%
df.shape
# Out:
# (31779, 249)

# %%
df.rename(columns={'ent':'CVE_ENT',
                   'mun':'CVE_MUN', 
                   'loc': 'CVE_LOC'}, 
                  inplace=True)

# %%
#list(df.columns)

# %%
list_text = ['r_def', 'cd_a','con', 'upm', 'd_sem', 'n_pro_viv', 'v_sel', 'n_hog', 'h_mud', 'n_ent', 'per', 'n_ren', "CVE_ENT", "fac", "n_inf", "ur"]
df.drop(labels=list_text, axis=1, inplace=True)

# %%
df.replace(to_replace='\r',value=np.NaN,inplace=True)

# %%
df.replace(to_replace='-\r',value=np.NaN,inplace=True)

# %%
df.replace(to_replace='',value=np.NaN,inplace=True)

# %%
df.replace(to_replace=' ',value=np.NaN,inplace=True)

# %%
df.replace({'1\r':1,  
           '2\r':2,
           '3\r':3,
           '4\r':4,
           '5\r':5,
           '6\r':6,
           '7\r':7,
           '8\r':8,
           '9\r':9,
           '0\r':0},
           inplace=True)

# %%
l = []
bandera = np.NAN
for column in df.columns:
    try:
        df[column].astype('int64')
    except:
        l.append(column)
    
    if df[column].dtype == np.int64:
        bandera = 'entero'
    elif df[column].dtype == np.float64:
        bandera = 'flotante'
    else:
        bandera = 'otro'
        
        
    print('COLUMNA: ', column)
    print('TIPO: ', bandera)
    print('NUNIQUE: ', df[column].nunique())
    print('UNIQUE: ', df[column].unique())
    print('VALUE COUNTS ', df[column].value_counts().sort_index())
    print('\n')
# Out:
# COLUMNA:  eda
# TIPO:  entero
# NUNIQUE:  87
# UNIQUE:  [46 48 23 18 36 31 32 42 40 75 15 43 35 68 37 27 33 16 21 85 63 24 59 54
#  61 56 17 26 22 45 51 30 28 65 50 47 64 67 34 12 52 25 20 19 91 53 71 14
#  13 44 60 78 89 69 84 57 62 29 77 66 39 79 38 70 41 88 55 92 74 58 49 82
#  80 73 90 72 81 76 95 83 94 97 87 98 93 86 96]
# VALUE COUNTS  12    542
# 13    556
# 14    597
# 15    607
# 16    611
# 17    554
# 18    606
# 19    579
# 20    637
# 21    691
# 22    661
# 23    605
# 24    618
# 25    642
# 26    636
# 27    597
# 28    634
# 29    530
# 30    599
# 31    601
# 32    576
# 33    594
# 34    486
# 35    536
# 36    561
# 37    516
# 38    501
# 39    519
# 40    575
# 41    543
#      ...
# 69    203
# 70    262
# 71    199
# 72    158
# 73    205
# 74    178
# 75    146
# 76    171
# 77    116
# 78    131
# 79    105
# 80    122
# 81     92
# 82     81
# 83     67
# 84     76
# 85     67
# 86     52
# 87     42
# 88     60
# 89     36
# 90     30
# 91     30
# 92     18
# 93     23
# 94     18
# 95     12
# 96      7
# 97     11
# 98     13
# Name: eda, Length: 87, dtype: int64
#
#
# COLUMNA:  p1
# TIPO:  entero
# NUNIQUE:  2
# UNIQUE:  [1 2]
# VALUE COUNTS  1    17038
# 2    14741
# Name: p1, dtype: int64
#
#
# COLUMNA:  p1a1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    48
# Name: p1a1, dtype: int64
#
#
# COLUMNA:  p1a2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    45
# Name: p1a2, dtype: int64
#
#
# COLUMNA:  p1a3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    14648
# Name: p1a3, dtype: int64
#
#
# COLUMNA:  p1b
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '1' '2']
# VALUE COUNTS  1      859
# 2    13789
# Name: p1b, dtype: int64
#
#
# COLUMNA:  p1c
# TIPO:  flotante
# NUNIQUE:  11
# UNIQUE:  [nan  5.  8.  6. 12.  1. 11.  7.  9.  4. 10.  3.]
# VALUE COUNTS  1.0       6
# 3.0       2
# 4.0       4
# 5.0     333
# 6.0     196
# 7.0       8
# 8.0     272
# 9.0       4
# 10.0      5
# 11.0     10
# 12.0     19
# Name: p1c, dtype: int64
#
#
# COLUMNA:  p1d
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '2' '1' '9']
# VALUE COUNTS  1    309
# 2    527
# 9      1
# Name: p1d, dtype: int64
#
#
# COLUMNA:  p1e
# TIPO:  otro
# NUNIQUE:  6
# UNIQUE:  [nan '1' '4' '2' '3' '9' '5']
# VALUE COUNTS  1    152
# 2    214
# 3     49
# 4    106
# 5      1
# 9      6
# Name: p1e, dtype: int64
#
#
# COLUMNA:  p2_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    7
# Name: p2_1, dtype: int64
#
#
# COLUMNA:  p2_2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    1004
# Name: p2_2, dtype: int64
#
#
# COLUMNA:  p2_3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    15
# Name: p2_3, dtype: int64
#
#
# COLUMNA:  p2_4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    13148
# Name: p2_4, dtype: int64
#
#
# COLUMNA:  p2_9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    2
# Name: p2_9, dtype: int64
#
#
# COLUMNA:  p2a_anio
# TIPO:  flotante
# NUNIQUE:  9
# UNIQUE:  [  nan 2015. 2016. 2013. 9999. 2014. 2005. 2010. 2011. 2012.]
# VALUE COUNTS  2005.0      1
# 2010.0      1
# 2011.0      1
# 2012.0      1
# 2013.0      4
# 2014.0     14
# 2015.0    160
# 2016.0    840
# 9999.0      3
# Name: p2a_anio, dtype: int64
#
#
# COLUMNA:  p2a_dia
# TIPO:  flotante
# NUNIQUE:  32
# UNIQUE:  [nan 99.  4.  1. 25. 11. 21. 15. 14. 20. 10.  7. 27. 19. 28.  8.  2. 17.
#  29. 30. 12. 18.  3.  5. 16.  9. 13. 22.  6. 24. 26. 23. 31.]
# VALUE COUNTS  1.0      97
# 2.0      34
# 3.0      38
# 4.0      36
# 5.0      28
# 6.0      18
# 7.0      38
# 8.0      20
# 9.0      18
# 10.0     28
# 11.0     20
# 12.0     30
# 13.0     13
# 14.0     16
# 15.0     88
# 16.0     23
# 17.0      7
# 18.0     32
# 19.0     12
# 20.0     39
# 21.0     14
# 22.0     21
# 23.0      7
# 24.0      8
# 25.0     19
# 26.0     15
# 27.0     10
# 28.0     24
# 29.0     15
# 30.0     12
# 31.0      3
# 99.0    242
# Name: p2a_dia, dtype: int64
#
#
# COLUMNA:  p2a_mes
# TIPO:  flotante
# NUNIQUE:  13
# UNIQUE:  [nan 10.  1. 11. 12.  7.  5.  6.  8.  2.  9.  3. 99.  4.]
# VALUE COUNTS  1.0     171
# 2.0      77
# 3.0      86
# 4.0      66
# 5.0      88
# 6.0      74
# 7.0      87
# 8.0      81
# 9.0      73
# 10.0     72
# 11.0     70
# 12.0     69
# 99.0     11
# Name: p2a_mes, dtype: int64
#
#
# COLUMNA:  p2a_sem
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  [nan '1' '9' '3' '2' '4']
# VALUE COUNTS  1    97
# 2    49
# 3    10
# 4    14
# 9    72
# Name: p2a_sem, dtype: int64
#
#
# COLUMNA:  p2b
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  [nan '1' '3' '2' '4' '9']
# VALUE COUNTS  1    965
# 2     32
# 3     19
# 4      8
# 9      1
# Name: p2b, dtype: int64
#
#
# COLUMNA:  p2b_anio
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [  nan 2015. 2016.]
# VALUE COUNTS  2015.0      19
# 2016.0    1006
# Name: p2b_anio, dtype: int64
#
#
# COLUMNA:  p2b_dia
# TIPO:  flotante
# NUNIQUE:  32
# UNIQUE:  [nan  7.  5.  8. 29. 30.  6. 13.  4. 21. 28. 10. 18. 16. 11. 12. 14. 15.
#  20. 99. 19. 23. 25. 26. 22. 27.  1.  2.  3.  9. 24. 17. 31.]
# VALUE COUNTS  1.0     25
# 2.0     28
# 3.0     29
# 4.0     32
# 5.0     34
# 6.0     18
# 7.0     32
# 8.0     54
# 9.0     29
# 10.0    34
# 11.0    25
# 12.0    36
# 13.0    22
# 14.0    42
# 15.0    68
# 16.0    19
# 17.0    17
# 18.0    30
# 19.0    36
# 20.0    30
# 21.0    30
# 22.0    41
# 23.0    25
# 24.0    23
# 25.0    33
# 26.0    19
# 27.0    19
# 28.0    39
# 29.0    37
# 30.0    28
# 31.0     9
# 99.0    82
# Name: p2b_dia, dtype: int64
#
#
# COLUMNA:  p2b_mes
# TIPO:  flotante
# NUNIQUE:  13
# UNIQUE:  [nan 12.  1. 10. 11.  2.  5.  3.  4.  6.  7. 99.  8.  9.]
# VALUE COUNTS  1.0      97
# 2.0      90
# 3.0      78
# 4.0      91
# 5.0     103
# 6.0      74
# 7.0      95
# 8.0      74
# 9.0      88
# 10.0     87
# 11.0     79
# 12.0     68
# 99.0      1
# Name: p2b_mes, dtype: int64
#
#
# COLUMNA:  p2b_sem
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  [nan '4' '1' '3' '2' '9']
# VALUE COUNTS  1    20
# 2    19
# 3    14
# 4    20
# 9     9
# Name: p2b_sem, dtype: int64
#
#
# COLUMNA:  p2c
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '1' '2']
# VALUE COUNTS  1    1003
# 2      13
# Name: p2c, dtype: int64
#
#
# COLUMNA:  p2d1
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  1.]
# VALUE COUNTS  1.0    505
# Name: p2d1, dtype: int64
#
#
# COLUMNA:  p2d10
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 10.]
# VALUE COUNTS  10.0    16
# Name: p2d10, dtype: int64
#
#
# COLUMNA:  p2d11
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 11.]
# VALUE COUNTS  11.0    3
# Name: p2d11, dtype: int64
#
#
# COLUMNA:  p2d2
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  2.]
# VALUE COUNTS  2.0    14
# Name: p2d2, dtype: int64
#
#
# COLUMNA:  p2d3
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  3.]
# VALUE COUNTS  3.0    16
# Name: p2d3, dtype: int64
#
#
# COLUMNA:  p2d4
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  4.]
# VALUE COUNTS  4.0    9
# Name: p2d4, dtype: int64
#
#
# COLUMNA:  p2d5
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  5.]
# VALUE COUNTS  5.0    14
# Name: p2d5, dtype: int64
#
#
# COLUMNA:  p2d6
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  6.]
# VALUE COUNTS  6.0    358
# Name: p2d6, dtype: int64
#
#
# COLUMNA:  p2d7
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  7.]
# VALUE COUNTS  7.0    47
# Name: p2d7, dtype: int64
#
#
# COLUMNA:  p2d8
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  8.]
# VALUE COUNTS  8.0    1
# Name: p2d8, dtype: int64
#
#
# COLUMNA:  p2d9
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  9.]
# VALUE COUNTS  9.0    173
# Name: p2d9, dtype: int64
#
#
# COLUMNA:  p2d99
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 99.]
# VALUE COUNTS  99.0    12
# Name: p2d99, dtype: int64
#
#
# COLUMNA:  p2e
# TIPO:  otro
# NUNIQUE:  6
# UNIQUE:  [nan '2' '3' '4' '1' '6' '5']
# VALUE COUNTS  1     349
# 2    1681
# 3    4924
# 4    5531
# 5     242
# 6     445
# Name: p2e, dtype: int64
#
#
# COLUMNA:  p2f
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [nan '3' '1' '2' '9']
# VALUE COUNTS  1    2309
# 2     489
# 3    9777
# 9       6
# Name: p2f, dtype: int64
#
#
# COLUMNA:  p2g1
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '2' '1' '9']
# VALUE COUNTS  1     894
# 2    1904
# 9       6
# Name: p2g1, dtype: int64
#
#
# COLUMNA:  p2g2
# TIPO:  flotante
# NUNIQUE:  11
# UNIQUE:  [nan  7.  9.  4. 12. 11.  8.  1.  3. 10.  2.  6.]
# VALUE COUNTS  1.0      16
# 2.0       4
# 3.0      50
# 4.0     259
# 6.0       2
# 7.0      66
# 8.0      13
# 9.0     370
# 10.0     26
# 11.0      4
# 12.0     84
# Name: p2g2, dtype: int64
#
#
# COLUMNA:  p2h1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    6966
# Name: p2h1, dtype: int64
#
#
# COLUMNA:  p2h2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    819
# Name: p2h2, dtype: int64
#
#
# COLUMNA:  p2h3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    68
# Name: p2h3, dtype: int64
#
#
# COLUMNA:  p2h4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    6244
# Name: p2h4, dtype: int64
#
#
# COLUMNA:  p2h9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    14
# Name: p2h9, dtype: int64
#
#
# COLUMNA:  p2i
# TIPO:  otro
# NUNIQUE:  9
# UNIQUE:  [nan '3' '1' '2' '4' '5' '6' '9' '8' '7']
# VALUE COUNTS  1     993
# 2    2763
# 3     493
# 4    1252
# 5     124
# 6       5
# 7       1
# 8      49
# 9       6
# Name: p2i, dtype: int64
#
#
# COLUMNA:  p2j
# TIPO:  otro
# NUNIQUE:  8
# UNIQUE:  [nan '2' '4' '6' '1' '5' '7' '9' '3']
# VALUE COUNTS  1    152
# 2    281
# 3     24
# 4    123
# 5    174
# 6    157
# 7    126
# 9     11
# Name: p2j, dtype: int64
#
#
# COLUMNA:  p2k
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [nan '1' '2' '3' '9']
# VALUE COUNTS  1    1281
# 2     684
# 3    3919
# 9      54
# Name: p2k, dtype: int64
#
#
# COLUMNA:  p2k_anio
# TIPO:  flotante
# NUNIQUE:  70
# UNIQUE:  [  nan 2016. 2015. 2014. 2009. 1996. 1990. 2011. 2008. 2006. 2013. 1982.
#  2001. 2012. 2003. 1992. 2007. 1962. 1977. 1967. 2005. 2004. 1999. 2000.
#  2010. 1995. 9999. 2002. 1970. 1988. 1966. 1997. 1960. 1958. 1965. 1961.
#  1976. 1959. 1986. 1984. 1994. 1998. 1974. 1991. 1981. 1989. 1987. 1953.
#  1975. 1971. 1945. 1950. 1980. 1985. 1972. 1969. 1957. 1993. 1963. 1978.
#  1968. 1979. 1964. 1983. 1956. 1955. 1951. 1973. 1954. 1946. 1947.]
# VALUE COUNTS  1945.0       1
# 1946.0       1
# 1947.0       1
# 1950.0       2
# 1951.0       2
# 1953.0       2
# 1954.0       3
# 1955.0       2
# 1956.0       6
# 1957.0       2
# 1958.0       6
# 1959.0       5
# 1960.0      13
# 1961.0       9
# 1962.0       7
# 1963.0       4
# 1964.0       6
# 1965.0      15
# 1966.0      23
# 1967.0       9
# 1968.0       5
# 1969.0       4
# 1970.0      16
# 1971.0      17
# 1972.0      12
# 1973.0       4
# 1974.0      10
# 1975.0      11
# 1976.0      47
# 1977.0       9
#           ...
# 1988.0      24
# 1989.0      16
# 1990.0      58
# 1991.0      51
# 1992.0      34
# 1993.0      22
# 1994.0      40
# 1995.0      71
# 1996.0     191
# 1997.0      29
# 1998.0      56
# 1999.0      46
# 2000.0     154
# 2001.0     153
# 2002.0      74
# 2003.0      59
# 2004.0      79
# 2005.0      91
# 2006.0     317
# 2007.0      67
# 2008.0     165
# 2009.0     121
# 2010.0     220
# 2011.0     244
# 2012.0     237
# 2013.0     309
# 2014.0     523
# 2015.0     682
# 2016.0    1284
# 9999.0      54
# Name: p2k_anio, Length: 70, dtype: int64
#
#
# COLUMNA:  p2k_mes
# TIPO:  flotante
# NUNIQUE:  13
# UNIQUE:  [nan  1.  2. 12.  3. 10. 11. 99.  4.  6.  9.  8.  7.  5.]
# VALUE COUNTS  1.0     122
# 2.0     163
# 3.0     189
# 4.0     154
# 5.0     183
# 6.0     209
# 7.0     189
# 8.0     162
# 9.0     149
# 10.0    159
# 11.0    104
# 12.0    166
# 99.0     70
# Name: p2k_mes, dtype: int64
#
#
# COLUMNA:  p3
# TIPO:  flotante
# NUNIQUE:  386
# UNIQUE:  [7121. 9611. 3212.   nan 3111. 2511. 2332. 5114. 4224. 2512. 8161. 7133.
#  5116. 5222. 7515. 9521. 9722. 8342. 2263. 9631. 2543. 8341. 7351. 9512.
#  3122. 7135. 3211. 4221. 2542. 9621. 5313. 4111. 8101. 8133. 9235. 5211.
#  1511. 5113. 2252. 2142. 2644. 4211. 1521. 2412. 7213. 2261. 3113. 7101.
#  7511. 3115. 8132. 3121. 7312. 2162. 2121. 2331. 2321. 2271. 5312. 9642.
#  8123. 2335. 2135. 2426. 2815. 4312. 2811. 9331. 9234. 2532. 1411. 5241.
#  2654. 2643. 2112. 2653. 2637. 3132. 8352. 9411. 7321. 4201. 5101. 3201.
#  9999. 8343. 2631. 9221. 1212. 2111. 2222. 2651. 2551. 5111. 9232. 7411.
#  4214. 2531. 5412. 2514. 1614. 5212. 1712. 7311. 2642. 2823. 9231. 2413.
#  9713. 2632. 7211. 9633. 8351. 8144. 5221. 2625. 1412. 5231. 7221. 1211.
#  7341. 2513. 2544. 1221. 2411. 4222. 2131. 2172. 1122. 2712. 1121. 5242.
#  5311. 7513. 1711. 2636. 9233. 2242. 7212. 2633. 9236. 9733. 8145. 8344.
#  9731. 9723. 7514. 1315. 9601. 2152. 4213. 9641. 2827. 9712. 5112. 1621.
#  2151. 2161. 5213. 2561. 9632. 7343. 4231. 2281. 2634. 2533. 3221. 2232.
#  2122. 2322. 1629. 2655. 2992. 9651. 2623. 2221. 5301. 3101. 6111. 8311.
#  3142. 7613. 1321. 8153. 2714. 8131. 1722. 7517. 2175. 9661. 3131. 2311.
#  9623. 7134. 2716. 2713. 2428. 3213. 5314. 8151. 2821. 1423. 1723. 1622.
#  2312. 2251. 7214. 3114. 2123. 4223. 1421. 6116. 9111. 2423. 2640. 1111.
#  7412. 1314. 2715. 1611. 2646. 7332. 2813. 1512. 2711. 2641. 2624. 1223.
#  2812. 1526. 7223. 7132. 2612. 8154. 1615. 7322. 2638. 3222. 2524. 9311.
#  2113. 3231. 4311. 5254. 2614. 2541. 1522. 1623. 2143. 4232. 2611. 2630.
#  2622. 8143. 1313. 4212. 9662. 2425. 2613. 7342. 9222. 8152. 2343. 7353.
#  7352. 2145. 2253. 8121. 8113. 1523. 8301. 2153. 7131. 2272. 5413. 7401.
#  9643. 2822. 6127. 2212. 1132. 9622. 2552. 2826. 1525. 6115. 5115. 2816.
#  9321. 1999. 8171. 2174. 2144. 8331. 1224. 7501. 9721. 2173. 2163. 6112.
#  9511. 1524. 1624. 2814. 8212. 8122. 7222. 2635. 2133. 8142. 2645. 6224.
#  7123. 1134. 2522. 2211. 1133. 3999. 7611. 8211. 2254. 2817. 5401. 3141.
#  1322. 1721. 2825. 1312. 7201. 2421. 2262. 1135. 2427. 9732. 2132. 2422.
#  5201. 2241. 7999. 8134. 2562. 8322. 8201. 1323. 8163. 9899. 5253. 2523.
#  2621. 1222. 2991. 2141. 9711. 7301. 2424. 2553. 6114. 1613. 2164. 1226.
#  6223. 9121. 7516. 9624. 3112. 7612. 8173. 8172. 1422. 2223. 2563. 2341.
#  9237. 2521. 7122. 2333. 6999. 6125. 2661. 2171. 9663. 9239. 7614. 8155.
#  5411. 2652. 6131.]
# VALUE COUNTS  1111.0      3
# 1121.0      7
# 1122.0     42
# 1132.0      3
# 1133.0      1
# 1134.0      1
# 1135.0      1
# 1211.0    104
# 1212.0     75
# 1221.0     10
# 1222.0      8
# 1223.0     17
# 1224.0      2
# 1226.0      1
# 1312.0      1
# 1313.0      4
# 1314.0     27
# 1315.0     21
# 1321.0     14
# 1322.0      2
# 1323.0      5
# 1411.0     89
# 1412.0     48
# 1421.0     12
# 1422.0      6
# 1423.0     15
# 1511.0    118
# 1512.0     34
# 1521.0     16
# 1522.0     10
#          ...
# 9511.0      6
# 9512.0    290
# 9521.0    295
# 9601.0     35
# 9611.0    740
# 9621.0    443
# 9622.0     13
# 9623.0     22
# 9624.0      3
# 9631.0     38
# 9632.0     13
# 9633.0     29
# 9641.0     28
# 9642.0     28
# 9643.0     26
# 9651.0      5
# 9661.0     27
# 9662.0      5
# 9663.0      2
# 9711.0      4
# 9712.0     61
# 9713.0     38
# 9721.0      2
# 9722.0     81
# 9723.0     20
# 9731.0      3
# 9732.0      1
# 9733.0      1
# 9899.0      2
# 9999.0     46
# Name: p3, Length: 386, dtype: int64
#
#
# COLUMNA:  p3a
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  ['2' '1' nan]
# VALUE COUNTS  1    13418
# 2     4186
# Name: p3a, dtype: int64
#
#
# COLUMNA:  p3b
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  ['1' nan '2']
# VALUE COUNTS  1    4028
# 2     158
# Name: p3b, dtype: int64
#
#
# COLUMNA:  p3c1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    28
# Name: p3c1, dtype: int64
#
#
# COLUMNA:  p3c2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    351
# Name: p3c2, dtype: int64
#
#
# COLUMNA:  p3c3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  ['3' nan]
# VALUE COUNTS  3    3801
# Name: p3c3, dtype: int64
#
#
# COLUMNA:  p3c4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    8
# Name: p3c4, dtype: int64
#
#
# COLUMNA:  p3c9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    1
# Name: p3c9, dtype: int64
#
#
# COLUMNA:  p3d
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  ['2' nan '1' '9']
# VALUE COUNTS  1    1171
# 2    2856
# 9       1
# Name: p3d, dtype: int64
#
#
# COLUMNA:  p3e
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '1' '2']
# VALUE COUNTS  1    1164
# 2       7
# Name: p3e, dtype: int64
#
#
# COLUMNA:  p3f1
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '1' '3' '2']
# VALUE COUNTS  1    1064
# 2      15
# 3      92
# Name: p3f1, dtype: int64
#
#
# COLUMNA:  p3f2
# TIPO:  flotante
# NUNIQUE:  3
# UNIQUE:  [nan  2.  3.  4.]
# VALUE COUNTS  2.0    7
# 3.0    6
# 4.0    2
# Name: p3f2, dtype: int64
#
#
# COLUMNA:  p3g1_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    660
# Name: p3g1_1, dtype: int64
#
#
# COLUMNA:  p3g1_2
# TIPO:  flotante
# NUNIQUE:  24
# UNIQUE:  [ nan  10.   3.   2.   5.   1.   8.   6.   4.   7.   9.  20.  15.  11.
#  300.  14. 999.  30. 100.  70.  18.  12.  99.  25. 200.]
# VALUE COUNTS  1.0      290
# 2.0      168
# 3.0       50
# 4.0       29
# 5.0       29
# 6.0       12
# 7.0       13
# 8.0       16
# 9.0        5
# 10.0       9
# 11.0       2
# 12.0       3
# 14.0       2
# 15.0       5
# 18.0       1
# 20.0       8
# 25.0       3
# 30.0       1
# 70.0       3
# 99.0       1
# 100.0      1
# 200.0      1
# 300.0      1
# 999.0      7
# Name: p3g1_2, dtype: int64
#
#
# COLUMNA:  p3g2_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    317
# Name: p3g2_1, dtype: int64
#
#
# COLUMNA:  p3g2_2
# TIPO:  flotante
# NUNIQUE:  9
# UNIQUE:  [ nan   1.   3.   4.   7.   2.   6. 999.   5.  11.]
# VALUE COUNTS  1.0      256
# 2.0       27
# 3.0       16
# 4.0        9
# 5.0        2
# 6.0        2
# 7.0        2
# 11.0       1
# 999.0      2
# Name: p3g2_2, dtype: int64
#
#
# COLUMNA:  p3g3_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    337
# Name: p3g3_1, dtype: int64
#
#
# COLUMNA:  p3g3_2
# TIPO:  flotante
# NUNIQUE:  5
# UNIQUE:  [nan  1.  2.  3.  4.  5.]
# VALUE COUNTS  1.0    269
# 2.0     52
# 3.0      9
# 4.0      6
# 5.0      1
# Name: p3g3_2, dtype: int64
#
#
# COLUMNA:  p3g4_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    1
# Name: p3g4_1, dtype: int64
#
#
# COLUMNA:  p3g4_2
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [ nan 999.]
# VALUE COUNTS  999.0    1
# Name: p3g4_2, dtype: int64
#
#
# COLUMNA:  p3g9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    8
# Name: p3g9, dtype: int64
#
#
# COLUMNA:  p3g_tot
# TIPO:  flotante
# NUNIQUE:  30
# UNIQUE:  [ nan   1.  13.   4.   3.   2.   6.   5.   9.   8.   7.  16.  21.  15.
#   12.  10. 300.  14. 999.  35.  20. 101.  70.  11.  18. 100.  23.  24.
#   25. 200.  72.]
# VALUE COUNTS  1.0      636
# 2.0      250
# 3.0       84
# 4.0       48
# 5.0       35
# 6.0       20
# 7.0       14
# 8.0       14
# 9.0        8
# 10.0       8
# 11.0       2
# 12.0       3
# 13.0       3
# 14.0       2
# 15.0       4
# 16.0       3
# 18.0       1
# 20.0       5
# 21.0       1
# 23.0       1
# 24.0       1
# 25.0       3
# 35.0       1
# 70.0       2
# 72.0       1
# 100.0      1
# 101.0      1
# 200.0      1
# 300.0      1
# 999.0      9
# Name: p3g_tot, dtype: int64
#
#
# COLUMNA:  p3h
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '1' '3' '2']
# VALUE COUNTS  1    13165
# 2       39
# 3      372
# Name: p3h, dtype: int64
#
#
# COLUMNA:  p3i
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '2' '1' '9']
# VALUE COUNTS  1    6629
# 2    6449
# 9      87
# Name: p3i, dtype: int64
#
#
# COLUMNA:  p3j
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '2' '1' '9']
# VALUE COUNTS  1    1962
# 2    1242
# 9      19
# Name: p3j, dtype: int64
#
#
# COLUMNA:  p3j1
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '1' '2' '9']
# VALUE COUNTS  1    1241
# 2    4992
# 9      29
# Name: p3j1, dtype: int64
#
#
# COLUMNA:  p3j2
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [nan '3' '2' '1' '4']
# VALUE COUNTS  1    135
# 2    423
# 3    547
# 4    136
# Name: p3j2, dtype: int64
#
#
# COLUMNA:  p3k1
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '2' '1' '9']
# VALUE COUNTS  1    6868
# 2    1574
# 9       6
# Name: p3k1, dtype: int64
#
#
# COLUMNA:  p3k2
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  [nan '2' '3' '1' '4']
# VALUE COUNTS  1      37
# 2    5668
# 3     168
# 4      37
# Name: p3k2, dtype: int64
#
#
# COLUMNA:  p3k3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    1468
# Name: p3k3, dtype: int64
#
#
# COLUMNA:  p3k4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    100
# Name: p3k4, dtype: int64
#
#
# COLUMNA:  p3k5
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '5']
# VALUE COUNTS  5    3099
# Name: p3k5, dtype: int64
#
#
# COLUMNA:  p3k9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    52
# Name: p3k9, dtype: int64
#
#
# COLUMNA:  p3l
# TIPO:  flotante
# NUNIQUE:  12
# UNIQUE:  [nan  2.  1.  7. 11.  3.  8.  4. 10.  9.  6.  5. 99.]
# VALUE COUNTS  1.0      557
# 2.0     2298
# 3.0      760
# 4.0      444
# 5.0      459
# 6.0      560
# 7.0      811
# 8.0      958
# 9.0      744
# 10.0     378
# 11.0    1937
# 99.0     335
# Name: p3l, dtype: int64
#
#
# COLUMNA:  p3l1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    2173
# Name: p3l1, dtype: int64
#
#
# COLUMNA:  p3l2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    1849
# Name: p3l2, dtype: int64
#
#
# COLUMNA:  p3l3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    407
# Name: p3l3, dtype: int64
#
#
# COLUMNA:  p3l4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    38
# Name: p3l4, dtype: int64
#
#
# COLUMNA:  p3l5
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '5']
# VALUE COUNTS  5    983
# Name: p3l5, dtype: int64
#
#
# COLUMNA:  p3l9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    17
# Name: p3l9, dtype: int64
#
#
# COLUMNA:  p3m1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '1']
# VALUE COUNTS  1    1613
# Name: p3m1, dtype: int64
#
#
# COLUMNA:  p3m2
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '2']
# VALUE COUNTS  2    343
# Name: p3m2, dtype: int64
#
#
# COLUMNA:  p3m3
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '3']
# VALUE COUNTS  3    384
# Name: p3m3, dtype: int64
#
#
# COLUMNA:  p3m4
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '4']
# VALUE COUNTS  4    1694
# Name: p3m4, dtype: int64
#
#
# COLUMNA:  p3m5
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '5']
# VALUE COUNTS  5    886
# Name: p3m5, dtype: int64
#
#
# COLUMNA:  p3m6
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '6']
# VALUE COUNTS  6    227
# Name: p3m6, dtype: int64
#
#
# COLUMNA:  p3m7
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '7']
# VALUE COUNTS  7    730
# Name: p3m7, dtype: int64
#
#
# COLUMNA:  p3m8
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '8']
# VALUE COUNTS  8    408
# Name: p3m8, dtype: int64
#
#
# COLUMNA:  p3m9
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  [nan '9']
# VALUE COUNTS  9    19
# Name: p3m9, dtype: int64
#
#
# COLUMNA:  p3n
# TIPO:  flotante
# NUNIQUE:  11
# UNIQUE:  [nan  8.  7.  1.  9.  6. 99.  5.  3. 10.  2.  4.]
# VALUE COUNTS  1.0      461
# 2.0       12
# 3.0       10
# 4.0        1
# 5.0       19
# 6.0      222
# 7.0      247
# 8.0     1878
# 9.0      272
# 10.0       5
# 99.0      96
# Name: p3n, dtype: int64
#
#
# COLUMNA:  p3o
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '2' '1']
# VALUE COUNTS  1      36
# 2    3187
# Name: p3o, dtype: int64
#
#
# COLUMNA:  p3p1
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '2' '3']
# VALUE COUNTS  2    33
# 3     3
# Name: p3p1, dtype: int64
#
#
# COLUMNA:  p3p2
# TIPO:  flotante
# NUNIQUE:  14
# UNIQUE:  [ nan  15.  22.  20. 221. 200.  21.  12.  30.  14.  23.  32.  13.   1.
#    7.]
# VALUE COUNTS  1.0       2
# 7.0       1
# 12.0      2
# 13.0      1
# 14.0      2
# 15.0     10
# 20.0      2
# 21.0      7
# 22.0      2
# 23.0      1
# 30.0      2
# 32.0      1
# 200.0     2
# 221.0     1
# Name: p3p2, dtype: int64
#
#
# COLUMNA:  p3q
# TIPO:  flotante
# NUNIQUE:  12
# UNIQUE:  [nan  1. 10. 11.  4.  2.  7.  9.  3.  8.  6. 99.  5.]
# VALUE COUNTS  1.0     200
# 2.0     801
# 3.0     265
# 4.0     131
# 5.0     141
# 6.0     170
# 7.0     235
# 8.0     276
# 9.0     213
# 10.0    121
# 11.0    691
# 99.0     91
# Name: p3q, dtype: int64
#
#
# COLUMNA:  p3r
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  ['3' nan '2' '9' '1']
# VALUE COUNTS  1     158
# 2     646
# 3    3522
# 9      25
# Name: p3r, dtype: int64
#
#
# COLUMNA:  p3r_anio
# TIPO:  flotante
# NUNIQUE:  51
# UNIQUE:  [1990. 1991. 2012.   nan 2011. 2003. 2014. 2015. 2005. 2006. 2013. 2010.
#  2008. 1999. 2007. 1983. 1996. 2002. 1985. 9999. 2000. 1965. 2009. 1995.
#  1994. 1993. 1980. 1975. 2001. 1987. 1992. 1997. 1982. 1998. 1988. 1986.
#  2004. 1970. 1974. 2016. 1989. 1984. 1981. 1963. 1960. 1956. 1978. 1979.
#  1972. 1976. 1969. 1966.]
# VALUE COUNTS  1956.0      1
# 1960.0      3
# 1963.0      2
# 1965.0      6
# 1966.0      1
# 1969.0      1
# 1970.0     10
# 1972.0      2
# 1974.0      5
# 1975.0     11
# 1976.0      7
# 1978.0      3
# 1979.0      3
# 1980.0     24
# 1981.0     11
# 1982.0      5
# 1983.0     14
# 1984.0     14
# 1985.0     60
# 1986.0     37
# 1987.0     19
# 1988.0     20
# 1989.0     11
# 1990.0    100
# 1991.0     31
# 1992.0     17
# 1993.0     25
# 1994.0     21
# 1995.0    116
# 1996.0     71
# 1997.0     29
# 1998.0     52
# 1999.0     26
# 2000.0    201
# 2001.0     44
# 2002.0     33
# 2003.0     56
# 2004.0     58
# 2005.0    193
# 2006.0    148
# 2007.0    125
# 2008.0    128
# 2009.0    119
# 2010.0    325
# 2011.0    207
# 2012.0    315
# 2013.0    350
# 2014.0    462
# 2015.0    646
# 2016.0    158
# 9999.0     25
# Name: p3r_anio, dtype: int64
#
#
# COLUMNA:  p3r_mes
# TIPO:  flotante
# NUNIQUE:  13
# UNIQUE:  [nan  6. 11.  4. 12. 10.  7.  1. 99.  9.  2.  3.  8.  5.]
# VALUE COUNTS  1.0     177
# 2.0      83
# 3.0      55
# 4.0      19
# 5.0      19
# 6.0      54
# 7.0      49
# 8.0      58
# 9.0      65
# 10.0     75
# 11.0     63
# 12.0     81
# 99.0     31
# Name: p3r_mes, dtype: int64
#
#
# COLUMNA:  p3s
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  ['1' nan '2']
# VALUE COUNTS  1    3518
# 2       4
# Name: p3s, dtype: int64
#
#
# COLUMNA:  p3t_anio
# TIPO:  flotante
# NUNIQUE:  4
# UNIQUE:  [  nan 2010. 2016. 2009. 2013.]
# VALUE COUNTS  2009.0    1
# 2010.0    1
# 2013.0    1
# 2016.0    1
# Name: p3t_anio, dtype: int64
#
#
# COLUMNA:  p3t_mes
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  1.]
# VALUE COUNTS  1.0    1
# Name: p3t_mes, dtype: int64
#
#
# COLUMNA:  p4
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  ['2' '3' '1' nan '4' '9']
# VALUE COUNTS  1    11375
# 2     5210
# 3     1008
# 4        5
# 9        6
# Name: p4, dtype: int64
#
#
# COLUMNA:  p4_1
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '1' '2']
# VALUE COUNTS  1    2340
# 2     787
# Name: p4_1, dtype: int64
#
#
# COLUMNA:  p4_2
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  [nan '3' '5' '4' '1' '2' '7' '6']
# VALUE COUNTS  1    495
# 2    323
# 3    854
# 4    680
# 5    432
# 6    291
# 7     52
# Name: p4_2, dtype: int64
#
#
# COLUMNA:  p4_3
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '2' '1']
# VALUE COUNTS  1     144
# 2    5625
# Name: p4_3, dtype: int64
#
#
# COLUMNA:  p4a
# TIPO:  flotante
# NUNIQUE:  147
# UNIQUE:  [2361. 8140. 4651.   nan 6222. 5411. 6112. 7221. 4690. 3110. 8111. 5611.
#  7222. 4850. 2363. 3370. 4662. 2382. 5615. 9314. 5613. 5614. 4611. 3260.
#  8121. 6150. 9312. 6211. 8112. 4641. 6221. 7210. 4681. 3150. 3320. 3250.
#  5221. 4661. 6131. 4632. 4612. 5620. 6132. 8130. 4652. 6111. 3380. 5322.
#  5310. 4920. 7114. 4631. 5120. 3350. 5222. 2381. 4840. 4881. 3220. 4340.
#  5240. 3120. 5190. 4350. 3360. 9700. 5170. 4671. 9313. 4620. 6212. 3270.
#  3230. 6251. 4330. 4810. 4310. 2370. 3310. 2399. 5110. 5150. 5510. 5412.
#  6141. 7111. 5230. 3210. 3340. 8122. 4320. 2210. 3240. 4642. 4699. 7131.
#  8123. 3140. 7132. 5413. 9311. 1110. 6231. 9999. 4930. 3130. 6142. 4910.
#  3160. 1150. 4672. 4682. 4360. 7113. 1121. 7120. 3330. 4860. 2221. 5616.
#  6252. 3399. 8125. 6241. 5414. 5223. 4370. 9800. 5321. 4399. 2222. 9320.
#  5210. 4882. 4820. 6232. 7133. 6121. 7112. 2122. 2132. 4830. 4870. 2110.
#  6242. 1130. 5180. 7223.]
# VALUE COUNTS  1110.0     146
# 1121.0       3
# 1130.0       1
# 1150.0       3
# 2110.0       1
# 2122.0       2
# 2132.0       1
# 2210.0      20
# 2221.0      10
# 2222.0       9
# 2361.0     212
# 2363.0      65
# 2370.0      49
# 2381.0     151
# 2382.0     639
# 2399.0       6
# 3110.0     458
# 3120.0      97
# 3130.0      21
# 3140.0      51
# 3150.0     184
# 3160.0      35
# 3210.0      24
# 3220.0      59
# 3230.0      78
# 3240.0      11
# 3250.0     231
# 3260.0     148
# 3270.0      34
# 3310.0      16
#           ...
# 6251.0      12
# 6252.0       5
# 7111.0      41
# 7112.0       2
# 7113.0      17
# 7114.0      42
# 7120.0      11
# 7131.0      82
# 7132.0      10
# 7133.0       1
# 7210.0      94
# 7221.0    1051
# 7222.0     169
# 7223.0       1
# 8111.0     291
# 8112.0     192
# 8121.0     373
# 8122.0      19
# 8123.0      17
# 8125.0       5
# 8130.0     142
# 8140.0     973
# 9311.0      21
# 9312.0     702
# 9313.0     348
# 9314.0     271
# 9320.0       5
# 9700.0      35
# 9800.0       5
# 9999.0      63
# Name: p4a, Length: 147, dtype: int64
#
#
# COLUMNA:  p4a_1
# TIPO:  otro
# NUNIQUE:  1
# UNIQUE:  ['1' nan]
# VALUE COUNTS  1    17604
# Name: p4a_1, dtype: int64
#
#
# COLUMNA:  p4b
# TIPO:  otro
# NUNIQUE:  4
# UNIQUE:  ['4' nan '2' '3' '1']
# VALUE COUNTS  1      149
# 2     1303
# 3     1853
# 4    13286
# Name: p4b, dtype: int64
#
#
# COLUMNA:  p4c
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  ['1' nan '2']
# VALUE COUNTS  1    7728
# 2    5558
# Name: p4c, dtype: int64
#
#
# COLUMNA:  p4d1
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '1' '2']
# VALUE COUNTS  1    2332
# 2     824
# Name: p4d1, dtype: int64
#
#
# COLUMNA:  p4d2
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  [nan '3' '6' '4' '1' '2' '7' '5']
# VALUE COUNTS  1    487
# 2    323
# 3    858
# 4    674
# 5    468
# 6    295
# 7     51
# Name: p4d2, dtype: int64
#
#
# COLUMNA:  p4d3
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '3' '2' '1']
# VALUE COUNTS  1      93
# 2    2638
# 3    5949
# Name: p4d3, dtype: int64
#
#
# COLUMNA:  p4e
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  ['4' nan '3' '2' '1' '9']
# VALUE COUNTS  1     212
# 2     550
# 3    2747
# 4    4216
# 9       3
# Name: p4e, dtype: int64
#
#
# COLUMNA:  p4f
# TIPO:  flotante
# NUNIQUE:  11
# UNIQUE:  [ 8. nan 10.  6.  3.  5.  2.  7.  9.  4. 11. 99.]
# VALUE COUNTS  2.0      265
# 3.0      438
# 4.0       68
# 5.0      658
# 6.0      562
# 7.0      119
# 8.0     1497
# 9.0      545
# 10.0      49
# 11.0      17
# 99.0       1
# Name: p4f, dtype: int64
#
#
# COLUMNA:  p4g
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  ['4' nan '2' '1' '9' '3']
# VALUE COUNTS  1    1842
# 2    1213
# 3     423
# 4    3824
# 9     214
# Name: p4g, dtype: int64
#
#
# COLUMNA:  p4h
# TIPO:  otro
# NUNIQUE:  6
# UNIQUE:  [nan '1' '4' '3' '2' '5' '9']
# VALUE COUNTS  1    4497
# 2     687
# 3     414
# 4     132
# 5      39
# 9       1
# Name: p4h, dtype: int64
#
#
# COLUMNA:  p4i
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  [nan '3' '1' '2' '9' '4']
# VALUE COUNTS  1     873
# 2    1866
# 3    2821
# 4     134
# 9      76
# Name: p4i, dtype: int64
#
#
# COLUMNA:  p4i_1
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '3' '2' '1']
# VALUE COUNTS  1      43
# 2     101
# 3    5626
# Name: p4i_1, dtype: int64
#
#
# COLUMNA:  p5
# TIPO:  otro
# NUNIQUE:  5
# UNIQUE:  ['1' nan '3' '2' '4' '9']
# VALUE COUNTS  1     4946
# 2      316
# 3    12229
# 4       53
# 9       15
# Name: p5, dtype: int64
#
#
# COLUMNA:  p5a
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  ['1' '2' nan '3' '9' '4' '6' '5']
# VALUE COUNTS  1    1052
# 2     253
# 3    3905
# 4      58
# 5       2
# 6      14
# 9       6
# Name: p5a, dtype: int64
#
#
# COLUMNA:  p5b
# TIPO:  otro
# NUNIQUE:  6
# UNIQUE:  ['1' nan '4' '3' '5' '6' '2']
# VALUE COUNTS  1    235
# 2     14
# 3     52
# 4     35
# 5      5
# 6      4
# Name: p5b, dtype: int64
#
#
# COLUMNA:  p5b_hdo
# TIPO:  flotante
# NUNIQUE:  25
# UNIQUE:  [nan  0.  9.  2.  6. 12.  8. 16.  7. 10. 11.  5.  4.  3. 17. 18. 98. 99.
#  14. 24. 13. 20.  1. 15. 19. 22.]
# VALUE COUNTS  0.0     10212
# 1.0         5
# 2.0        42
# 3.0        43
# 4.0        97
# 5.0       143
# 6.0       212
# 7.0       105
# 8.0       788
# 9.0       260
# 10.0      525
# 11.0       49
# 12.0      317
# 13.0       16
# 14.0       41
# 15.0       12
# 16.0       61
# 17.0        2
# 18.0       17
# 19.0        1
# 20.0        3
# 22.0        1
# 24.0        3
# 98.0       15
# 99.0        1
# Name: p5b_hdo, dtype: int64
#
#
# COLUMNA:  p5b_hju
# TIPO:  flotante
# NUNIQUE:  23
# UNIQUE:  [nan  8.  6.  7.  9.  0. 10. 12.  3.  4.  2. 11.  5. 16. 18. 98. 17. 14.
#   1. 15. 13. 20. 19. 24.]
# VALUE COUNTS  0.0     1301
# 1.0       40
# 2.0      133
# 3.0      127
# 4.0      346
# 5.0      417
# 6.0      750
# 7.0      518
# 8.0     4556
# 9.0     1601
# 10.0    1990
# 11.0     157
# 12.0     805
# 13.0      38
# 14.0      55
# 15.0      14
# 16.0      49
# 17.0       4
# 18.0      16
# 19.0       1
# 20.0       4
# 24.0       1
# 98.0      48
# Name: p5b_hju, dtype: int64
#
#
# COLUMNA:  p5b_hlu
# TIPO:  flotante
# NUNIQUE:  23
# UNIQUE:  [nan  8.  6.  7.  0.  9. 12.  3. 10.  4.  2. 16. 11.  5. 17. 18. 98.  1.
#  14. 15. 24. 13. 19. 20.]
# VALUE COUNTS  0.0     1361
# 1.0       39
# 2.0      140
# 3.0      145
# 4.0      359
# 5.0      410
# 6.0      760
# 7.0      527
# 8.0     4505
# 9.0     1571
# 10.0    1926
# 11.0     155
# 12.0     807
# 13.0      41
# 14.0      60
# 15.0      16
# 16.0      68
# 17.0       2
# 18.0      25
# 19.0       1
# 20.0       2
# 24.0       3
# 98.0      48
# Name: p5b_hlu, dtype: int64
#
#
# COLUMNA:  p5b_hma
# TIPO:  flotante
# NUNIQUE:  22
# UNIQUE:  [nan  8.  0.  7.  9. 12.  3.  6. 10.  4.  2. 18. 11.  5. 16. 98.  1. 17.
#  14. 15. 13. 19. 20.]
# VALUE COUNTS  0.0     1375
# 1.0       37
# 2.0      122
# 3.0      136
# 4.0      347
# 5.0      401
# 6.0      759
# 7.0      522
# 8.0     4548
# 9.0     1603
# 10.0    1955
# 11.0     157
# 12.0     811
# 13.0      37
# 14.0      47
# 15.0      14
# 16.0      34
# 17.0       5
# 18.0      12
# 19.0       1
# 20.0       1
# 98.0      47
# Name: p5b_hma, dtype: int64
#
#
# COLUMNA:  p5b_hmi
# TIPO:  flotante
# NUNIQUE:  22
# UNIQUE:  [nan  8.  6.  7.  9. 10. 12.  3.  4.  2.  0. 16. 11.  5. 17. 98.  1. 14.
#  18. 15. 24. 13. 20.]
# VALUE COUNTS  0.0     1310
# 1.0       41
# 2.0      143
# 3.0      153
# 4.0      373
# 5.0      406
# 6.0      763
# 7.0      514
# 8.0     4534
# 9.0     1597
# 10.0    1965
# 11.0     163
# 12.0     782
# 13.0      37
# 14.0      62
# 15.0      16
# 16.0      46
# 17.0       3
# 18.0      13
# 20.0       2
# 24.0       2
# 98.0      46
# Name: p5b_hmi, dtype: int64
#
#
# COLUMNA:  p5b_hsa
# TIPO:  flotante
# NUNIQUE:  25
# UNIQUE:  [nan  8.  6.  0.  9. 12.  3.  5. 10.  2. 18.  7. 16. 11.  4. 98. 17. 14.
#  99. 15.  1. 13. 20. 19. 24. 22.]
# VALUE COUNTS  0.0     6272
# 1.0        8
# 2.0       69
# 3.0       92
# 4.0      331
# 5.0      745
# 6.0      750
# 7.0      243
# 8.0     2068
# 9.0      604
# 10.0    1007
# 11.0      99
# 12.0     525
# 13.0      24
# 14.0      48
# 15.0      16
# 16.0      29
# 17.0       3
# 18.0       5
# 19.0       1
# 20.0       4
# 22.0       1
# 24.0       1
# 98.0      25
# 99.0       1
# Name: p5b_hsa, dtype: int64
#
#
# COLUMNA:  p5b_hvi
# TIPO:  flotante
# NUNIQUE:  23
# UNIQUE:  [nan  8.  6.  7.  9. 10. 12.  3.  4.  2.  0. 16. 11.  5. 17. 18. 98. 14.
#  15. 24.  1. 13. 20. 19.]
# VALUE COUNTS  0.0     1088
# 1.0       43
# 2.0      141
# 3.0      154
# 4.0      382
# 5.0      428
# 6.0      785
# 7.0      534
# 8.0     4583
# 9.0     1603
# 10.0    1998
# 11.0     154
# 12.0     833
# 13.0      35
# 14.0      59
# 15.0      16
# 16.0      57
# 17.0       4
# 18.0      19
# 19.0       1
# 20.0       5
# 24.0       2
# 98.0      47
# Name: p5b_hvi, dtype: int64
#
#
# COLUMNA:  p5b_mdo
# TIPO:  flotante
# NUNIQUE:  5
# UNIQUE:  [nan  0. 30.  1. 10. 11.]
# VALUE COUNTS  0.0     12950
# 1.0         9
# 10.0        1
# 11.0        1
# 30.0       10
# Name: p5b_mdo, dtype: int64
#
#
# COLUMNA:  p5b_mju
# TIPO:  flotante
# NUNIQUE:  5
# UNIQUE:  [nan  0. 30.  1. 20.  9.]
# VALUE COUNTS  0.0     12817
# 1.0         2
# 9.0         1
# 20.0        2
# 30.0      149
# Name: p5b_mju, dtype: int64
#
#
# COLUMNA:  p5b_mlu
# TIPO:  flotante
# NUNIQUE:  5
# UNIQUE:  [nan  0. 30.  8. 15.  9.]
# VALUE COUNTS  0.0     12826
# 8.0         1
# 9.0         1
# 15.0        1
# 30.0      142
# Name: p5b_mlu, dtype: int64
#
#
# COLUMNA:  p5b_mma
# TIPO:  flotante
# NUNIQUE:  6
# UNIQUE:  [nan  0. 30.  8.  3. 15.  9.]
# VALUE COUNTS  0.0     12824
# 3.0         1
# 8.0         1
# 9.0         1
# 15.0        1
# 30.0      143
# Name: p5b_mma, dtype: int64
#
#
# COLUMNA:  p5b_mmi
# TIPO:  flotante
# NUNIQUE:  9
# UNIQUE:  [nan  0. 30.  3.  6.  8.  2. 20. 10.  9.]
# VALUE COUNTS  0.0     12820
# 2.0         1
# 3.0         2
# 6.0         1
# 8.0         1
# 9.0         1
# 10.0        1
# 20.0        1
# 30.0      143
# Name: p5b_mmi, dtype: int64
#
#
# COLUMNA:  p5b_msa
# TIPO:  flotante
# NUNIQUE:  3
# UNIQUE:  [nan  0. 30. 20.]
# VALUE COUNTS  0.0     12924
# 20.0        2
# 30.0       45
# Name: p5b_msa, dtype: int64
#
#
# COLUMNA:  p5b_mvi
# TIPO:  flotante
# NUNIQUE:  6
# UNIQUE:  [nan  0. 30.  1. 40.  8. 10.]
# VALUE COUNTS  0.0     12820
# 1.0         2
# 8.0         1
# 10.0        1
# 30.0      146
# 40.0        1
# Name: p5b_mvi, dtype: int64
#
#
# COLUMNA:  p5b_tdia
# TIPO:  otro
# NUNIQUE:  8
# UNIQUE:  [nan '6' '5' '3' '7' '4' '2' '1' '9']
# VALUE COUNTS  1     206
# 2     462
# 3     539
# 4     647
# 5    5170
# 6    4917
# 7    1029
# 9       1
# Name: p5b_tdia, dtype: int64
#
#
# COLUMNA:  p5b_thrs
# TIPO:  flotante
# NUNIQUE:  100
# UNIQUE:  [ nan  48.  30.  35.  40.  54.  45.  72.  18.  70.  55.  20.  14.  42.
#   56.  50.  60.  88.  49.  12.  84.  75.  66.  36.  77.  25.  28.  44.
#   63.  24.  53.  51.  27.  64.  11.  61.  52.  15.  16.   8.  10.  46.
#   21.   6.  80.  58.  47.  34.  89.   4.  29.  32.   3.  76.  65. 999.
#    7.  79.  33.   2.  86.  90.   5.  68.   9.  13.   1.  17.  43.  22.
#   62.  31.  41.  98.  96. 103.  26.  71.  37.  59.  78.  57. 108.  23.
#   85. 112.  91. 114. 105.  39. 126.  19.  82.  67.  69.  38.  74. 120.
#   81.  95.  87.]
# VALUE COUNTS  1.0        9
# 2.0       32
# 3.0       25
# 4.0       61
# 5.0       48
# 6.0       74
# 7.0       18
# 8.0       91
# 9.0       54
# 10.0     108
# 11.0      14
# 12.0     163
# 13.0       6
# 14.0      45
# 15.0     104
# 16.0     124
# 17.0       6
# 18.0     108
# 19.0       6
# 20.0     233
# 21.0      51
# 22.0      21
# 23.0       5
# 24.0     289
# 25.0     167
# 26.0      13
# 27.0      28
# 28.0      82
# 29.0      10
# 30.0     494
#         ...
# 71.0       5
# 72.0     315
# 74.0       3
# 75.0      10
# 76.0       8
# 77.0      22
# 78.0      23
# 79.0       4
# 80.0       8
# 81.0       1
# 82.0       3
# 84.0     145
# 85.0       2
# 86.0       5
# 87.0       1
# 88.0      20
# 89.0       2
# 90.0      10
# 91.0      10
# 95.0       1
# 96.0      15
# 98.0      18
# 103.0      1
# 105.0      5
# 108.0      2
# 112.0      5
# 114.0      1
# 120.0      2
# 126.0      2
# 999.0     51
# Name: p5b_thrs, Length: 100, dtype: int64
#
#
# COLUMNA:  p5c
# TIPO:  otro
# NUNIQUE:  3
# UNIQUE:  [nan '1' '2' '9']
# VALUE COUNTS  1    11286
# 2     1684
# 9        1
# Name: p5c, dtype: int64
#
#
# COLUMNA:  p5c_hdo
# TIPO:  flotante
# NUNIQUE:  22
# UNIQUE:  [ 0. nan  8. 10. 14. 12.  5.  9.  7.  6.  4.  1. 16.  3. 11. 18. 98.  2.
#  22. 24. 15. 17. 13.]
# VALUE COUNTS  0.0     3264
# 1.0        6
# 2.0        9
# 3.0       19
# 4.0       29
# 5.0       52
# 6.0       72
# 7.0       41
# 8.0      252
# 9.0       78
# 10.0     148
# 11.0      19
# 12.0     107
# 13.0       5
# 14.0      14
# 15.0       6
# 16.0      16
# 17.0       5
# 18.0       7
# 22.0       1
# 24.0       2
# 98.0       3
# Name: p5c_hdo, dtype: int64
#
#
# COLUMNA:  p5c_hju
# TIPO:  flotante
# NUNIQUE:  21
# UNIQUE:  [ 0. nan  4.  8.  5. 10.  9. 12.  2.  6.  3. 24.  7. 11. 16. 98. 14. 18.
#   1. 17. 15. 13.]
# VALUE COUNTS  0.0      536
# 1.0       17
# 2.0       34
# 3.0       48
# 4.0      104
# 5.0      154
# 6.0      257
# 7.0      182
# 8.0     1336
# 9.0      513
# 10.0     602
# 11.0      68
# 12.0     244
# 13.0       6
# 14.0      17
# 15.0       7
# 16.0      10
# 17.0       2
# 18.0       2
# 24.0       1
# 98.0      15
# Name: p5c_hju, dtype: int64
#
#
# COLUMNA:  p5c_hlu
# TIPO:  flotante
# NUNIQUE:  21
# UNIQUE:  [ 4. nan  8. 10.  5.  9.  0. 12.  2. 14.  6.  3.  7. 11. 16. 98. 18. 17.
#   1. 24. 15. 13.]
# VALUE COUNTS  0.0      481
# 1.0       11
# 2.0       37
# 3.0       59
# 4.0       89
# 5.0      146
# 6.0      245
# 7.0      179
# 8.0     1386
# 9.0      532
# 10.0     593
# 11.0      65
# 12.0     255
# 13.0       6
# 14.0      17
# 15.0       6
# 16.0      18
# 17.0       6
# 18.0       7
# 24.0       2
# 98.0      15
# Name: p5c_hlu, dtype: int64
#
#
# COLUMNA:  p5c_hma
# TIPO:  flotante
# NUNIQUE:  20
# UNIQUE:  [ 0. nan  8. 10.  5.  4.  9. 12.  2. 14.  3.  6. 24.  7. 11.  1. 98. 16.
#  13. 17. 15.]
# VALUE COUNTS  0.0      408
# 1.0       12
# 2.0       38
# 3.0       43
# 4.0      105
# 5.0      143
# 6.0      247
# 7.0      184
# 8.0     1413
# 9.0      554
# 10.0     621
# 11.0      74
# 12.0     259
# 13.0       7
# 14.0      16
# 15.0       6
# 16.0       6
# 17.0       2
# 24.0       1
# 98.0      16
# Name: p5c_hma, dtype: int64
#
#
# COLUMNA:  p5c_hmi
# TIPO:  flotante
# NUNIQUE:  21
# UNIQUE:  [ 4. nan  8. 10.  5.  9. 12.  2. 14.  0.  6.  7. 11.  3. 16. 98. 18.  1.
#  17. 24. 15. 13.]
# VALUE COUNTS  0.0      359
# 1.0       15
# 2.0       38
# 3.0       54
# 4.0      100
# 5.0      146
# 6.0      261
# 7.0      187
# 8.0     1417
# 9.0      562
# 10.0     623
# 11.0      72
# 12.0     251
# 13.0      10
# 14.0      17
# 15.0       7
# 16.0       9
# 17.0       5
# 18.0       5
# 24.0       2
# 98.0      15
# Name: p5c_hmi, dtype: int64
#
#
# COLUMNA:  p5c_hsa
# TIPO:  flotante
# NUNIQUE:  21
# UNIQUE:  [ 0. nan 10.  8.  5.  9. 12.  4.  3. 14.  6.  7.  2. 98. 16. 11.  1. 17.
#  18. 15. 13. 20.]
# VALUE COUNTS  0.0     2080
# 1.0        6
# 2.0       20
# 3.0       35
# 4.0       92
# 5.0      256
# 6.0      232
# 7.0       93
# 8.0      591
# 9.0      186
# 10.0     304
# 11.0      34
# 12.0     174
# 13.0       7
# 14.0      16
# 15.0       8
# 16.0       5
# 17.0       2
# 18.0       2
# 20.0       1
# 98.0      11
# Name: p5c_hsa, dtype: int64
#
#
# COLUMNA:  p5c_hvi
# TIPO:  flotante
# NUNIQUE:  20
# UNIQUE:  [ 0. nan  8. 10.  5.  3.  4.  6. 12.  9.  7. 11.  2.  1. 98. 14. 16. 18.
#  17. 15. 13.]
# VALUE COUNTS  0.0      643
# 1.0       15
# 2.0       40
# 3.0       48
# 4.0       86
# 5.0      146
# 6.0      254
# 7.0      166
# 8.0     1311
# 9.0      493
# 10.0     581
# 11.0      65
# 12.0     233
# 13.0       7
# 14.0      18
# 15.0       8
# 16.0      13
# 17.0       5
# 18.0       6
# 98.0      17
# Name: p5c_hvi, dtype: int64
#
#
# COLUMNA:  p5c_mdo
# TIPO:  flotante
# NUNIQUE:  4
# UNIQUE:  [ 0. nan 30.  1.  9.]
# VALUE COUNTS  0.0     4141
# 1.0        2
# 9.0        1
# 30.0      11
# Name: p5c_mdo, dtype: int64
#
#
# COLUMNA:  p5c_mju
# TIPO:  flotante
# NUNIQUE:  4
# UNIQUE:  [ 0. nan  8. 30. 33.]
# VALUE COUNTS  0.0     4103
# 8.0        1
# 30.0      50
# 33.0       1
# Name: p5c_mju, dtype: int64
#
#
# COLUMNA:  p5c_mlu
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [ 0. nan 30.]
# VALUE COUNTS  0.0     4106
# 30.0      49
# Name: p5c_mlu, dtype: int64
#
#
# COLUMNA:  p5c_mma
# TIPO:  flotante
# NUNIQUE:  4
# UNIQUE:  [ 0. nan 30.  1. 33.]
# VALUE COUNTS  0.0     4102
# 1.0        1
# 30.0      51
# 33.0       1
# Name: p5c_mma, dtype: int64
#
#
# COLUMNA:  p5c_mmi
# TIPO:  flotante
# NUNIQUE:  3
# UNIQUE:  [ 0. nan 30.  3.]
# VALUE COUNTS  0.0     4105
# 3.0        1
# 30.0      49
# Name: p5c_mmi, dtype: int64
#
#
# COLUMNA:  p5c_msa
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [ 0. nan 30.]
# VALUE COUNTS  0.0     4143
# 30.0      12
# Name: p5c_msa, dtype: int64
#
#
# COLUMNA:  p5c_mvi
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [ 0. nan 30.]
# VALUE COUNTS  0.0     4105
# 30.0      50
# Name: p5c_mvi, dtype: int64
#
#
# COLUMNA:  p5c_tdia
# TIPO:  otro
# NUNIQUE:  8
# UNIQUE:  ['2' nan '6' '5' '4' '3' '7' '1' '9']
# VALUE COUNTS  1      58
# 2     169
# 3     295
# 4     246
# 5    1608
# 6    1410
# 7     352
# 9      17
# Name: p5c_tdia, dtype: int64
#
#
# COLUMNA:  p5c_thrs
# TIPO:  flotante
# NUNIQUE:  90
# UNIQUE:  [  8.  nan  44.  40.  29.  24.  48.  15.  12.  27.  60.  30.  45.  14.
#   32.  82.  72.  38.  28.  41.  50.  25.   6.  46.   9.  36.  37.  63.
#   49.  54.  17.  35.  34.  18.  42.  10.  84.  70.  56.  20.   4.  21.
#   16.  57.  13.  47.  64.   5. 999.  66.  55.  98.  52.  96.   7.  19.
#   87.  61.  90.  11.  88. 102.  43.  53.  65.  68.  26.   1.  51.  22.
#   33.   2.   3.  67. 114.  75. 100.  39.  71.  77.  78.  85. 105.  31.
#   58.  62.  23.  91.  86.  89.  59.]
# VALUE COUNTS  1.0        3
# 2.0        9
# 3.0        6
# 4.0       14
# 5.0       14
# 6.0       30
# 7.0        5
# 8.0       20
# 9.0       24
# 10.0      33
# 11.0       3
# 12.0      47
# 13.0       4
# 14.0      14
# 15.0      36
# 16.0      48
# 17.0       3
# 18.0      52
# 19.0       3
# 20.0      69
# 21.0      24
# 22.0      13
# 23.0       1
# 24.0     123
# 25.0      67
# 26.0       4
# 27.0      30
# 28.0      43
# 29.0       9
# 30.0     185
#         ...
# 61.0       7
# 62.0       1
# 63.0      32
# 64.0      11
# 65.0      10
# 66.0      42
# 67.0       2
# 68.0       7
# 70.0      63
# 71.0       2
# 72.0      96
# 75.0       6
# 77.0       7
# 78.0       5
# 82.0       2
# 84.0      48
# 85.0       1
# 86.0       1
# 87.0       1
# 88.0       7
# 89.0       4
# 90.0       6
# 91.0       2
# 96.0       2
# 98.0       8
# 100.0      1
# 102.0      1
# 105.0      1
# 114.0      1
# 999.0     17
# Name: p5c_thrs, Length: 90, dtype: int64
#
#
# COLUMNA:  p5d
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  ['2' nan '1']
# VALUE COUNTS  1    3401
# 2     754
# Name: p5d, dtype: int64
#
#
# COLUMNA:  p5d1
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '1' '2']
# VALUE COUNTS  1     904
# 2    1059
# Name: p5d1, dtype: int64
#
#
# COLUMNA:  p5d_hdo
# TIPO:  flotante
# NUNIQUE:  16
# UNIQUE:  [nan  0. 12.  9. 10.  8. 16.  6. 18. 14.  3. 13.  7.  4.  2.  5. 11.]
# VALUE COUNTS  0.0     812
# 2.0       1
# 3.0       2
# 4.0       1
# 5.0       2
# 6.0       7
# 7.0       4
# 8.0      24
# 9.0      13
# 10.0     13
# 11.0      1
# 12.0     15
# 13.0      2
# 14.0      1
# 16.0      3
# 18.0      3
# Name: p5d_hdo, dtype: int64
#
#
# COLUMNA:  p5d_hju
# TIPO:  flotante
# NUNIQUE:  17
# UNIQUE:  [nan  6.  8. 12.  0.  7.  4.  1.  5.  9.  3. 10. 11. 16. 13.  2. 18. 14.]
# VALUE COUNTS  0.0      38
# 1.0       6
# 2.0       3
# 3.0      10
# 4.0      16
# 5.0      28
# 6.0      72
# 7.0      64
# 8.0     373
# 9.0     125
# 10.0    105
# 11.0     10
# 12.0     45
# 13.0      4
# 14.0      2
# 16.0      1
# 18.0      2
# Name: p5d_hju, dtype: int64
#
#
# COLUMNA:  p5d_hlu
# TIPO:  flotante
# NUNIQUE:  17
# UNIQUE:  [nan  6.  8. 12.  7.  4.  1.  0.  5.  9. 10. 11.  2. 16. 18. 14. 13.  3.]
# VALUE COUNTS  0.0      40
# 1.0       6
# 2.0       3
# 3.0       9
# 4.0      19
# 5.0      28
# 6.0      72
# 7.0      64
# 8.0     368
# 9.0     124
# 10.0    104
# 11.0     10
# 12.0     46
# 13.0      2
# 14.0      3
# 16.0      3
# 18.0      3
# Name: p5d_hlu, dtype: int64
#
#
# COLUMNA:  p5d_hma
# TIPO:  flotante
# NUNIQUE:  15
# UNIQUE:  [nan  6.  8. 12.  0.  7.  4.  1.  5.  9. 10. 11.  3. 13.  2. 14.]
# VALUE COUNTS  0.0      38
# 1.0       6
# 2.0       3
# 3.0       9
# 4.0      16
# 5.0      28
# 6.0      76
# 7.0      63
# 8.0     371
# 9.0     126
# 10.0    105
# 11.0     10
# 12.0     47
# 13.0      4
# 14.0      2
# Name: p5d_hma, dtype: int64
#
#
# COLUMNA:  p5d_hmi
# TIPO:  flotante
# NUNIQUE:  17
# UNIQUE:  [nan  6.  8. 12.  0.  7.  4.  1.  9.  5.  3. 10. 11.  2. 18. 16. 14. 13.]
# VALUE COUNTS  0.0      26
# 1.0       7
# 2.0       4
# 3.0       8
# 4.0      19
# 5.0      26
# 6.0      72
# 7.0      64
# 8.0     372
# 9.0     129
# 10.0    108
# 11.0     10
# 12.0     49
# 13.0      4
# 14.0      3
# 16.0      2
# 18.0      1
# Name: p5d_hmi, dtype: int64
#
#
# COLUMNA:  p5d_hsa
# TIPO:  flotante
# NUNIQUE:  14
# UNIQUE:  [nan  0.  8.  5. 12.  7.  9. 11. 10.  4.  6. 13.  3. 14.  2.]
# VALUE COUNTS  0.0     584
# 2.0       1
# 3.0       2
# 4.0      11
# 5.0      53
# 6.0      38
# 7.0      15
# 8.0      90
# 9.0      38
# 10.0     34
# 11.0      7
# 12.0     26
# 13.0      3
# 14.0      2
# Name: p5d_hsa, dtype: int64
#
#
# COLUMNA:  p5d_hvi
# TIPO:  flotante
# NUNIQUE:  17
# UNIQUE:  [nan  6.  8. 12.  0.  7.  4.  1.  5.  9. 10. 11.  2. 18. 16. 14. 13.  3.]
# VALUE COUNTS  0.0      24
# 1.0       5
# 2.0       6
# 3.0       8
# 4.0      18
# 5.0      28
# 6.0      76
# 7.0      65
# 8.0     374
# 9.0     125
# 10.0    106
# 11.0     11
# 12.0     49
# 13.0      3
# 14.0      3
# 16.0      2
# 18.0      1
# Name: p5d_hvi, dtype: int64
#
#
# COLUMNA:  p5d_mdo
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     903
# 30.0      1
# Name: p5d_mdo, dtype: int64
#
#
# COLUMNA:  p5d_mju
# TIPO:  flotante
# NUNIQUE:  3
# UNIQUE:  [nan  0.  3. 30.]
# VALUE COUNTS  0.0     884
# 3.0       1
# 30.0     19
# Name: p5d_mju, dtype: int64
#
#
# COLUMNA:  p5d_mlu
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     885
# 30.0     19
# Name: p5d_mlu, dtype: int64
#
#
# COLUMNA:  p5d_mma
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     884
# 30.0     20
# Name: p5d_mma, dtype: int64
#
#
# COLUMNA:  p5d_mmi
# TIPO:  flotante
# NUNIQUE:  3
# UNIQUE:  [nan  0. 30.  1.]
# VALUE COUNTS  0.0     883
# 1.0       1
# 30.0     20
# Name: p5d_mmi, dtype: int64
#
#
# COLUMNA:  p5d_msa
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     899
# 30.0      5
# Name: p5d_msa, dtype: int64
#
#
# COLUMNA:  p5d_mvi
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     884
# 30.0     20
# Name: p5d_mvi, dtype: int64
#
#
# COLUMNA:  p5d_tdia
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  [nan '5' '6' '1' '2' '3' '7' '4']
# VALUE COUNTS  1      3
# 2     12
# 3     18
# 4      9
# 5    554
# 6    277
# 7     31
# Name: p5d_tdia, dtype: int64
#
#
# COLUMNA:  p5d_thrs
# TIPO:  flotante
# NUNIQUE:  56
# UNIQUE:  [nan 30. 40. 48. 60.  8. 35. 22.  5. 45. 41. 12. 25. 72. 42.  6. 54. 55.
#  33. 66. 50. 56. 20. 32. 49. 37. 64. 90. 27. 36. 88. 24. 18. 84. 69. 51.
#   4. 78. 47. 21. 46. 15. 44. 61. 16. 62. 17. 67. 65. 70. 52. 57. 31. 58.
#  63. 10. 92.]
# VALUE COUNTS  4.0       3
# 5.0       6
# 6.0       4
# 8.0       2
# 10.0      1
# 12.0      5
# 15.0      7
# 16.0      1
# 17.0      1
# 18.0      3
# 20.0     14
# 21.0      2
# 22.0      4
# 24.0      6
# 25.0     18
# 27.0      1
# 30.0     66
# 31.0      1
# 32.0      2
# 33.0      1
# 35.0     49
# 36.0     15
# 37.0      6
# 40.0    253
# 41.0      2
# 42.0     15
# 44.0      8
# 45.0     81
# 46.0      4
# 47.0      2
# 48.0     78
# 49.0      3
# 50.0     57
# 51.0      8
# 52.0      2
# 54.0     35
# 55.0     16
# 56.0     18
# 57.0      2
# 58.0      1
# 60.0     49
# 61.0      1
# 62.0      3
# 63.0      1
# 64.0      1
# 65.0      1
# 66.0     11
# 67.0      1
# 69.0      1
# 70.0      4
# 72.0     16
# 78.0      2
# 84.0      6
# 88.0      2
# 90.0      1
# 92.0      1
# Name: p5d_thrs, dtype: int64
#
#
# COLUMNA:  p5e
# TIPO:  flotante
# NUNIQUE:  13
# UNIQUE:  [nan  5.  9. 10. 12.  3.  1.  8.  7.  6. 11.  2.  4. 99.]
# VALUE COUNTS  1.0      19
# 2.0       1
# 3.0      14
# 4.0       3
# 5.0      46
# 6.0       1
# 7.0       5
# 8.0     500
# 9.0      14
# 10.0      7
# 11.0     13
# 12.0     23
# 99.0      1
# Name: p5e, dtype: int64
#
#
# COLUMNA:  p5e1
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  ['2' '1' nan]
# VALUE COUNTS  1    627
# 2    322
# Name: p5e1, dtype: int64
#
#
# COLUMNA:  p5e_hdo
# TIPO:  flotante
# NUNIQUE:  15
# UNIQUE:  [nan  0.  8. 14. 12.  5. 10.  6.  9.  7.  4. 16. 18.  3. 17. 13.]
# VALUE COUNTS  0.0     568
# 3.0       1
# 4.0       1
# 5.0       4
# 6.0       3
# 7.0       4
# 8.0      20
# 9.0       4
# 10.0      9
# 12.0      8
# 13.0      1
# 14.0      1
# 16.0      1
# 17.0      1
# 18.0      1
# Name: p5e_hdo, dtype: int64
#
#
# COLUMNA:  p5e_hju
# TIPO:  flotante
# NUNIQUE:  17
# UNIQUE:  [nan  8.  7. 10.  4.  0.  5.  9. 12. 14.  6.  3. 11.  2. 18.  1. 17. 13.]
# VALUE COUNTS  0.0      21
# 1.0       1
# 2.0       3
# 3.0       5
# 4.0      13
# 5.0      25
# 6.0      28
# 7.0      44
# 8.0     257
# 9.0      93
# 10.0     93
# 11.0     11
# 12.0     29
# 13.0      1
# 14.0      1
# 17.0      1
# 18.0      1
# Name: p5e_hju, dtype: int64
#
#
# COLUMNA:  p5e_hlu
# TIPO:  flotante
# NUNIQUE:  17
# UNIQUE:  [nan  0.  8.  7. 10.  4.  5.  9. 12. 14.  6.  3. 11.  2. 16. 18. 17. 13.]
# VALUE COUNTS  0.0      19
# 2.0       3
# 3.0       6
# 4.0      14
# 5.0      24
# 6.0      28
# 7.0      44
# 8.0     252
# 9.0      94
# 10.0     95
# 11.0     11
# 12.0     32
# 13.0      1
# 14.0      1
# 16.0      1
# 17.0      1
# 18.0      1
# Name: p5e_hlu, dtype: int64
#
#
# COLUMNA:  p5e_hma
# TIPO:  flotante
# NUNIQUE:  15
# UNIQUE:  [nan  8.  7. 10.  4.  5.  9. 12.  0. 14.  6.  3. 11.  2. 17. 13.]
# VALUE COUNTS  0.0      17
# 2.0       3
# 3.0       4
# 4.0      13
# 5.0      25
# 6.0      30
# 7.0      44
# 8.0     256
# 9.0      96
# 10.0     95
# 11.0     11
# 12.0     30
# 13.0      1
# 14.0      1
# 17.0      1
# Name: p5e_hma, dtype: int64
#
#
# COLUMNA:  p5e_hmi
# TIPO:  flotante
# NUNIQUE:  17
# UNIQUE:  [nan  0.  8.  7. 10.  4.  5.  9. 12. 14.  6.  3. 11.  1.  2. 16. 17. 13.]
# VALUE COUNTS  0.0      17
# 1.0       1
# 2.0       3
# 3.0       6
# 4.0      13
# 5.0      25
# 6.0      30
# 7.0      45
# 8.0     251
# 9.0      94
# 10.0     95
# 11.0     11
# 12.0     32
# 13.0      1
# 14.0      1
# 16.0      1
# 17.0      1
# Name: p5e_hmi, dtype: int64
#
#
# COLUMNA:  p5e_hsa
# TIPO:  flotante
# NUNIQUE:  15
# UNIQUE:  [nan  8.  0. 10.  5.  9. 12.  4.  2. 14.  6.  3.  7.  1. 17. 13.]
# VALUE COUNTS  0.0     365
# 1.0       1
# 2.0       1
# 3.0       4
# 4.0      14
# 5.0      49
# 6.0      26
# 7.0      12
# 8.0      74
# 9.0      23
# 10.0     38
# 12.0     17
# 13.0      1
# 14.0      1
# 17.0      1
# Name: p5e_hsa, dtype: int64
#
#
# COLUMNA:  p5e_hvi
# TIPO:  flotante
# NUNIQUE:  16
# UNIQUE:  [nan  0.  8.  7. 10.  4.  5.  9. 12.  2. 14.  6.  3. 11. 16. 17. 13.]
# VALUE COUNTS  0.0      15
# 2.0       3
# 3.0       6
# 4.0      14
# 5.0      24
# 6.0      29
# 7.0      45
# 8.0     256
# 9.0      92
# 10.0     94
# 11.0     11
# 12.0     34
# 13.0      1
# 14.0      1
# 16.0      1
# 17.0      1
# Name: p5e_hvi, dtype: int64
#
#
# COLUMNA:  p5e_mdo
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  0.]
# VALUE COUNTS  0.0    627
# Name: p5e_mdo, dtype: int64
#
#
# COLUMNA:  p5e_mju
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     616
# 30.0     11
# Name: p5e_mju, dtype: int64
#
#
# COLUMNA:  p5e_mlu
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     616
# 30.0     11
# Name: p5e_mlu, dtype: int64
#
#
# COLUMNA:  p5e_mma
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     616
# 30.0     11
# Name: p5e_mma, dtype: int64
#
#
# COLUMNA:  p5e_mmi
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     616
# 30.0     11
# Name: p5e_mmi, dtype: int64
#
#
# COLUMNA:  p5e_msa
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  0.]
# VALUE COUNTS  0.0    627
# Name: p5e_msa, dtype: int64
#
#
# COLUMNA:  p5e_mvi
# TIPO:  flotante
# NUNIQUE:  2
# UNIQUE:  [nan  0. 30.]
# VALUE COUNTS  0.0     616
# 30.0     11
# Name: p5e_mvi, dtype: int64
#
#
# COLUMNA:  p5e_tdia
# TIPO:  otro
# NUNIQUE:  7
# UNIQUE:  [nan '3' '6' '5' '2' '7' '4' '1']
# VALUE COUNTS  1      3
# 2      5
# 3      9
# 4      9
# 5    347
# 6    222
# 7     32
# Name: p5e_tdia, dtype: int64
#
#
# COLUMNA:  p5e_thrs
# TIPO:  flotante
# NUNIQUE:  49
# UNIQUE:  [ nan  24.  48.  35.  40.  60.  20.  25.  45.  54.  50.  72.  44.   4.
#   98.  46.  51.  84.  56.  36.  18.  68.  70.  30.  42.  55.  16.  12.
#   10.  49.  61.  63.  32.  66.   9.  88.   8.  58.  47.  21.   6. 119.
#   17.  22.  52.  41.  15.  91.  57.  28.]
# VALUE COUNTS  4.0        3
# 6.0        1
# 8.0        1
# 9.0        3
# 10.0       3
# 12.0       3
# 15.0       2
# 16.0       1
# 17.0       1
# 18.0       3
# 20.0       5
# 21.0       1
# 22.0       1
# 24.0       7
# 25.0      16
# 28.0       1
# 30.0      18
# 32.0       7
# 35.0      37
# 36.0      11
# 40.0     150
# 41.0       1
# 42.0      14
# 44.0       6
# 45.0      59
# 46.0       5
# 47.0       2
# 48.0      71
# 49.0       3
# 50.0      61
# 51.0       8
# 52.0       1
# 54.0      19
# 55.0      18
# 56.0       7
# 57.0       1
# 58.0       2
# 60.0      39
# 61.0       2
# 63.0       2
# 66.0       3
# 68.0       2
# 70.0       9
# 72.0      10
# 84.0       3
# 88.0       1
# 91.0       1
# 98.0       1
# 119.0      1
# Name: p5e_thrs, dtype: int64
#
#
# COLUMNA:  p5f
# TIPO:  flotante
# NUNIQUE:  11
# UNIQUE:  [nan  8.  5.  1.  9. 11.  3.  4. 12. 10.  2.  7.]
# VALUE COUNTS  1.0       5
# 2.0       1
# 3.0       4
# 4.0       1
# 5.0      13
# 7.0       1
# 8.0     408
# 9.0       5
# 10.0      3
# 11.0      4
# 12.0      6
# Name: p5f, dtype: int64
#
#
# COLUMNA:  p5f1
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  1.]
# VALUE COUNTS  1.0    3
# Name: p5f1, dtype: int64
#
#
# COLUMNA:  p5f10
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 10.]
# VALUE COUNTS  10.0    6
# Name: p5f10, dtype: int64
#
#
# COLUMNA:  p5f11
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 11.]
# VALUE COUNTS  11.0    2
# Name: p5f11, dtype: int64
#
#
# COLUMNA:  p5f12
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p5f12, dtype: int64)
#
#
# COLUMNA:  p5f13
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 13.]
# VALUE COUNTS  13.0    22
# Name: p5f13, dtype: int64
#
#
# COLUMNA:  p5f14
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 14.]
# VALUE COUNTS  14.0    12133
# Name: p5f14, dtype: int64
#
#
# COLUMNA:  p5f15
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 15.]
# VALUE COUNTS  15.0    1076
# Name: p5f15, dtype: int64
#
#
# COLUMNA:  p5f2
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  2.]
# VALUE COUNTS  2.0    2
# Name: p5f2, dtype: int64
#
#
# COLUMNA:  p5f3
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  3.]
# VALUE COUNTS  3.0    2
# Name: p5f3, dtype: int64
#
#
# COLUMNA:  p5f4
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  4.]
# VALUE COUNTS  4.0    5
# Name: p5f4, dtype: int64
#
#
# COLUMNA:  p5f5
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  5.]
# VALUE COUNTS  5.0    3
# Name: p5f5, dtype: int64
#
#
# COLUMNA:  p5f6
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  6.]
# VALUE COUNTS  6.0    3
# Name: p5f6, dtype: int64
#
#
# COLUMNA:  p5f7
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  7.]
# VALUE COUNTS  7.0    3
# Name: p5f7, dtype: int64
#
#
# COLUMNA:  p5f8
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  8.]
# VALUE COUNTS  8.0    3
# Name: p5f8, dtype: int64
#
#
# COLUMNA:  p5f9
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  9.]
# VALUE COUNTS  9.0    3
# Name: p5f9, dtype: int64
#
#
# COLUMNA:  p5f99
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 99.]
# VALUE COUNTS  99.0    3
# Name: p5f99, dtype: int64
#
#
# COLUMNA:  p5g1
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p5g1, dtype: int64)
#
#
# COLUMNA:  p5g10
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 10.]
# VALUE COUNTS  10.0    1
# Name: p5g10, dtype: int64
#
#
# COLUMNA:  p5g11
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p5g11, dtype: int64)
#
#
# COLUMNA:  p5g12
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p5g12, dtype: int64)
#
#
# COLUMNA:  p5g13
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 13.]
# VALUE COUNTS  13.0    1
# Name: p5g13, dtype: int64
#
#
# COLUMNA:  p5g14
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [14. nan]
# VALUE COUNTS  14.0    3882
# Name: p5g14, dtype: int64
#
#
# COLUMNA:  p5g15
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan 15.]
# VALUE COUNTS  15.0    465
# Name: p5g15, dtype: int64
#
#
# COLUMNA:  p5g2
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  2.]
# VALUE COUNTS  2.0    1
# Name: p5g2, dtype: int64
#
#
# COLUMNA:  p5g3
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  3.]
# VALUE COUNTS  3.0    1
# Name: p5g3, dtype: int64
#
#
# COLUMNA:  p5g4
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  4.]
# VALUE COUNTS  4.0    1
# Name: p5g4, dtype: int64
#
#
# COLUMNA:  p5g5
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  5.]
# VALUE COUNTS  5.0    1
# Name: p5g5, dtype: int64
#
#
# COLUMNA:  p5g6
# TIPO:  flotante
# NUNIQUE:  1
# UNIQUE:  [nan  6.]
# VALUE COUNTS  6.0    1
# Name: p5g6, dtype: int64
#
#
# COLUMNA:  p5g7
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p5g7, dtype: int64)
#
#
# COLUMNA:  p5g8
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p5g8, dtype: int64)
#
#
# COLUMNA:  p5g9
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p5g9, dtype: int64)
#
#
# COLUMNA:  p5g99
# TIPO:  flotante
# NUNIQUE:  0
# UNIQUE:  [nan]
# VALUE COUNTS  Series([], Name: p5g99, dtype: int64)
#
#
# COLUMNA:  p5h
# TIPO:  otro
# NUNIQUE:  2
# UNIQUE:  [nan '2' '1']
# VALUE COUNTS  1    2
# 2    1
# Name: p5h, dtype: int64

# %%
l
# Out:
# ['p1a1',
#  'p1a2',
#  'p1a3',
#  'p1b',
#  'p1c',
#  'p1d',
#  'p1e',
#  'p2_1',
#  'p2_2',
#  'p2_3',
#  'p2_4',
#  'p2_9',
#  'p2a_anio',
#  'p2a_dia',
#  'p2a_mes',
#  'p2a_sem',
#  'p2b',
#  'p2b_anio',
#  'p2b_dia',
#  'p2b_mes',
#  'p2b_sem',
#  'p2c',
#  'p2d1',
#  'p2d10',
#  'p2d11',
#  'p2d2',
#  'p2d3',
#  'p2d4',
#  'p2d5',
#  'p2d6',
#  'p2d7',
#  'p2d8',
#  'p2d9',
#  'p2d99',
#  'p2e',
#  'p2f',
#  'p2g1',
#  'p2g2',
#  'p2h1',
#  'p2h2',
#  'p2h3',
#  'p2h4',
#  'p2h9',
#  'p2i',
#  'p2j',
#  'p2k',
#  'p2k_anio',
#  'p2k_mes',
#  'p3',
#  'p3a',
#  'p3b',
#  'p3c1',
#  'p3c2',
#  'p3c3',
#  'p3c4',
#  'p3c9',
#  'p3d',
#  'p3e',
#  'p3f1',
#  'p3f2',
#  'p3g1_1',
#  'p3g1_2',
#  'p3g2_1',
#  'p3g2_2',
#  'p3g3_1',
#  'p3g3_2',
#  'p3g4_1',
#  'p3g4_2',
#  'p3g9',
#  'p3g_tot',
#  'p3h',
#  'p3i',
#  'p3j',
#  'p3j1',
#  'p3j2',
#  'p3k1',
#  'p3k2',
#  'p3k3',
#  'p3k4',
#  'p3k5',
#  'p3k9',
#  'p3l',
#  'p3l1',
#  'p3l2',
#  'p3l3',
#  'p3l4',
#  'p3l5',
#  'p3l9',
#  'p3m1',
#  'p3m2',
#  'p3m3',
#  'p3m4',
#  'p3m5',
#  'p3m6',
#  'p3m7',
#  'p3m8',
#  'p3m9',
#  'p3n',
#  'p3o',
#  'p3p1',
#  'p3p2',
#  'p3q',
#  'p3r',
#  'p3r_anio',
#  'p3r_mes',
#  'p3s',
#  'p3t_anio',
#  'p3t_mes',
#  'p4',
#  'p4_1',
#  'p4_2',
#  'p4_3',
#  'p4a',
#  'p4a_1',
#  'p4b',
#  'p4c',
#  'p4d1',
#  'p4d2',
#  'p4d3',
#  'p4e',
#  'p4f',
#  'p4g',
#  'p4h',
#  'p4i',
#  'p4i_1',
#  'p5',
#  'p5a',
#  'p5b',
#  'p5b_hdo',
#  'p5b_hju',
#  'p5b_hlu',
#  'p5b_hma',
#  'p5b_hmi',
#  'p5b_hsa',
#  'p5b_hvi',
#  'p5b_mdo',
#  'p5b_mju',
#  'p5b_mlu',
#  'p5b_mma',
#  'p5b_mmi',
#  'p5b_msa',
#  'p5b_mvi',
#  'p5b_tdia',
#  'p5b_thrs',
#  'p5c',
#  'p5c_hdo',
#  'p5c_hju',
#  'p5c_hlu',
#  'p5c_hma',
#  'p5c_hmi',
#  'p5c_hsa',
#  'p5c_hvi',
#  'p5c_mdo',
#  'p5c_mju',
#  'p5c_mlu',
#  'p5c_mma',
#  'p5c_mmi',
#  'p5c_msa',
#  'p5c_mvi',
#  'p5c_tdia',
#  'p5c_thrs',
#  'p5d',
#  'p5d1',
#  'p5d_hdo',
#  'p5d_hju',
#  'p5d_hlu',
#  'p5d_hma',
#  'p5d_hmi',
#  'p5d_hsa',
#  'p5d_hvi',
#  'p5d_mdo',
#  'p5d_mju',
#  'p5d_mlu',
#  'p5d_mma',
#  'p5d_mmi',
#  'p5d_msa',
#  'p5d_mvi',
#  'p5d_tdia',
#  'p5d_thrs',
#  'p5e',
#  'p5e1',
#  'p5e_hdo',
#  'p5e_hju',
#  'p5e_hlu',
#  'p5e_hma',
#  'p5e_hmi',
#  'p5e_hsa',
#  'p5e_hvi',
#  'p5e_mdo',
#  'p5e_mju',
#  'p5e_mlu',
#  'p5e_mma',
#  'p5e_mmi',
#  'p5e_msa',
#  'p5e_mvi',
#  'p5e_tdia',
#  'p5e_thrs',
#  'p5f',
#  'p5f1',
#  'p5f10',
#  'p5f11',
#  'p5f12',
#  'p5f13',
#  'p5f14',
#  'p5f15',
#  'p5f2',
#  'p5f3',
#  'p5f4',
#  'p5f5',
#  'p5f6',
#  'p5f7',
#  'p5f8',
#  'p5f9',
#  'p5f99',
#  'p5g1',
#  'p5g10',
#  'p5g11',
#  'p5g12',
#  'p5g13',
#  'p5g14',
#  'p5g15',
#  'p5g2',
#  'p5g3',
#  'p5g4',
#  'p5g5',
#  'p5g6',
#  'p5g7',
#  'p5g8',
#  'p5g9',
#  'p5g99',
#  'p5h']

# %%
df.head()
# Out:
#    eda  p1 p1a1 p1a2 p1a3  p1b  p1c  p1d  p1e p2_1  ... p5g2 p5g3 p5g4 p5g5  \
# 0   46   1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 1   48   2  NaN  NaN    3    1  5.0    2    1  NaN  ...  NaN  NaN  NaN  NaN
# 2   23   1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 3   18   2  NaN  NaN    3    2  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 4   36   2  NaN  NaN    3    2  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
#
#    p5g6  p5g7  p5g8 p5g9 p5g99  p5h
# 0   NaN   NaN   NaN  NaN   NaN  NaN
# 1   NaN   NaN   NaN  NaN   NaN  NaN
# 2   NaN   NaN   NaN  NaN   NaN  NaN
# 3   NaN   NaN   NaN  NaN   NaN  NaN
# 4   NaN   NaN   NaN  NaN   NaN  NaN
#
# [5 rows x 233 columns]

# %%
df.replace(to_replace=-1,value=np.NaN,inplace=True)

# %%
file = "../../../../../../dataframes/enoe/COE1T/df_concat_2016.csv"

# %%
df.to_csv(path_or_buf=file, index=False)
