# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
file = "../../../../../dataframes/ensu/df_09_impute.csv"

# %%
df = pd.read_csv(file)

# %%
df.shape
# Out:
# (8718, 49)

# %%
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#    BP1_1  BP1_2_01  BP1_2_02  BP1_2_03  BP1_2_04  BP1_2_05  BP1_2_06  \
# 0      2         1         3         2         3         1         2
# 1      2         2         2         2         1         2         2
# 2      2         1         1         2         3         1         1
# 3      1         1         1         1         3         1         1
# 4      2         2         2         2         3         2         1
#
#    BP1_2_07  BP1_2_08  BP1_2_09  ...  BP3_1_09  BP3_1_10  BP3_1_11  BP3_1_12  \
# 0         2         2         2  ...         0         0         0         0
# 1         2         2         2  ...         1         1         1         1
# 2         1         2         3  ...         0         1         1         0
# 3         1         2         2  ...         0         0         0         1
# 4         2         2         3  ...         0         1         0         1
#
#    BP3_1_13  BP3_1_14  BP3_1_15  BP3_1_99  BP3_2  EST
# 0         0         0         0         0      3    3
# 1         1         0         0         0      4    3
# 2         0         0         0         0      3    3
# 3         0         0         0         0      3    3
# 4         0         0         0         0      3    2
#
# [5 rows x 49 columns]

# %%
dataframe_to_transform = df_copy.copy()

for column in df_copy.columns:
    df = pd.DataFrame(dataframe_to_transform[column].value_counts(normalize=True, sort=False, ascending=True))
    #df['cumsum']=(np.cumsum(df[column]))/2
    df['cumsum']=np.cumsum(df[column])
#    print(df)
    
    if df[df.duplicated(['cumsum'], keep=False)].any() is True:
        print(df[df.duplicated(['cumsum'], keep=False)])
    else:
        dict_to_transform = df['cumsum'].to_dict()
#        print(dict_to_transform)
        dataframe_to_transform[column] = dataframe_to_transform[column].replace(dict_to_transform)
#        print(dataframe_to_transform)

# %%
dataframe_to_transform.head()
# Out:
#       BP1_1  BP1_2_01  BP1_2_02  BP1_2_03  BP1_2_04  BP1_2_05  BP1_2_06  \
# 0  1.000000  0.721152  1.000000  0.991971  1.000000  0.351227  0.926933
# 1  1.000000  0.999885  0.704061  0.991971  0.054141  0.838839  0.926933
# 2  1.000000  0.721152  0.403533  0.991971  1.000000  0.351227  0.565841
# 3  0.128585  0.721152  0.403533  0.254416  1.000000  0.351227  0.565841
# 4  1.000000  0.999885  0.704061  0.991971  1.000000  0.838839  0.565841
#
#    BP1_2_07  BP1_2_08  BP1_2_09  ...  BP3_1_09  BP3_1_10  BP3_1_11  BP3_1_12  \
# 0  0.884492  0.843886  0.903189  ...   0.82886  0.161849  0.474191  0.179972
# 1  0.884492  0.843886  0.903189  ...   1.00000  1.000000  1.000000  1.000000
# 2  0.249943  0.843886  1.000000  ...   0.82886  1.000000  1.000000  0.179972
# 3  0.249943  0.843886  0.903189  ...   0.82886  0.161849  0.474191  1.000000
# 4  0.884492  0.843886  1.000000  ...   0.82886  1.000000  0.474191  1.000000
#
#    BP3_1_13  BP3_1_14  BP3_1_15  BP3_1_99     BP3_2       EST
# 0  0.378757  0.967424  0.994953       1.0  0.615508  0.853636
# 1  1.000000  0.967424  0.994953       1.0  0.999426  0.853636
# 2  0.378757  0.967424  0.994953       1.0  0.615508  0.853636
# 3  0.378757  0.967424  0.994953       1.0  0.615508  0.853636
# 4  0.378757  0.967424  0.994953       1.0  0.615508  0.407318
#
# [5 rows x 49 columns]

# %%
df_copy = dataframe_to_transform
df_copy.head()
# Out:
#       BP1_1  BP1_2_01  BP1_2_02  BP1_2_03  BP1_2_04  BP1_2_05  BP1_2_06  \
# 0  1.000000  0.721152  1.000000  0.991971  1.000000  0.351227  0.926933
# 1  1.000000  0.999885  0.704061  0.991971  0.054141  0.838839  0.926933
# 2  1.000000  0.721152  0.403533  0.991971  1.000000  0.351227  0.565841
# 3  0.128585  0.721152  0.403533  0.254416  1.000000  0.351227  0.565841
# 4  1.000000  0.999885  0.704061  0.991971  1.000000  0.838839  0.565841
#
#    BP1_2_07  BP1_2_08  BP1_2_09  ...  BP3_1_09  BP3_1_10  BP3_1_11  BP3_1_12  \
# 0  0.884492  0.843886  0.903189  ...   0.82886  0.161849  0.474191  0.179972
# 1  0.884492  0.843886  0.903189  ...   1.00000  1.000000  1.000000  1.000000
# 2  0.249943  0.843886  1.000000  ...   0.82886  1.000000  1.000000  0.179972
# 3  0.249943  0.843886  0.903189  ...   0.82886  0.161849  0.474191  1.000000
# 4  0.884492  0.843886  1.000000  ...   0.82886  1.000000  0.474191  1.000000
#
#    BP3_1_13  BP3_1_14  BP3_1_15  BP3_1_99     BP3_2       EST
# 0  0.378757  0.967424  0.994953       1.0  0.615508  0.853636
# 1  1.000000  0.967424  0.994953       1.0  0.999426  0.853636
# 2  0.378757  0.967424  0.994953       1.0  0.615508  0.853636
# 3  0.378757  0.967424  0.994953       1.0  0.615508  0.853636
# 4  0.378757  0.967424  0.994953       1.0  0.615508  0.407318
#
# [5 rows x 49 columns]

# %%
list_regejos = df_copy.columns[df_copy.isnull().any()].tolist()
list_regejos
# Out:
# []

# %%
df_copy.drop(labels=list_regejos, axis=1, inplace=True)

# %%
file = "../../../../../dataframes/ensu/df_09_transform.csv"

# %%
df_copy.to_csv(file,index = False, header = True, sep = ',', encoding = 'utf-8')
